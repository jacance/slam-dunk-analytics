# %%
#Imports
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize
import string
import html5lib

# %%
# #Maybe necessary installation
# pip install html5lib

# %%
#Obtain all player names/links
#Set letter list/empty lists
letters = ['m','n','o','p','q','r','s']
player_links3 = []
final_players3 = []
final_player_links = []
official_players = []
for i in letters:
    #Setup preliminary lists for specific letter
    all_players = []
    player_links = []
    final_players = []
    #Soup setup for specific letter
    url = f'https://www.sports-reference.com/cbb/players/{i}-index.html'
    response = requests.get(url)
    soup = bs(response.text, 'html.parser')
    href = soup.find_all('a')
    #Get links
    all_links = [x['href'] for x in href]
    #Get players
    for i in href:
        try:
            all_players.append(i.text)
        except:
            all_players.append(i)
    #Filter for just /cbb/players in URL
    for i in range(len(all_links)):
        try:
            if '/cbb/players' in all_links[i]:
                player_links.append(all_links[i])
                final_players.append(all_players[i])
        except:
            pass
    #Get rid of Danny Vranes, Marvin Barnes, Bobby Hurley, James Worthy, Tayshaun Prince duplicates
    player_links3.append(player_links[:len(player_links)-5])
    final_players3.append(final_players[:len(player_links)-5])
#Unlisting
player_links2 = []
final_players2 = []
for x in player_links3:
    for y in x:
        player_links2.append(y)
for x in final_players3:
    for y in x:
        final_players2.append(y)
#Replace /cbb/players, filter for player names/links only
individual_player_links = [x.replace('/cbb/players','') for x in player_links2 if '/cbb/players' in x]
final_player_links = []
official_players = []
for i in range(len(individual_player_links)):
    if ((individual_player_links[i] != '/') & (individual_player_links[i] != '')): 
        final_player_links.append(individual_player_links[i])
        official_players.append(final_players2[i])

# %%
import bs4
#Get columns
#Soup setup w/comments
url2 = f'https://www.sports-reference.com/cbb/players{final_player_links[0]}'
response2 = requests.get(url2)
soup2 = bs(response2.text)
comments = soup2.find_all(text=lambda text:isinstance(text, bs4.Comment))
#Get commented out HTML
per_40_html = []
for i in range(len(comments)):
    if '<table class="row_summable sortable stats_table" id="players_per_min" data-cols-to-freeze=",1">' in str(comments[i]):
        per_40_html.append(comments[i])
    else:
        pass
#Get column names + create empty table
table1 = pd.read_html(per_40_html[0])
table = pd.DataFrame(columns=table1[0].columns)

# %%
player_table_names = []
for i in range(len(final_player_links)):
    #Soup setup w/comments
    per_40_html = []
    url2 = f'https://www.sports-reference.com/cbb/players{final_player_links[i]}'
    response2 = requests.get(url2)
    soup2 = bs(response2.text)
    comments = soup2.find_all(text=lambda text:isinstance(text, bs4.Comment))
    #Get commented out HTML
    for j in comments:
        if '<table class="row_summable sortable stats_table" id="players_per_min" data-cols-to-freeze=",1">' in str(j):
            per_40_html.append(j)
        else:
            pass
    #Filter for the per 40 to even exist
    if len(per_40_html) != 0:
        #Get base table/append if exists
        table0 = pd.read_html(per_40_html[0])
        table00 = table0[0]
        table00['player'] = official_players[i]
        table = table.append(table00)
        #Add player name to list
        player_table_names.append(official_players[i])
        print(f"Adding {official_players[i]}'s per 40 stats.")
    else:
        print(f"{official_players[i]}'s per 40 stats unavailable. Skipping player!")
# Out:
# Adding Amath M'Baye's per 40 stats.
# Adding Kane Ma's per 40 stats.
# Harvey Maack's per 40 stats unavailable. Skipping player!
# Richard Maack's per 40 stats unavailable. Skipping player!
# Charlese Maag's per 40 stats unavailable. Skipping player!
# Adding Ryan Maag's per 40 stats.
# Charles Maas's per 40 stats unavailable. Skipping player!
# Adding Ryan Maas's per 40 stats.
# Adding Chase Maasdorp's per 40 stats.
# Craig Maass's per 40 stats unavailable. Skipping player!
# Adding Tom Maayan's per 40 stats.
# Adding Nick Mabbutt's per 40 stats.
# Mike Maben's per 40 stats unavailable. Skipping player!
# Ron Maben's per 40 stats unavailable. Skipping player!
# Scott Mabey's per 40 stats unavailable. Skipping player!
# Adding Leroy Mabins's per 40 stats.
# Tony Mabrey's per 40 stats unavailable. Skipping player!
# Guy Mabry's per 40 stats unavailable. Skipping player!
# Adding Halsey Mabry's per 40 stats.
# Thomas Mabry's per 40 stats unavailable. Skipping player!
# Adding Nehemiah Mabson's per 40 stats.
# William Mac Donald's per 40 stats unavailable. Skipping player!
# Jamie Macahon's per 40 stats unavailable. Skipping player!
# Tony Macalik's per 40 stats unavailable. Skipping player!
# Mike Macaluso's per 40 stats unavailable. Skipping player!
# Nick Macarchuk's per 40 stats unavailable. Skipping player!
# Adding Nick Macarchuk's per 40 stats.
# Adding Barry MacArthur's per 40 stats.
# Dale MacArthur's per 40 stats unavailable. Skipping player!
# Ed Macauley's per 40 stats unavailable. Skipping player!
# Peter MacBeth's per 40 stats unavailable. Skipping player!
# Adding Kenny Maccalla's per 40 stats.
# Rick Maccarone's per 40 stats unavailable. Skipping player!
# Bill MacCarthy's per 40 stats unavailable. Skipping player!
# Wil Macchi's per 40 stats unavailable. Skipping player!
# Vince Macciocchi's per 40 stats unavailable. Skipping player!
# Bob MacConnell's per 40 stats unavailable. Skipping player!
# Darin Maccoux's per 40 stats unavailable. Skipping player!
# Adding Todd MacCulloch's per 40 stats.
# Mike MacDermott's per 40 stats unavailable. Skipping player!
# Dean MacDonald's per 40 stats unavailable. Skipping player!
# Glenn MacDonald's per 40 stats unavailable. Skipping player!
# Howard MacDonald's per 40 stats unavailable. Skipping player!
# Jon MacDonald's per 40 stats unavailable. Skipping player!
# Mackey MacDonald's per 40 stats unavailable. Skipping player!
# Adding Mark MacDonald's per 40 stats.
# Adding Matt MacDonald's per 40 stats.
# Mike Macdonald's per 40 stats unavailable. Skipping player!
# Adding Nick MacDonald's per 40 stats.
# Ron MacDonald's per 40 stats unavailable. Skipping player!
# Scott MacDonald's per 40 stats unavailable. Skipping player!
# Scott MacDonald's per 40 stats unavailable. Skipping player!
# Adding Tommy MacDonald's per 40 stats.
# _ MacDonald's per 40 stats unavailable. Skipping player!
# _ MacDonald's per 40 stats unavailable. Skipping player!
# Adding Sean Macdonnell's per 40 stats.
# Adding Connor MacDougall's per 40 stats.
# Adding Matt MacDougall's per 40 stats.
# Ryan MacDowell's per 40 stats unavailable. Skipping player!
# John Macel's per 40 stats unavailable. Skipping player!
# Stan Macel's per 40 stats unavailable. Skipping player!
# Adding Marcus Macellari's per 40 stats.
# Doug Macey's per 40 stats unavailable. Skipping player!
# _ Macey's per 40 stats unavailable. Skipping player!
# Ernest MacFadgen's per 40 stats unavailable. Skipping player!
# George MacFarland's per 40 stats unavailable. Skipping player!
# Adding Kenny Macfarland's per 40 stats.
# Mike MacFarlane's per 40 stats unavailable. Skipping player!
# Adding Taj MacFarlane's per 40 stats.
# Bob MacGillivary's per 40 stats unavailable. Skipping player!
# Ron MacGilvray's per 40 stats unavailable. Skipping player!
# Danny MacGregor's per 40 stats unavailable. Skipping player!
# Adding Gavin MacGregor's per 40 stats.
# Adding Matt MacGregor's per 40 stats.
# Enoch Mach's per 40 stats unavailable. Skipping player!
# Barry Machado's per 40 stats unavailable. Skipping player!
# Adding Jonathan Machado's per 40 stats.
# Adding Pablo Machado's per 40 stats.
# Adding Scott Machado's per 40 stats.
# Adding Bryan Machamer's per 40 stats.
# Adding Matthew Mache's per 40 stats.
# Adding Michael Mache's per 40 stats.
# Adding Marshall Macheledt's per 40 stats.
# Fred Machemer's per 40 stats unavailable. Skipping player!
# John Machiaverna's per 40 stats unavailable. Skipping player!
# Bob Machock's per 40 stats unavailable. Skipping player!
# Bill Machorek's per 40 stats unavailable. Skipping player!
# Adding Brent Machowiak's per 40 stats.
# Adding Carmen Maciariello's per 40 stats.
# Eric Macias's per 40 stats unavailable. Skipping player!
# Mario Macias's per 40 stats unavailable. Skipping player!
# Adding Genesis Maciel's per 40 stats.
# Adding Pedro Maciel's per 40 stats.
# Adding Pedro Maciel's per 40 stats.
# _ MacIntyre's per 40 stats unavailable. Skipping player!
# Al Mack's per 40 stats unavailable. Skipping player!
# Al Mack's per 40 stats unavailable. Skipping player!
# Al Mack's per 40 stats unavailable. Skipping player!
# Alphonso Mack's per 40 stats unavailable. Skipping player!
# Adding Andre Mack's per 40 stats.
# Adding Angelo Mack's per 40 stats.
# Adding Anthony Mack's per 40 stats.
# Adding B.J. Mack's per 40 stats.
# Billy Mack's per 40 stats unavailable. Skipping player!
# Adding Brant Mack's per 40 stats.
# Byron Mack's per 40 stats unavailable. Skipping player!
# Adding Cam Mack's per 40 stats.
# Carlton Mack's per 40 stats unavailable. Skipping player!
# Charles Mack's per 40 stats unavailable. Skipping player!
# Adding Chaz Mack's per 40 stats.
# Adding Chris Mack's per 40 stats.
# Chuck Mack's per 40 stats unavailable. Skipping player!
# Adding Connie Mack's per 40 stats.
# Danny Mack's per 40 stats unavailable. Skipping player!
# Dave Mack's per 40 stats unavailable. Skipping player!
# Adding Doneal Mack's per 40 stats.
# Dorey Mack's per 40 stats unavailable. Skipping player!
# Adding Edward Mack's per 40 stats.
# Adding Eugene Mack's per 40 stats.
# Gene Mack's per 40 stats unavailable. Skipping player!
# Geoff Mack's per 40 stats unavailable. Skipping player!
# Adding Giovanni Mack's per 40 stats.
# Guy Mack's per 40 stats unavailable. Skipping player!
# Harold Mack's per 40 stats unavailable. Skipping player!
# Adding Holland Mack's per 40 stats.
# Adding Isaac Mack's per 40 stats.
# Jerry Mack's per 40 stats unavailable. Skipping player!
# Adding Jimmy Mack's per 40 stats.
# Joe Mack's per 40 stats unavailable. Skipping player!
# Joe Mack's per 40 stats unavailable. Skipping player!
# John Mack's per 40 stats unavailable. Skipping player!
# John Mack's per 40 stats unavailable. Skipping player!
# Adding Johnny Mack's per 40 stats.
# Adding Joshua Mack's per 40 stats.
# Adding Kajon Mack's per 40 stats.
# Adding Ken Mack's per 40 stats.
# Ken Mack's per 40 stats unavailable. Skipping player!
# Adding Kendell Mack's per 40 stats.
# Kendell Mack's per 40 stats unavailable. Skipping player!
# Adding Lamont Mack's per 40 stats.
# Larry Mack's per 40 stats unavailable. Skipping player!
# Lewis Mack's per 40 stats unavailable. Skipping player!
# Adding Marc Mack's per 40 stats.
# Mike Mack's per 40 stats unavailable. Skipping player!
# Adding Monty Mack's per 40 stats.
# Adding Myles Mack's per 40 stats.
# Adding Nehemiah Mack's per 40 stats.
# Ollie Mack's per 40 stats unavailable. Skipping player!
# Phillip Mack's per 40 stats unavailable. Skipping player!
# Ray Mack's per 40 stats unavailable. Skipping player!
# Renardo Mack's per 40 stats unavailable. Skipping player!
# Rodney Mack's per 40 stats unavailable. Skipping player!
# Sam Mack's per 40 stats unavailable. Skipping player!
# Adding Sam Mack's per 40 stats.
# Adding Shelvin Mack's per 40 stats.
# Sherman Mack's per 40 stats unavailable. Skipping player!
# Adding Tavares Mack's per 40 stats.
# Adding Terrence Mack's per 40 stats.
# Adding Tevin Mack's per 40 stats.
# Tom Mack's per 40 stats unavailable. Skipping player!
# Toney Mack's per 40 stats unavailable. Skipping player!
# Tony Mack's per 40 stats unavailable. Skipping player!
# Adding Troy Mack's per 40 stats.
# Adding Ty Mack's per 40 stats.
# George Mackaronis's per 40 stats unavailable. Skipping player!
# Adding Ali Mackay's per 40 stats.
# Hugh Mackay's per 40 stats unavailable. Skipping player!
# Jack Mackay's per 40 stats unavailable. Skipping player!
# John Mackay's per 40 stats unavailable. Skipping player!
# Adding Luke MacKay's per 40 stats.
# Lyndon MacKay's per 40 stats unavailable. Skipping player!
# Rick Mackay's per 40 stats unavailable. Skipping player!
# Earsell Mackbee's per 40 stats unavailable. Skipping player!
# Bobby Macke's per 40 stats unavailable. Skipping player!
# Adding Spencer Macke's per 40 stats.
# William Mackel's per 40 stats unavailable. Skipping player!
# Adding Mike Mackell's per 40 stats.
# Adding Andrew Mackenzie's per 40 stats.
# David MacKenzie's per 40 stats unavailable. Skipping player!
# Jack MacKenzie's per 40 stats unavailable. Skipping player!
# Adding Keith MacKenzie's per 40 stats.
# Ken MacKenzie's per 40 stats unavailable. Skipping player!
# Adding Kimbal MacKenzie's per 40 stats.
# Norm MacKenzie's per 40 stats unavailable. Skipping player!
# Scott MacKenzie's per 40 stats unavailable. Skipping player!
# Tom MacKenzie's per 40 stats unavailable. Skipping player!
# Horace Mackeroy's per 40 stats unavailable. Skipping player!
# Brian Mackey's per 40 stats unavailable. Skipping player!
# Brian Mackey's per 40 stats unavailable. Skipping player!
# Adding Christian Mackey's per 40 stats.
# Daryl Mackey's per 40 stats unavailable. Skipping player!
# Earnest Mackey's per 40 stats unavailable. Skipping player!
# Adding Ethan Mackey's per 40 stats.
# Gerry Mackey's per 40 stats unavailable. Skipping player!
# Greg Mackey's per 40 stats unavailable. Skipping player!
# Adding James Mackey's per 40 stats.
# Jeff Mackey's per 40 stats unavailable. Skipping player!
# Adding Joe Mackey's per 40 stats.
# Joe Mackey's per 40 stats unavailable. Skipping player!
# John Mackey's per 40 stats unavailable. Skipping player!
# Adding Malcolm Mackey's per 40 stats.
# Adding Marcus Mackey's per 40 stats.
# Adding Mario Mackey's per 40 stats.
# Mark Mackey's per 40 stats unavailable. Skipping player!
# Paul Mackey's per 40 stats unavailable. Skipping player!
# Adding Trent Mackey's per 40 stats.
# Troy Mackey's per 40 stats unavailable. Skipping player!
# _ Mackey's per 40 stats unavailable. Skipping player!
# Glen Mackie's per 40 stats unavailable. Skipping player!
# Adding Joran Mackie's per 40 stats.
# Adding Keith Mackie's per 40 stats.
# Ed Mackiewicz's per 40 stats unavailable. Skipping player!
# Dan Mackin's per 40 stats unavailable. Skipping player!
# Gary Mackin's per 40 stats unavailable. Skipping player!
# Bob MacKinnon's per 40 stats unavailable. Skipping player!
# Bruce MacKinnon's per 40 stats unavailable. Skipping player!
# Jim MacKinnon's per 40 stats unavailable. Skipping player!
# _ MacKinnon's per 40 stats unavailable. Skipping player!
# Adding Jesse Mackinson's per 40 stats.
# Bob Mackish's per 40 stats unavailable. Skipping player!
# Adding Daijon Macklien's per 40 stats.
# Adding Brandon Macklin's per 40 stats.
# Dan Macklin's per 40 stats unavailable. Skipping player!
# Adding Danyell Macklin's per 40 stats.
# Adding David Macklin's per 40 stats.
# Gerry Macklin's per 40 stats unavailable. Skipping player!
# Adding Joe Macklin's per 40 stats.
# Adding Joseph Macklin's per 40 stats.
# Ken Macklin's per 40 stats unavailable. Skipping player!
# Adding Oliver Macklin's per 40 stats.
# Rudy Macklin's per 40 stats unavailable. Skipping player!
# Adding Vernon Macklin's per 40 stats.
# Zedric Macklin's per 40 stats unavailable. Skipping player!
# _ Macklin's per 40 stats unavailable. Skipping player!
# Mike Macknin's per 40 stats unavailable. Skipping player!
# Johnny Macknowski's per 40 stats unavailable. Skipping player!
# Tom Macko's per 40 stats unavailable. Skipping player!
# Adding Cedric Mackyeon's per 40 stats.
# _ Maclam's per 40 stats unavailable. Skipping player!
# Breck MacLaren's per 40 stats unavailable. Skipping player!
# Richard MacLaughlin's per 40 stats unavailable. Skipping player!
# _ MacLaughlin's per 40 stats unavailable. Skipping player!
# Adding Andrew Maclay's per 40 stats.
# Don MacLean's per 40 stats unavailable. Skipping player!
# Iain MacLean's per 40 stats unavailable. Skipping player!
# Adding Kyle MacLean's per 40 stats.
# Adding D.J. MacLeay's per 40 stats.
# Bruce MacLeod's per 40 stats unavailable. Skipping player!
# Adding Calum Macleod's per 40 stats.
# Chuck MacLeod's per 40 stats unavailable. Skipping player!
# Gerrard MacLeod's per 40 stats unavailable. Skipping player!
# John MacLeod's per 40 stats unavailable. Skipping player!
# Adding Matt MacLeod's per 40 stats.
# Adding Chad Maclies's per 40 stats.
# Adding Corderio Maclin's per 40 stats.
# Adding Herley Maclin's per 40 stats.
# John Maclin's per 40 stats unavailable. Skipping player!
# Adding Tamarr Maclin's per 40 stats.
# Tom MacMahon's per 40 stats unavailable. Skipping player!
# Hugh MacMasters's per 40 stats unavailable. Skipping player!
# Adding Auryn MacMillan's per 40 stats.
# Hugh MacNeil's per 40 stats unavailable. Skipping player!
# Ed Macner's per 40 stats unavailable. Skipping player!
# Dave Macomber's per 40 stats unavailable. Skipping player!
# Jeff Macomber's per 40 stats unavailable. Skipping player!
# Mark Macomber's per 40 stats unavailable. Skipping player!
# Adding Brian Macon's per 40 stats.
# Carl Macon's per 40 stats unavailable. Skipping player!
# Adding Charles Macon's per 40 stats.
# Adding Daryl Macon's per 40 stats.
# Adding Elijah Macon's per 40 stats.
# Adding Jerry Macon's per 40 stats.
# Mark Macon's per 40 stats unavailable. Skipping player!
# Adding Trayce Macon's per 40 stats.
# Adding Will Macon's per 40 stats.
# _ Macon's per 40 stats unavailable. Skipping player!
# _ Maconochee's per 40 stats unavailable. Skipping player!
# Adding Will Macoy's per 40 stats.
# David MacPhee's per 40 stats unavailable. Skipping player!
# John MacPhee's per 40 stats unavailable. Skipping player!
# Lenny MacPhee's per 40 stats unavailable. Skipping player!
# Les MacPhee's per 40 stats unavailable. Skipping player!
# Wendell MacPhee's per 40 stats unavailable. Skipping player!
# Windy MacPhee's per 40 stats unavailable. Skipping player!
# Adding Allan MacQuarrie's per 40 stats.
# _ MacRae's per 40 stats unavailable. Skipping player!
# Bill Macready's per 40 stats unavailable. Skipping player!
# George Macuga's per 40 stats unavailable. Skipping player!
# John Macukas's per 40 stats unavailable. Skipping player!
# Adding Igor Macura's per 40 stats.
# Adding J.P. Macura's per 40 stats.
# Adding Jere Macura's per 40 stats.
# Adding Petar Macura's per 40 stats.
# Kyle Macy's per 40 stats unavailable. Skipping player!
# Paul Macy's per 40 stats unavailable. Skipping player!
# Steve MacZinko's per 40 stats unavailable. Skipping player!
# Adding Mike Maczko's per 40 stats.
# John Maczuzak's per 40 stats unavailable. Skipping player!
# Doug Madaio's per 40 stats unavailable. Skipping player!
# Drew Madar's per 40 stats unavailable. Skipping player!
# Adding Samer Madarani's per 40 stats.
# Bill Madden's per 40 stats unavailable. Skipping player!
# Chris Madden's per 40 stats unavailable. Skipping player!
# Adding Dajuan Madden's per 40 stats.
# Adding Henry Madden's per 40 stats.
# Adding Hunter-Jack Madden's per 40 stats.
# Kevin Madden's per 40 stats unavailable. Skipping player!
# Kevin Madden's per 40 stats unavailable. Skipping player!
# Mark Madden's per 40 stats unavailable. Skipping player!
# Adding Mark Madden's per 40 stats.
# Adding Maurice Madden's per 40 stats.
# Mitch Madden's per 40 stats unavailable. Skipping player!
# Nils Madden's per 40 stats unavailable. Skipping player!
# Adding Rashad Madden's per 40 stats.
# Adding Tecon Madden's per 40 stats.
# Adding Tom Madden's per 40 stats.
# Wilson Madden's per 40 stats unavailable. Skipping player!
# Bud Maddie's per 40 stats unavailable. Skipping player!
# George Maddock's per 40 stats unavailable. Skipping player!
# Adding Damen Maddox's per 40 stats.
# Adding Dante Maddox's per 40 stats.
# Adding Darius Maddox's per 40 stats.
# Adding Darus Maddox's per 40 stats.
# Adding Gerrald Maddox's per 40 stats.
# Jim Maddox's per 40 stats unavailable. Skipping player!
# Jim Maddox's per 40 stats unavailable. Skipping player!
# Adding Kareem Maddox's per 40 stats.
# Adding Michael Maddox's per 40 stats.
# Mike Maddox's per 40 stats unavailable. Skipping player!
# Milton Maddox's per 40 stats unavailable. Skipping player!
# Adding Sam Maddox's per 40 stats.
# Adding Tito Maddox's per 40 stats.
# Tommy Maddox's per 40 stats unavailable. Skipping player!
# Adding Tray Maddox Jr.'s per 40 stats.
# Joseph Maddrey's per 40 stats unavailable. Skipping player!
# Adding Tyler Maddry's per 40 stats.
# Adding Drew Maddux's per 40 stats.
# Adding Nick Maddux's per 40 stats.
# Ray Maddux's per 40 stats unavailable. Skipping player!
# Ron Madeen's per 40 stats unavailable. Skipping player!
# Adding Matt Maden's per 40 stats.
# Bob Mader's per 40 stats unavailable. Skipping player!
# Adding Dave Mader's per 40 stats.
# John Mader's per 40 stats unavailable. Skipping player!
# Adding Sam Mader's per 40 stats.
# Adding Raphael Madera's per 40 stats.
# Matt Maderos's per 40 stats unavailable. Skipping player!
# Bill Madey's per 40 stats unavailable. Skipping player!
# Adding Jamar Madge's per 40 stats.
# Adding Dragan Madic's per 40 stats.
# Bob Madigan's per 40 stats unavailable. Skipping player!
# Adding Matty Madigan's per 40 stats.
# Adding Patrick Madigan's per 40 stats.
# Adding Joey Madimba's per 40 stats.
# Adding Daniel Mading's per 40 stats.
# Adding Mading Mading's per 40 stats.
# Adding Marial Mading's per 40 stats.
# Adding Ausar Madison's per 40 stats.
# Bernard Madison's per 40 stats unavailable. Skipping player!
# Bill Madison's per 40 stats unavailable. Skipping player!
# Adding Bobby Madison's per 40 stats.
# Adding Charles Madison's per 40 stats.
# Adding Delmonte Madison's per 40 stats.
# Derrold Madison's per 40 stats unavailable. Skipping player!
# Adding James Madison's per 40 stats.
# Jim Madison's per 40 stats unavailable. Skipping player!
# Jimmy Madison's per 40 stats unavailable. Skipping player!
# Adding Karl Madison's per 40 stats.
# Lester Madison's per 40 stats unavailable. Skipping player!
# Adding Matt Madison's per 40 stats.
# Adding Maurice Madison's per 40 stats.
# Paul Madison's per 40 stats unavailable. Skipping player!
# Adding Rashaun Madison's per 40 stats.
# Richard Madison's per 40 stats unavailable. Skipping player!
# Adding Ricky Madison's per 40 stats.
# Adding Stephen Madison's per 40 stats.
# Adding T. Madison's per 40 stats.
# Adding Toby Madison's per 40 stats.
# Adding Tony Madison's per 40 stats.
# Adding Tyler Madison's per 40 stats.
# Gerald Madkins's per 40 stats unavailable. Skipping player!
# Nate Madkins's per 40 stats unavailable. Skipping player!
# Matt Madlinger's per 40 stats unavailable. Skipping player!
# Calvin Madlock's per 40 stats unavailable. Skipping player!
# Adding Cameron Madlock's per 40 stats.
# Adding Ed Madlock's per 40 stats.
# Tony Madlock's per 40 stats unavailable. Skipping player!
# Adding Majok Madol's per 40 stats.
# Bob Madole's per 40 stats unavailable. Skipping player!
# Adding PA Madou Jallow's per 40 stats.
# Adding Nick Madray's per 40 stats.
# Charlie Madrazo's per 40 stats unavailable. Skipping player!
# Steve Madreperla's per 40 stats unavailable. Skipping player!
# Bob Madrick's per 40 stats unavailable. Skipping player!
# Robert Madrick's per 40 stats unavailable. Skipping player!
# Adding Joe Madrid's per 40 stats.
# Adding Jordan Madrid-Andrews's per 40 stats.
# Adding Braiten Madrigal's per 40 stats.
# Al Madsen's per 40 stats unavailable. Skipping player!
# Adding Andrew Madsen's per 40 stats.
# Ed Madsen's per 40 stats unavailable. Skipping player!
# Adding Gabe Madsen's per 40 stats.
# Adding Kyle Madsen's per 40 stats.
# Adding Luke Madsen's per 40 stats.
# Mac Madsen's per 40 stats unavailable. Skipping player!
# Adding Mark Madsen's per 40 stats.
# Adding Mason Madsen's per 40 stats.
# Ed Madson's per 40 stats unavailable. Skipping player!
# Adding Akosa Maduegbunam's per 40 stats.
# Adding Kodi Maduka's per 40 stats.
# Adding Ivan Madunic's per 40 stats.
# Tony Maduri's per 40 stats unavailable. Skipping player!
# Sam Maduro's per 40 stats unavailable. Skipping player!
# Adding Junior Madut's per 40 stats.
# Adding Jan Maehlen's per 40 stats.
# Martin Maehlmann's per 40 stats unavailable. Skipping player!
# Wayne Maenster's per 40 stats unavailable. Skipping player!
# Scott Maentz's per 40 stats unavailable. Skipping player!
# Adding Lebo Maepa's per 40 stats.
# Ed Maerz's per 40 stats unavailable. Skipping player!
# Randy Maerz's per 40 stats unavailable. Skipping player!
# Adding Cameron Maes's per 40 stats.
# George Maes's per 40 stats unavailable. Skipping player!
# Adding Ernie Maesch's per 40 stats.
# Adding Anthony Maestranzi's per 40 stats.
# Bill Maetschke's per 40 stats unavailable. Skipping player!
# _ Maffrey's per 40 stats unavailable. Skipping player!
# Adding Rinaldo Mafra's per 40 stats.
# Adding Roberto Mafra's per 40 stats.
# Adding Mawot Mag's per 40 stats.
# Frank Magaletta's per 40 stats unavailable. Skipping player!
# Cecil Magana's per 40 stats unavailable. Skipping player!
# Larry Magaral's per 40 stats unavailable. Skipping player!
# Bill Magarity's per 40 stats unavailable. Skipping player!
# Billy Magarity's per 40 stats unavailable. Skipping player!
# Adding Dave Magarity's per 40 stats.
# Jake Magarity's per 40 stats unavailable. Skipping player!
# Mark Magarity's per 40 stats unavailable. Skipping player!
# Mike Magarity's per 40 stats unavailable. Skipping player!
# Adding Will Magarity's per 40 stats.
# Eric Magdanz's per 40 stats unavailable. Skipping player!
# Tony Magdowski's per 40 stats unavailable. Skipping player!
# John Mageali's per 40 stats unavailable. Skipping player!
# Brendan Magee's per 40 stats unavailable. Skipping player!
# Adding Cory Magee's per 40 stats.
# Adding Derrick Magee's per 40 stats.
# Dexter Magee's per 40 stats unavailable. Skipping player!
# Dexter Magee's per 40 stats unavailable. Skipping player!
# Adding Dominic Magee's per 40 stats.
# Adding Fletcher Magee's per 40 stats.
# Gerald Magee's per 40 stats unavailable. Skipping player!
# Adding Gregoryshon Magee's per 40 stats.
# Gus Magee's per 40 stats unavailable. Skipping player!
# Jack Magee's per 40 stats unavailable. Skipping player!
# Jeff Magee's per 40 stats unavailable. Skipping player!
# Keith Magee's per 40 stats unavailable. Skipping player!
# Kevin Magee's per 40 stats unavailable. Skipping player!
# Adding Kobe Magee's per 40 stats.
# Norman Magee's per 40 stats unavailable. Skipping player!
# Adding Pat Magee's per 40 stats.
# Pat Magee's per 40 stats unavailable. Skipping player!
# Pete Magee's per 40 stats unavailable. Skipping player!
# Norman Mager's per 40 stats unavailable. Skipping player!
# Billy Magers's per 40 stats unavailable. Skipping player!
# Dan Magett's per 40 stats unavailable. Skipping player!
# Adding Josh Maggard's per 40 stats.
# Adding Kevin Maggard's per 40 stats.
# Michael Maggard's per 40 stats unavailable. Skipping player!
# Adding Corey Maggette's per 40 stats.
# Adding Dylon Maggio's per 40 stats.
# Brian Magid's per 40 stats unavailable. Skipping player!
# _ Magid's per 40 stats unavailable. Skipping player!
# Jim Magill's per 40 stats unavailable. Skipping player!
# Robert Magilligan's per 40 stats unavailable. Skipping player!
# _ Magilligan's per 40 stats unavailable. Skipping player!
# Adding D.J. Magley's per 40 stats.
# David Magley's per 40 stats unavailable. Skipping player!
# John Maglio's per 40 stats unavailable. Skipping player!
# Jim Maglisceau's per 40 stats unavailable. Skipping player!
# Adding Jamaal Magloire's per 40 stats.
# Adding Kostas Maglos's per 40 stats.
# Adding Pat Magnarelli's per 40 stats.
# Adding Will Magnay's per 40 stats.
# Adding Cole Magner's per 40 stats.
# Larry Magner's per 40 stats unavailable. Skipping player!
# Trent Magner's per 40 stats unavailable. Skipping player!
# Jim Magness's per 40 stats unavailable. Skipping player!
# Ernie Magni's per 40 stats unavailable. Skipping player!
# Jack Magno's per 40 stats unavailable. Skipping player!
# Adding Courcy Magnus's per 40 stats.
# Ed Magnus's per 40 stats unavailable. Skipping player!
# Adding Ellis Magnuson's per 40 stats.
# Scott Magnuson's per 40 stats unavailable. Skipping player!
# Vernon Magnuson's per 40 stats unavailable. Skipping player!
# Adding Bjorn Magnussen's per 40 stats.
# Floyd Magnusson's per 40 stats unavailable. Skipping player!
# Jim Magnusson's per 40 stats unavailable. Skipping player!
# Kent Magnusson's per 40 stats unavailable. Skipping player!
# Adding Logan Magnusson's per 40 stats.
# Adding Ajak Magot's per 40 stats.
# Adding Tim Magowan's per 40 stats.
# Ernie Magri's per 40 stats unavailable. Skipping player!
# Bill Maguire's per 40 stats unavailable. Skipping player!
# Bill Maguire's per 40 stats unavailable. Skipping player!
# Bob Maguire's per 40 stats unavailable. Skipping player!
# Adding Dustin Maguire's per 40 stats.
# Jim Maguire's per 40 stats unavailable. Skipping player!
# Joe Maguire's per 40 stats unavailable. Skipping player!
# John Maguire's per 40 stats unavailable. Skipping player!
# Mike Maguire's per 40 stats unavailable. Skipping player!
# Myles Maguire's per 40 stats unavailable. Skipping player!
# Nicholas Maguire's per 40 stats unavailable. Skipping player!
# Paul Maguire's per 40 stats unavailable. Skipping player!
# Adding D'Andre Mahaffey's per 40 stats.
# Donnie Mahaffey's per 40 stats unavailable. Skipping player!
# Adding Jamie Mahaffey's per 40 stats.
# Randy Mahaffey's per 40 stats unavailable. Skipping player!
# Adding Rayne Mahaffey's per 40 stats.
# Richie Mahaffey's per 40 stats unavailable. Skipping player!
# Tom Mahaffey's per 40 stats unavailable. Skipping player!
# Bob Mahala's per 40 stats unavailable. Skipping player!
# Adding Robert Mahala's per 40 stats.
# Tom Mahala's per 40 stats unavailable. Skipping player!
# Hout Mahaley's per 40 stats unavailable. Skipping player!
# Hoyt Mahaley's per 40 stats unavailable. Skipping player!
# Adding Brandon Mahan's per 40 stats.
# Sterling Mahan's per 40 stats unavailable. Skipping player!
# Adding Carter Mahaney's per 40 stats.
# Keith Mahaney's per 40 stats unavailable. Skipping player!
# Larry Mahaney's per 40 stats unavailable. Skipping player!
# Adding Sean Mahany's per 40 stats.
# Andy Mahar's per 40 stats unavailable. Skipping player!
# Shawn Maharaj's per 40 stats unavailable. Skipping player!
# Shawn Maharay's per 40 stats unavailable. Skipping player!
# Dave Maher's per 40 stats unavailable. Skipping player!
# Dennis Maher's per 40 stats unavailable. Skipping player!
# Denny Maher's per 40 stats unavailable. Skipping player!
# Jerry Maher's per 40 stats unavailable. Skipping player!
# Jim Maher's per 40 stats unavailable. Skipping player!
# Jim Maher's per 40 stats unavailable. Skipping player!
# Jim Maher's per 40 stats unavailable. Skipping player!
# Matt Maher's per 40 stats unavailable. Skipping player!
# John Maheras's per 40 stats unavailable. Skipping player!
# _ Mahias's per 40 stats unavailable. Skipping player!
# Gil Mahla's per 40 stats unavailable. Skipping player!
# Jim Mahler's per 40 stats unavailable. Skipping player!
# Adding Anas Mahmoud's per 40 stats.
# Adding Jameel Mahmud's per 40 stats.
# Adding Ryan Mahnken's per 40 stats.
# Bruce Mahon's per 40 stats unavailable. Skipping player!
# John Mahonchak's per 40 stats unavailable. Skipping player!
# Jai Mahone's per 40 stats unavailable. Skipping player!
# Adding Tobias Mahone's per 40 stats.
# _ Mahone's per 40 stats unavailable. Skipping player!
# Adding August Mahoney's per 40 stats.
# Bob Mahoney's per 40 stats unavailable. Skipping player!
# Brian Mahoney's per 40 stats unavailable. Skipping player!
# Brian Mahoney's per 40 stats unavailable. Skipping player!
# Charlie Mahoney's per 40 stats unavailable. Skipping player!
# Daniel Mahoney's per 40 stats unavailable. Skipping player!
# Adding Danny Mahoney's per 40 stats.
# Adding Darin Mahoney's per 40 stats.
# Adding Denzel Mahoney's per 40 stats.
# Adding Dolan Mahoney's per 40 stats.
# Ed Mahoney's per 40 stats unavailable. Skipping player!
# Frank Mahoney's per 40 stats unavailable. Skipping player!
# John Mahoney's per 40 stats unavailable. Skipping player!
# Johnny Mahoney's per 40 stats unavailable. Skipping player!
# Adding Kalen Mahoney's per 40 stats.
# Kenneth Mahoney's per 40 stats unavailable. Skipping player!
# Kurt Mahoney's per 40 stats unavailable. Skipping player!
# Len Mahoney's per 40 stats unavailable. Skipping player!
# Adding Max Mahoney's per 40 stats.
# Mickey Mahoney's per 40 stats unavailable. Skipping player!
# Mike Mahoney's per 40 stats unavailable. Skipping player!
# Paul Mahoney's per 40 stats unavailable. Skipping player!
# Rick Mahoney's per 40 stats unavailable. Skipping player!
# Robert Mahoney's per 40 stats unavailable. Skipping player!
# Adding Shane Mahoney's per 40 stats.
# Tony Mahoney's per 40 stats unavailable. Skipping player!
# _ Mahoney's per 40 stats unavailable. Skipping player!
# _ Mahoney's per 40 stats unavailable. Skipping player!
# _ Mahoney's per 40 stats unavailable. Skipping player!
# Adding Dusan Mahorcic's per 40 stats.
# Adding Andre Mahorn's per 40 stats.
# Adding Marlon Mahorn's per 40 stats.
# Owen Mahorn's per 40 stats unavailable. Skipping player!
# Doug Mahurin's per 40 stats unavailable. Skipping player!
# Adding R.J. Mahurin's per 40 stats.
# Adding Rafael Maia's per 40 stats.
# Adding Wanley Maia's per 40 stats.
# Adding Marten Maide's per 40 stats.
# Adding Timothy Maiden's per 40 stats.
# Adding Chris Maidoh's per 40 stats.
# Gary Maier's per 40 stats unavailable. Skipping player!
# Adding Habib Maiga's per 40 stats.
# Ralph Maigaard's per 40 stats unavailable. Skipping player!
# Dick Maile's per 40 stats unavailable. Skipping player!
# Adding Jason Maile's per 40 stats.
# Adding Jeff Mailhot's per 40 stats.
# Adding Erik Mailliard's per 40 stats.
# Greg Main's per 40 stats unavailable. Skipping player!
# Adding Kareem Maine's per 40 stats.
# Bobby Maines's per 40 stats unavailable. Skipping player!
# Bill Mainor's per 40 stats unavailable. Skipping player!
# Adding Jordan Mains's per 40 stats.
# Adding Nik Mains's per 40 stats.
# Rick Mainwaring's per 40 stats unavailable. Skipping player!
# Victor Mair's per 40 stats unavailable. Skipping player!
# Mike Maisel's per 40 stats unavailable. Skipping player!
# Adding Malik Maitland's per 40 stats.
# _ Maitland's per 40 stats unavailable. Skipping player!
# Adding Richardson Maitre's per 40 stats.
# Adding Wol Maiwen's per 40 stats.
# Adding Mabor Majak's per 40 stats.
# Adding Majur Majak's per 40 stats.
# Adding Panu Majala's per 40 stats.
# Adding Aurimas Majauskas's per 40 stats.
# Dan Majerle's per 40 stats unavailable. Skipping player!
# Jeff Majerle's per 40 stats unavailable. Skipping player!
# Adding Ryan Majerle's per 40 stats.
# Adding Nameir Majette's per 40 stats.
# Adding Alex Majewski's per 40 stats.
# Frank Majewski's per 40 stats unavailable. Skipping player!
# Adding Mark Majick's per 40 stats.
# Mark Majick's per 40 stats unavailable. Skipping player!
# Adding Ater Majok's per 40 stats.
# Adding Majok Majok's per 40 stats.
# Adding Dominique Major's per 40 stats.
# Ed Major's per 40 stats unavailable. Skipping player!
# Adding Franklin Major's per 40 stats.
# Gary Major's per 40 stats unavailable. Skipping player!
# Harley Major's per 40 stats unavailable. Skipping player!
# James Major's per 40 stats unavailable. Skipping player!
# Adding Jazmonn Major's per 40 stats.
# Adding Jeremy Major's per 40 stats.
# Adding Jerry Major's per 40 stats.
# John Major's per 40 stats unavailable. Skipping player!
# Adding Juwan Major's per 40 stats.
# Adding Luke Major's per 40 stats.
# Nat Major's per 40 stats unavailable. Skipping player!
# Adding Renaldo Major's per 40 stats.
# Ross Major's per 40 stats unavailable. Skipping player!
# Adding TayVaughn Major's per 40 stats.
# Zane Major's per 40 stats unavailable. Skipping player!
# Gene Majors's per 40 stats unavailable. Skipping player!
# Jack Majors's per 40 stats unavailable. Skipping player!
# Adding John Majors's per 40 stats.
# Adding Dusan Majstorovic's per 40 stats.
# Adding Yemi Makanjuola's per 40 stats.
# Chester Makarewicz's per 40 stats unavailable. Skipping player!
# Steve Makata's per 40 stats unavailable. Skipping player!
# Bob Makatura's per 40 stats unavailable. Skipping player!
# Ed Makay's per 40 stats unavailable. Skipping player!
# Adding Yemi Makenjuola's per 40 stats.
# Adding Henry Makeny's per 40 stats.
# Adding Chier Maker's per 40 stats.
# Adding Makur Maker's per 40 stats.
# Wyatt Maker's per 40 stats unavailable. Skipping player!
# Adding Alex Maki's per 40 stats.
# Adding Esa Maki-Tulokas's per 40 stats.
# Adding Charles Makings's per 40 stats.
# Adding Kristjan Makke's per 40 stats.
# Mike Makkemos's per 40 stats unavailable. Skipping player!
# Hatim Makki's per 40 stats unavailable. Skipping player!
# Timo Makkonen's per 40 stats unavailable. Skipping player!
# Adding Hungo Makor's per 40 stats.
# Ed Makovsky's per 40 stats unavailable. Skipping player!
# Adding Stas Makshantsev's per 40 stats.
# Adding Omoniyi Makun's per 40 stats.
# Adding Adong Makuoi's per 40 stats.
# Steve Makwinski's per 40 stats unavailable. Skipping player!
# Adding Ege Mala's per 40 stats.
# Bob Malaby's per 40 stats unavailable. Skipping player!
# Mike Malachuk's per 40 stats unavailable. Skipping player!
# Rege Malady's per 40 stats unavailable. Skipping player!
# Raynard Malaine's per 40 stats unavailable. Skipping player!
# Dub Malaise's per 40 stats unavailable. Skipping player!
# Adding Fernando Malaman's per 40 stats.
# Lionel Malamed's per 40 stats unavailable. Skipping player!
# _ Malamed's per 40 stats unavailable. Skipping player!
# Fred Malan's per 40 stats unavailable. Skipping player!
# Dan Malane's per 40 stats unavailable. Skipping player!
# Bill Malarkey's per 40 stats unavailable. Skipping player!
# Pat Malarkey's per 40 stats unavailable. Skipping player!
# Adding Ville Malaska's per 40 stats.
# Adding Chris Malcolm's per 40 stats.
# Duncan Malcolm's per 40 stats unavailable. Skipping player!
# Kim Malcolm's per 40 stats unavailable. Skipping player!
# Kim Malcolm's per 40 stats unavailable. Skipping player!
# Mau Malcolm's per 40 stats unavailable. Skipping player!
# Stanley Malcom's per 40 stats unavailable. Skipping player!
# Adding Hunter Maldonado's per 40 stats.
# Jim Maldonado's per 40 stats unavailable. Skipping player!
# Adding Rafael Maldonado's per 40 stats.
# Paul Maldowney's per 40 stats unavailable. Skipping player!
# Adding Gabas Maldunas's per 40 stats.
# Joe Malecek's per 40 stats unavailable. Skipping player!
# Steve Malecki's per 40 stats unavailable. Skipping player!
# Walt Malecki's per 40 stats unavailable. Skipping player!
# Matt Malerich's per 40 stats unavailable. Skipping player!
# Adding Pawel Malesa's per 40 stats.
# Adding Nikola Malesevic's per 40 stats.
# Mike Maleske's per 40 stats unavailable. Skipping player!
# Jim Maley's per 40 stats unavailable. Skipping player!
# Adding Jimmy Maley's per 40 stats.
# Paul Maley's per 40 stats unavailable. Skipping player!
# Jim Malfetti's per 40 stats unavailable. Skipping player!
# Adding Jay Malham's per 40 stats.
# Adding Jeff Malham's per 40 stats.
# Jeff Malham's per 40 stats unavailable. Skipping player!
# Adding Karandeep Malhi's per 40 stats.
# Adding Anthony Malhoit's per 40 stats.
# Adding Adam Malik's per 40 stats.
# Adding Rasheed Malik's per 40 stats.
# Jim Malinchak's per 40 stats unavailable. Skipping player!
# Tom Malinchak's per 40 stats unavailable. Skipping player!
# _ Malincinski's per 40 stats unavailable. Skipping player!
# Adding Eric Malinowski's per 40 stats.
# Adding Greg Malinowski's per 40 stats.
# _ Malinverni's per 40 stats unavailable. Skipping player!
# Brent Malion's per 40 stats unavailable. Skipping player!
# Ray Malkiewicz's per 40 stats unavailable. Skipping player!
# Dave Malkin's per 40 stats unavailable. Skipping player!
# John Mallard's per 40 stats unavailable. Skipping player!
# Wayne Mallard's per 40 stats unavailable. Skipping player!
# Bill Mallen's per 40 stats unavailable. Skipping player!
# Dave Maller's per 40 stats unavailable. Skipping player!
# Adding Bill Mallernee's per 40 stats.
# Adding Kyle Mallers's per 40 stats.
# Adding Demond Mallet's per 40 stats.
# John Mallet's per 40 stats unavailable. Skipping player!
# Adding Jermaine Mallett's per 40 stats.
# Jerry Mallett's per 40 stats unavailable. Skipping player!
# John Mallett's per 40 stats unavailable. Skipping player!
# Adding Shane Mallett's per 40 stats.
# John Malletta's per 40 stats unavailable. Skipping player!
# Schene Malliet's per 40 stats unavailable. Skipping player!
# Adding Stefan Malliet's per 40 stats.
# Bob Mallimson's per 40 stats unavailable. Skipping player!
# Adding Jason Mallin's per 40 stats.
# Harvey Mallis's per 40 stats unavailable. Skipping player!
# Tom Mallison's per 40 stats unavailable. Skipping player!
# Adding Dave Mallon's per 40 stats.
# Adding Sean Mallon's per 40 stats.
# Billy Mallory's per 40 stats unavailable. Skipping player!
# Adding DeVaughn Mallory's per 40 stats.
# Adding Hodari Mallory's per 40 stats.
# Jim Mallory's per 40 stats unavailable. Skipping player!
# John Mallory's per 40 stats unavailable. Skipping player!
# Adding Kaleb Mallory's per 40 stats.
# Ricky Mallory's per 40 stats unavailable. Skipping player!
# _ Mallory's per 40 stats unavailable. Skipping player!
# Tom Mallot's per 40 stats unavailable. Skipping player!
# Bob Malloy's per 40 stats unavailable. Skipping player!
# Dave Malloy's per 40 stats unavailable. Skipping player!
# Ed Malloy's per 40 stats unavailable. Skipping player!
# Eddie Malloy's per 40 stats unavailable. Skipping player!
# Adding Jerome Malloy's per 40 stats.
# Adding Jonathan Malloy's per 40 stats.
# Adding Rodney Malloy's per 40 stats.
# Adding Shawn Malloy's per 40 stats.
# Steve Malloy's per 40 stats unavailable. Skipping player!
# Steve Malloy's per 40 stats unavailable. Skipping player!
# Terry Malloy's per 40 stats unavailable. Skipping player!
# J. Gunnar Malm's per 40 stats unavailable. Skipping player!
# Arthur Malmberg's per 40 stats unavailable. Skipping player!
# Ron Malmen's per 40 stats unavailable. Skipping player!
# Ron Malmquist's per 40 stats unavailable. Skipping player!
# Gary Malmrose's per 40 stats unavailable. Skipping player!
# _ Malmrose's per 40 stats unavailable. Skipping player!
# Rick Malnati's per 40 stats unavailable. Skipping player!
# Adding Tino Malnati's per 40 stats.
# Chuck Malner's per 40 stats unavailable. Skipping player!
# Gary Maloncon's per 40 stats unavailable. Skipping player!
# Adding Alex Malone's per 40 stats.
# Adding Andre Malone's per 40 stats.
# Art Malone's per 40 stats unavailable. Skipping player!
# Bob Malone's per 40 stats unavailable. Skipping player!
# Bob Malone's per 40 stats unavailable. Skipping player!
# Adding Byron Malone's per 40 stats.
# Adding Costa Malone's per 40 stats.
# Adding Darcy Malone's per 40 stats.
# Adding Dennis Malone's per 40 stats.
# Adding Derick Malone's per 40 stats.
# Adding Donnie Malone's per 40 stats.
# Embry Malone's per 40 stats unavailable. Skipping player!
# Ernest Malone's per 40 stats unavailable. Skipping player!
# Folly Malone's per 40 stats unavailable. Skipping player!
# Adding Gordon Malone's per 40 stats.
# Adding Jason Malone's per 40 stats.
# Adding Jay Malone's per 40 stats.
# Jeff Malone's per 40 stats unavailable. Skipping player!
# Jim Malone's per 40 stats unavailable. Skipping player!
# Joe Malone's per 40 stats unavailable. Skipping player!
# Adding Joey Malone's per 40 stats.
# Adding John Malone's per 40 stats.
# John Malone's per 40 stats unavailable. Skipping player!
# John Malone's per 40 stats unavailable. Skipping player!
# Adding Kaelen Malone's per 40 stats.
# Karl Malone's per 40 stats unavailable. Skipping player!
# Keith Malone's per 40 stats unavailable. Skipping player!
# Keith Malone's per 40 stats unavailable. Skipping player!
# Kevin Malone's per 40 stats unavailable. Skipping player!
# Adding Lekheythan Malone's per 40 stats.
# Malik Malone's per 40 stats unavailable. Skipping player!
# Adding Marcus Malone's per 40 stats.
# Adding Marcus Malone's per 40 stats.
# Marcus Malone's per 40 stats unavailable. Skipping player!
# Adding Marcus Malone's per 40 stats.
# Adding Matt Malone's per 40 stats.
# Adding Mike Malone's per 40 stats.
# Mike Malone's per 40 stats unavailable. Skipping player!
# Adding Moses Malone's per 40 stats.
# Odis Malone's per 40 stats unavailable. Skipping player!
# Adding Ralph Malone's per 40 stats.
# Adding Revaldo Malone's per 40 stats.
# Ron Malone's per 40 stats unavailable. Skipping player!
# Ronnie Malone's per 40 stats unavailable. Skipping player!
# Adding Ryan Malone's per 40 stats.
# Adding Sam Malone's per 40 stats.
# Terrell Malone's per 40 stats unavailable. Skipping player!
# Tom Malone's per 40 stats unavailable. Skipping player!
# Willie Malone's per 40 stats unavailable. Skipping player!
# Adding Xzavier Malone's per 40 stats.
# _ Malone's per 40 stats unavailable. Skipping player!
# Adding Ashton Malone-Dunson's per 40 stats.
# Brian Maloney's per 40 stats unavailable. Skipping player!
# Darren Maloney's per 40 stats unavailable. Skipping player!
# Harry Maloney's per 40 stats unavailable. Skipping player!
# Jim Maloney's per 40 stats unavailable. Skipping player!
# Adding Jimmy Maloney's per 40 stats.
# Joe Maloney's per 40 stats unavailable. Skipping player!
# Joe Maloney's per 40 stats unavailable. Skipping player!
# John Maloney's per 40 stats unavailable. Skipping player!
# Adding Matt Maloney's per 40 stats.
# Adding Matt Maloney's per 40 stats.
# Michael Maloney's per 40 stats unavailable. Skipping player!
# Mike Maloney's per 40 stats unavailable. Skipping player!
# Rick Maloney's per 40 stats unavailable. Skipping player!
# Tom Maloney's per 40 stats unavailable. Skipping player!
# Tom Maloney's per 40 stats unavailable. Skipping player!
# Adding Tre' Maloney's per 40 stats.
# Adding Jason Malonga's per 40 stats.
# Adding Nick Malonga's per 40 stats.
# Steve Malovic's per 40 stats unavailable. Skipping player!
# Jerry Maloy's per 40 stats unavailable. Skipping player!
# Mike Maloy's per 40 stats unavailable. Skipping player!
# Adding Makuach Maluach's per 40 stats.
# Adding K.J. Malveau's per 40 stats.
# Adding Andrew Malveaux's per 40 stats.
# Fred Malveaux's per 40 stats unavailable. Skipping player!
# Murray Malveaux's per 40 stats unavailable. Skipping player!
# Nolton Malveaux's per 40 stats unavailable. Skipping player!
# Tony Malveaux's per 40 stats unavailable. Skipping player!
# Adding Carl Malvo's per 40 stats.
# Adding Chris Mamele's per 40 stats.
# Nick Mamley's per 40 stats unavailable. Skipping player!
# Adding Ben Mammel's per 40 stats.
# Adding Scott Mammel's per 40 stats.
# Adding Fahmmi Mamo's per 40 stats.
# Adding Sandro Mamukelashvili's per 40 stats.
# Pat Manahan's per 40 stats unavailable. Skipping player!
# Pat Manahan's per 40 stats unavailable. Skipping player!
# Ted Manakas's per 40 stats unavailable. Skipping player!
# Adding Troyce Manassa's per 40 stats.
# Adding Omar El Manasterly's per 40 stats.
# Adding Carlos Mancasola's per 40 stats.
# John Mancasola's per 40 stats unavailable. Skipping player!
# Adding Paolo Mancasola's per 40 stats.
# Ron Mancasola's per 40 stats unavailable. Skipping player!
# Adding Garland Mance's per 40 stats.
# Adding Omar-Seli Mance's per 40 stats.
# Gary Manchel's per 40 stats unavailable. Skipping player!
# Adding Darrius Manciel's per 40 stats.
# Adding Mike Manciel's per 40 stats.
# Bill Mancini's per 40 stats unavailable. Skipping player!
# Mark Mancini's per 40 stats unavailable. Skipping player!
# Adding Stefano Mancini's per 40 stats.
# John Mancino's per 40 stats unavailable. Skipping player!
# Pat Mancuso's per 40 stats unavailable. Skipping player!
# Adding Jonathan Mandeldove's per 40 stats.
# Adding Isaiah Manderson's per 40 stats.
# Kevin Manderville's per 40 stats unavailable. Skipping player!
# Adding Richard Mandeville's per 40 stats.
# Adding Mirko Mandic's per 40 stats.
# Nick Mandravelis's per 40 stats unavailable. Skipping player!
# Bob Mandula's per 40 stats unavailable. Skipping player!
# Harry Manee's per 40 stats unavailable. Skipping player!
# Adding Brady Manek's per 40 stats.
# Adding Kellen Manek's per 40 stats.
# Sam Manella's per 40 stats unavailable. Skipping player!
# _ Maner's per 40 stats unavailable. Skipping player!
# Adding Justin Maneri's per 40 stats.
# Bill Maney's per 40 stats unavailable. Skipping player!
# Chris Mang's per 40 stats unavailable. Skipping player!
# Adding Charles Manga's per 40 stats.
# Adding Stephane Manga's per 40 stats.
# John Mangan's per 40 stats unavailable. Skipping player!
# Adding Greg Mangano's per 40 stats.
# Jim Mangapora's per 40 stats unavailable. Skipping player!
# George Manger's per 40 stats unavailable. Skipping player!
# Adding Solomon Mangham's per 40 stats.
# Walt Mangham's per 40 stats unavailable. Skipping player!
# _ Mangham's per 40 stats unavailable. Skipping player!
# Adding Mikey Manghum's per 40 stats.
# Al Mangin's per 40 stats unavailable. Skipping player!
# Pete Mangina's per 40 stats unavailable. Skipping player!
# Leon Mangis's per 40 stats unavailable. Skipping player!
# Adding Collin Mangrum's per 40 stats.
# Adding Kenneth Mangrum's per 40 stats.
# Adding Corey Mangum's per 40 stats.
# Adding Dravon Mangum's per 40 stats.
# Fred Mangum's per 40 stats unavailable. Skipping player!
# Adding Willie Mangum's per 40 stats.
# Adding Sam Manhanga's per 40 stats.
# Jim Manhardt's per 40 stats unavailable. Skipping player!
# Hugh Manhart's per 40 stats unavailable. Skipping player!
# Adding Bobby Manheimer's per 40 stats.
# Carey Manhertz's per 40 stats unavailable. Skipping player!
# Adding Chris Manhertz's per 40 stats.
# Adding Malcolm Manier's per 40 stats.
# Todd Maniford's per 40 stats unavailable. Skipping player!
# Adding Jahenns Manigat's per 40 stats.
# Adding Corey Manigault's per 40 stats.
# Adding Kenny Manigault's per 40 stats.
# Adding Ron Manigault's per 40 stats.
# Adding Dorian Manigo's per 40 stats.
# Bill Manikas's per 40 stats unavailable. Skipping player!
# Bob Manion's per 40 stats unavailable. Skipping player!
# George Manis's per 40 stats unavailable. Skipping player!
# Mike Manis's per 40 stats unavailable. Skipping player!
# Carl Maniscalco's per 40 stats unavailable. Skipping player!
# Adding Sam Maniscalco's per 40 stats.
# Adding Ezra Manjon's per 40 stats.
# Bob Manker's per 40 stats unavailable. Skipping player!
# Adding Chris Manker's per 40 stats.
# Steve Manker's per 40 stats unavailable. Skipping player!
# Adding Tadas Mankevicius's per 40 stats.
# Adding Austin Mankin's per 40 stats.
# John Mankin's per 40 stats unavailable. Skipping player!
# Glen Mankowski's per 40 stats unavailable. Skipping player!
# Adding Devareaux Manley's per 40 stats.
# Joe Manley's per 40 stats unavailable. Skipping player!
# Adding John Manley's per 40 stats.
# Karl Manley's per 40 stats unavailable. Skipping player!
# Adding Keith Manley's per 40 stats.
# Kevin Manley's per 40 stats unavailable. Skipping player!
# Adding Mark Manley's per 40 stats.
# R. Manley's per 40 stats unavailable. Skipping player!
# Adding Sterling Manley's per 40 stats.
# Adding Todd Manley's per 40 stats.
# Adding Tyron Manlove's per 40 stats.
# Howard Manly's per 40 stats unavailable. Skipping player!
# Alan Mann's per 40 stats unavailable. Skipping player!
# Anthony Mann's per 40 stats unavailable. Skipping player!
# Art Mann's per 40 stats unavailable. Skipping player!
# Bill Mann's per 40 stats unavailable. Skipping player!
# Bill Mann's per 40 stats unavailable. Skipping player!
# Billy Mann's per 40 stats unavailable. Skipping player!
# Billy Mann's per 40 stats unavailable. Skipping player!
# Adding Brad Mann's per 40 stats.
# Adding Bradley Mann's per 40 stats.
# Brison Mann's per 40 stats unavailable. Skipping player!
# Adding Charles Mann's per 40 stats.
# Adding Chris Mann's per 40 stats.
# Adding Clint Mann's per 40 stats.
# Adding Cody Mann's per 40 stats.
# Cornelius Mann's per 40 stats unavailable. Skipping player!
# Adding Cornell Mann's per 40 stats.
# Cyrus Mann's per 40 stats unavailable. Skipping player!
# Dave Mann's per 40 stats unavailable. Skipping player!
# Don Mann's per 40 stats unavailable. Skipping player!
# Adding Eric Mann's per 40 stats.
# Fred Mann's per 40 stats unavailable. Skipping player!
# Garry Mann's per 40 stats unavailable. Skipping player!
# Gene Mann's per 40 stats unavailable. Skipping player!
# Hank Mann's per 40 stats unavailable. Skipping player!
# Adding J.J. Mann's per 40 stats.
# Jack Mann's per 40 stats unavailable. Skipping player!
# Adding Jamaine Mann's per 40 stats.
# James Mann's per 40 stats unavailable. Skipping player!
# Adding Jarrett Mann's per 40 stats.
# Adding Jason Mann's per 40 stats.
# Jerry Mann's per 40 stats unavailable. Skipping player!
# Adding Joe Mann's per 40 stats.
# John Mann's per 40 stats unavailable. Skipping player!
# John Mann's per 40 stats unavailable. Skipping player!
# ...
# Dale Smith's per 40 stats unavailable. Skipping player!
# Dallas Smith's per 40 stats unavailable. Skipping player!
# Adding Damany Smith's per 40 stats.
# Adding Damarius Smith's per 40 stats.
# Adding Damian Smith's per 40 stats.
# Adding Damien Smith's per 40 stats.
# Adding Damien Smith's per 40 stats.
# Adding Damion Smith's per 40 stats.
# Dan Smith's per 40 stats unavailable. Skipping player!
# Dan Smith's per 40 stats unavailable. Skipping player!
# Dan Smith's per 40 stats unavailable. Skipping player!
# Dan Smith's per 40 stats unavailable. Skipping player!
# Dan Smith's per 40 stats unavailable. Skipping player!
# Dan Smith's per 40 stats unavailable. Skipping player!
# Dan Smith's per 40 stats unavailable. Skipping player!
# Adding Dana Smith's per 40 stats.
# Dana Smith's per 40 stats unavailable. Skipping player!
# Adding Dane Smith's per 40 stats.
# Adding Daniel Smith's per 40 stats.
# Adding Danny Smith's per 40 stats.
# Adding DaQuan Smith's per 40 stats.
# Adding Darius Smith's per 40 stats.
# Darrell Smith's per 40 stats unavailable. Skipping player!
# Adding Darren Smith's per 40 stats.
# Darrin Smith's per 40 stats unavailable. Skipping player!
# Adding Darryl Smith's per 40 stats.
# Darryl Smith's per 40 stats unavailable. Skipping player!
# Adding Darwayne Smith's per 40 stats.
# Darwin Smith's per 40 stats unavailable. Skipping player!
# Daryl Smith's per 40 stats unavailable. Skipping player!
# Daryl Smith's per 40 stats unavailable. Skipping player!
# Adding Dave Smith's per 40 stats.
# Dave Smith's per 40 stats unavailable. Skipping player!
# Dave Smith's per 40 stats unavailable. Skipping player!
# Dave Smith's per 40 stats unavailable. Skipping player!
# Dave Smith's per 40 stats unavailable. Skipping player!
# Dave Smith's per 40 stats unavailable. Skipping player!
# Dave Smith's per 40 stats unavailable. Skipping player!
# Dave Smith's per 40 stats unavailable. Skipping player!
# Dave Smith's per 40 stats unavailable. Skipping player!
# Dave Smith's per 40 stats unavailable. Skipping player!
# David Smith's per 40 stats unavailable. Skipping player!
# David Smith's per 40 stats unavailable. Skipping player!
# David Smith's per 40 stats unavailable. Skipping player!
# David Smith's per 40 stats unavailable. Skipping player!
# David Smith's per 40 stats unavailable. Skipping player!
# Adding David Smith's per 40 stats.
# David Smith's per 40 stats unavailable. Skipping player!
# Adding David Smith's per 40 stats.
# Adding Davis Smith's per 40 stats.
# Dean Smith's per 40 stats unavailable. Skipping player!
# Dean Smith's per 40 stats unavailable. Skipping player!
# Dean Smith's per 40 stats unavailable. Skipping player!
# Adding Deivon Smith's per 40 stats.
# DeJuan Smith's per 40 stats unavailable. Skipping player!
# Delos Smith's per 40 stats unavailable. Skipping player!
# Adding Demarius Smith's per 40 stats.
# Adding Demetrious Smith's per 40 stats.
# Adding Demetrius Smith's per 40 stats.
# Adding Demetrius Smith's per 40 stats.
# Adding Dennis Smith's per 40 stats.
# Adding Dennis Smith's per 40 stats.
# Dennis Smith's per 40 stats unavailable. Skipping player!
# Dennis Smith's per 40 stats unavailable. Skipping player!
# Dennis Smith's per 40 stats unavailable. Skipping player!
# Dennis Smith's per 40 stats unavailable. Skipping player!
# Dennis Smith's per 40 stats unavailable. Skipping player!
# Dennis Smith's per 40 stats unavailable. Skipping player!
# Adding Deonte Smith's per 40 stats.
# Derek Smith's per 40 stats unavailable. Skipping player!
# Adding Derek Smith's per 40 stats.
# Adding Derek Smith's per 40 stats.
# Adding Derek Smith's per 40 stats.
# Adding Derrick Smith's per 40 stats.
# Adding Derrick Smith's per 40 stats.
# Adding Derrick Smith's per 40 stats.
# Adding Deuce Smith's per 40 stats.
# Adding Deville Smith's per 40 stats.
# Adding Devin Smith's per 40 stats.
# Adding Devon Smith's per 40 stats.
# Adding DeVonte Smith's per 40 stats.
# Adding Dexter Smith's per 40 stats.
# Adding Diante Smith's per 40 stats.
# Dick Smith's per 40 stats unavailable. Skipping player!
# Dick Smith's per 40 stats unavailable. Skipping player!
# Dick Smith's per 40 stats unavailable. Skipping player!
# Dick Smith's per 40 stats unavailable. Skipping player!
# Adding Dionne Smith's per 40 stats.
# Adding Dominic Smith's per 40 stats.
# Don Smith's per 40 stats unavailable. Skipping player!
# Don Smith's per 40 stats unavailable. Skipping player!
# Don Smith's per 40 stats unavailable. Skipping player!
# Adding Don Smith's per 40 stats.
# Don Smith's per 40 stats unavailable. Skipping player!
# Don Smith's per 40 stats unavailable. Skipping player!
# Don Smith's per 40 stats unavailable. Skipping player!
# Adding Donald Smith's per 40 stats.
# Donald Smith's per 40 stats unavailable. Skipping player!
# Donald Smith's per 40 stats unavailable. Skipping player!
# Donnell Smith's per 40 stats unavailable. Skipping player!
# Adding Donohue Smith's per 40 stats.
# Adding Donovan Smith's per 40 stats.
# Adding Dontaie Smith's per 40 stats.
# Adding Dontavious Smith's per 40 stats.
# Adding Donte Smith's per 40 stats.
# Adding Donte Smith's per 40 stats.
# Adding Donte Smith's per 40 stats.
# Adding Doug Smith's per 40 stats.
# Doug Smith's per 40 stats unavailable. Skipping player!
# Doug Smith's per 40 stats unavailable. Skipping player!
# Doug Smith's per 40 stats unavailable. Skipping player!
# Doug Smith's per 40 stats unavailable. Skipping player!
# Doug Smith's per 40 stats unavailable. Skipping player!
# Adding Drew Smith's per 40 stats.
# Adding Drew Smith's per 40 stats.
# Adding Dru Smith's per 40 stats.
# Duane Smith's per 40 stats unavailable. Skipping player!
# Adding Dudley Smith's per 40 stats.
# Durward Smith's per 40 stats unavailable. Skipping player!
# Durwood Smith's per 40 stats unavailable. Skipping player!
# Adding Dwayne Smith's per 40 stats.
# Dwayne Smith's per 40 stats unavailable. Skipping player!
# Dwayne Smith's per 40 stats unavailable. Skipping player!
# Adding Dwight Smith's per 40 stats.
# Dwight Smith's per 40 stats unavailable. Skipping player!
# Adding Dylan Smith's per 40 stats.
# Adding Earl Smith's per 40 stats.
# Earl Smith's per 40 stats unavailable. Skipping player!
# Adding Early Smith's per 40 stats.
# Ed Smith's per 40 stats unavailable. Skipping player!
# Ed Smith's per 40 stats unavailable. Skipping player!
# Ed Smith's per 40 stats unavailable. Skipping player!
# Ed Smith's per 40 stats unavailable. Skipping player!
# Adding Eddie Smith's per 40 stats.
# Adding Eddie Smith's per 40 stats.
# Eddie Smith's per 40 stats unavailable. Skipping player!
# Eddie Smith's per 40 stats unavailable. Skipping player!
# Edward Smith's per 40 stats unavailable. Skipping player!
# Adding Effrence Smith's per 40 stats.
# Adding Eliot Smith's per 40 stats.
# Ellsworth Smith's per 40 stats unavailable. Skipping player!
# Adding Emanuel Smith's per 40 stats.
# Adding Emmanuel Smith's per 40 stats.
# Emmett Smith's per 40 stats unavailable. Skipping player!
# Adding Eric Smith 's per 40 stats.
# Adding Eric Smith's per 40 stats.
# Adding Eric Smith's per 40 stats.
# Adding Eric Smith's per 40 stats.
# Eric Smith's per 40 stats unavailable. Skipping player!
# Eric Smith's per 40 stats unavailable. Skipping player!
# Eric Smith's per 40 stats unavailable. Skipping player!
# Eric Smith's per 40 stats unavailable. Skipping player!
# Eric Smith's per 40 stats unavailable. Skipping player!
# Adding Erick Smith's per 40 stats.
# Adding Erik Smith's per 40 stats.
# Adding Erik Smith's per 40 stats.
# Ernest Smith's per 40 stats unavailable. Skipping player!
# Ernie Smith's per 40 stats unavailable. Skipping player!
# Eugene Smith's per 40 stats unavailable. Skipping player!
# Adding Evan Smith's per 40 stats.
# Adding Evan Smith's per 40 stats.
# Adding Everett Smith's per 40 stats.
# Frank Smith's per 40 stats unavailable. Skipping player!
# Frank Smith's per 40 stats unavailable. Skipping player!
# Frank Smith's per 40 stats unavailable. Skipping player!
# Franz Smith's per 40 stats unavailable. Skipping player!
# Adding Fred Smith's per 40 stats.
# Adding Fred Smith's per 40 stats.
# Adding Fred Smith's per 40 stats.
# Fred Smith's per 40 stats unavailable. Skipping player!
# Fred Smith's per 40 stats unavailable. Skipping player!
# Fred Lucky Smith's per 40 stats unavailable. Skipping player!
# Adding G.G. Smith's per 40 stats.
# G.J. Smith's per 40 stats unavailable. Skipping player!
# Adding Galin Smith's per 40 stats.
# Garfield Smith's per 40 stats unavailable. Skipping player!
# Garfield Smith's per 40 stats unavailable. Skipping player!
# Adding Garn Smith's per 40 stats.
# Adding Gary Smith's per 40 stats.
# Gary Smith's per 40 stats unavailable. Skipping player!
# Gary Smith's per 40 stats unavailable. Skipping player!
# Gavin Smith's per 40 stats unavailable. Skipping player!
# Gayle Smith's per 40 stats unavailable. Skipping player!
# Gene Smith's per 40 stats unavailable. Skipping player!
# Adding Gene Smith's per 40 stats.
# Gene Smith's per 40 stats unavailable. Skipping player!
# Gene Smith's per 40 stats unavailable. Skipping player!
# Gene Smith's per 40 stats unavailable. Skipping player!
# Gene Smith's per 40 stats unavailable. Skipping player!
# George Smith's per 40 stats unavailable. Skipping player!
# George Smith's per 40 stats unavailable. Skipping player!
# Adding Gerald Smith's per 40 stats.
# Gerald Smith's per 40 stats unavailable. Skipping player!
# Gerald Smith's per 40 stats unavailable. Skipping player!
# Gerald Smith's per 40 stats unavailable. Skipping player!
# Adding Gerard Smith's per 40 stats.
# Gerry Smith's per 40 stats unavailable. Skipping player!
# Adding Gino Smith's per 40 stats.
# Adding Giovanni Smith's per 40 stats.
# Glen Smith's per 40 stats unavailable. Skipping player!
# Glenn Smith's per 40 stats unavailable. Skipping player!
# Glenn Smith's per 40 stats unavailable. Skipping player!
# Glenn Smith's per 40 stats unavailable. Skipping player!
# Gordon Smith's per 40 stats unavailable. Skipping player!
# Grady Smith's per 40 stats unavailable. Skipping player!
# Adding Greg Smith's per 40 stats.
# Greg Smith's per 40 stats unavailable. Skipping player!
# Greg Smith's per 40 stats unavailable. Skipping player!
# Greg Smith's per 40 stats unavailable. Skipping player!
# Greg Smith's per 40 stats unavailable. Skipping player!
# Greg Smith's per 40 stats unavailable. Skipping player!
# Greg Smith's per 40 stats unavailable. Skipping player!
# Adding Greg Smith's per 40 stats.
# Adding Greg Smith's per 40 stats.
# Adding Greg Smith's per 40 stats.
# Adding Greg Smith's per 40 stats.
# Adding Greg Smith's per 40 stats.
# Greg Smith's per 40 stats unavailable. Skipping player!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-6d35fb877e5f> in <module>
#       4     per_40_html = []
#       5     url2 = f'https://www.sports-reference.com/cbb/players{final_player_links[i]}'
# ----> 6     response2 = requests.get(url2)
#       7     soup2 = bs(response2.text)
#       8     comments = soup2.find_all(text=lambda text:isinstance(text, bs4.Comment))
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/http/client.py in getresponse(self)
#    1352         try:
#    1353             try:
# -> 1354                 response.begin()
#    1355             except ConnectionError:
#    1356                 self.close()
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1010                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1011                   self.__class__)
# -> 1012             return self.read(nbytes, buffer)
#    1013         else:
#    1014             return socket.recv_into(self, buffer, nbytes, flags)
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/ssl.py in read(self, len, buffer)
#     872             raise ValueError("Read on closed or unwrapped SSL socket.")
#     873         try:
# --> 874             return self._sslobj.read(len, buffer)
#     875         except SSLError as x:
#     876             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
table.to_csv("Players_M-GregSmith.csv")
