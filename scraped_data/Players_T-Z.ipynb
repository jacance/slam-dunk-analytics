# %%
#Imports

from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize
import string
import html5lib

# %%
#Maybe necessary installation
#pip install html5lib

# %%
#Obtain all player names/links

#Set letter list/empty lists
letters = ['t','u','v','w','x','y','z']
player_links3 = []
final_players3 = []
final_player_links = []
official_players = []

for i in letters:
    #Setup preliminary lists for specific letter
    all_players = []
    player_links = []
    final_players = []
    #Soup setup for specific letter
    url = f'https://www.sports-reference.com/cbb/players/{i}-index.html'
    response = requests.get(url)
    soup = bs(response.text, 'html.parser')
    href = soup.find_all('a')
    #Get links
    all_links = [x['href'] for x in href]
    #Get players
    for i in href:
        try:
            all_players.append(i.text)
        except:
            all_players.append(i)
    #Filter for just /cbb/players in URL
    for i in range(len(all_links)):
        try:
            if '/cbb/players' in all_links[i]:
                player_links.append(all_links[i])
                final_players.append(all_players[i])
        except:
            pass
    #Get rid of Danny Vranes, Marvin Barnes, Bobby Hurley, James Worthy, Tayshaun Prince duplicates
    player_links3.append(player_links[:len(player_links)-5])
    final_players3.append(final_players[:len(player_links)-5])

#Unlisting
player_links2 = []
final_players2 = []

for x in player_links3:
    for y in x:
        player_links2.append(y)
        
for x in final_players3:
    for y in x:
        final_players2.append(y)
        
#Replace /cbb/players, filter for player names/links only
individual_player_links = [x.replace('/cbb/players','') for x in player_links2 if '/cbb/players' in x]
final_player_links = []
official_players = []

for i in range(len(individual_player_links)):
    if ((individual_player_links[i] != '/') & (individual_player_links[i] != '')): 
        final_player_links.append(individual_player_links[i])
        official_players.append(final_players2[i])

# %%
import bs4

#Get columns
#Soup setup w/comments
url2 = f'https://www.sports-reference.com/cbb/players{final_player_links[0]}'
response2 = requests.get(url2)
soup2 = bs(response2.text)
comments = soup2.find_all(text=lambda text:isinstance(text, bs4.Comment))
#Get commented out HTML
per_40_html = []
for i in range(len(comments)):
    if '<table class="row_summable sortable stats_table" id="players_per_min" data-cols-to-freeze=",1">' in str(comments[i]):
        per_40_html.append(comments[i])
    else:
        pass
#Get column names + create empty table
table1 = pd.read_html(per_40_html[0])
table = pd.DataFrame(columns=table1[0].columns)

# %%
player_table_names = []

for i in range(len(final_player_links)):
    #Soup setup w/comments
    per_40_html = []
    url2 = f'https://www.sports-reference.com/cbb/players{final_player_links[i]}'
    response2 = requests.get(url2)
    soup2 = bs(response2.text)
    comments = soup2.find_all(text=lambda text:isinstance(text, bs4.Comment))
    #Get commented out HTML
    for j in comments:
        if '<table class="row_summable sortable stats_table" id="players_per_min" data-cols-to-freeze=",1">' in str(j):
            per_40_html.append(j)
        else:
            pass
    #Filter for the per 40 to even exist
    if len(per_40_html) != 0:
        #Get base table/append if exists
        table0 = pd.read_html(per_40_html[0])
        table00 = table0[0]
        table00['player'] = official_players[i]
        table = table.append(table00)
        #Add player name to list
        player_table_names.append(official_players[i])
        print(f"Adding {official_players[i]}'s per 40 stats.")
    else:
        print(f"{official_players[i]}'s per 40 stats unavailable. Skipping player!")
# Out:
# Adding Jafar Taalib's per 40 stats.
# Ken Tabaka's per 40 stats unavailable. Skipping player!
# Adding Emmanuel Taban's per 40 stats.
# Ed Tabash's per 40 stats unavailable. Skipping player!
# Adding Brandon Tabb's per 40 stats.
# Adding Colin Tabb's per 40 stats.
# Adding Demarquelle Tabb's per 40 stats.
# Adding Josh Tabb's per 40 stats.
# Adding Ladarius Tabb's per 40 stats.
# Adding Melvin Tabb's per 40 stats.
# Adding Michael Tabb's per 40 stats.
# Adding Sean Tabb's per 40 stats.
# Adding Wynston Tabbs's per 40 stats.
# Adding Kyle Taber's per 40 stats.
# Aaron Tabet's per 40 stats unavailable. Skipping player!
# Adding Charles Tabet's per 40 stats.
# Adding Philip Tabet's per 40 stats.
# Sam Tabet's per 40 stats unavailable. Skipping player!
# Dennis Tabisz's per 40 stats unavailable. Skipping player!
# Adding Troy Tabler's per 40 stats.
# Clyde Tables's per 40 stats unavailable. Skipping player!
# Adding Tarkan Taboglu's per 40 stats.
# Adding Alex Tabor's per 40 stats.
# Chet Tabor's per 40 stats unavailable. Skipping player!
# Gerald Tabor's per 40 stats unavailable. Skipping player!
# Joel Tabor's per 40 stats unavailable. Skipping player!
# Ron Tabron's per 40 stats unavailable. Skipping player!
# Bob Tabscott's per 40 stats unavailable. Skipping player!
# Adding Stefan Tacke's per 40 stats.
# Clyde Tackett's per 40 stats unavailable. Skipping player!
# Jim Tackett's per 40 stats unavailable. Skipping player!
# Adding Todd Tackett's per 40 stats.
# John Taddiken's per 40 stats unavailable. Skipping player!
# _ Tadei's per 40 stats unavailable. Skipping player!
# Dave Tadich's per 40 stats unavailable. Skipping player!
# Adding Jared Tadlock's per 40 stats.
# Travis Tadysak's per 40 stats unavailable. Skipping player!
# Adding Chris Taflinger's per 40 stats.
# Adding Fabrice Tafo's per 40 stats.
# Adding Tyler Tafoya's per 40 stats.
# Adding Chris Taft's per 40 stats.
# John Taft's per 40 stats unavailable. Skipping player!
# Morris Taft's per 40 stats unavailable. Skipping player!
# Tom Tagatz's per 40 stats unavailable. Skipping player!
# Glenn Taggart's per 40 stats unavailable. Skipping player!
# Adding Harrison Taggart's per 40 stats.
# Jeff Taggart's per 40 stats unavailable. Skipping player!
# Adding Nick Taggart's per 40 stats.
# Adding Shawn Taggart's per 40 stats.
# Paul Tagliabue's per 40 stats unavailable. Skipping player!
# Walt Tague's per 40 stats unavailable. Skipping player!
# Adding Joonas Tahvanainen's per 40 stats.
# Adding Ville Tahvanainen's per 40 stats.
# Adding Sean Taibi's per 40 stats.
# Adding David Tairu's per 40 stats.
# Herbert Taischer's per 40 stats unavailable. Skipping player!
# Alan Tait's per 40 stats unavailable. Skipping player!
# Charles Tait's per 40 stats unavailable. Skipping player!
# Karl Tait's per 40 stats unavailable. Skipping player!
# Marshall Tait's per 40 stats unavailable. Skipping player!
# Michael Tait's per 40 stats unavailable. Skipping player!
# Sutton Tait's per 40 stats unavailable. Skipping player!
# Tom Tait's per 40 stats unavailable. Skipping player!
# Adding Noah Taitz's per 40 stats.
# Adding Lance Takaki's per 40 stats.
# Adding Imran Takhar's per 40 stats.
# Adding Sama Taku's per 40 stats.
# Mark Talaga's per 40 stats unavailable. Skipping player!
# Alan Talbert's per 40 stats unavailable. Skipping player!
# Adding Chance Talbert's per 40 stats.
# Adding Ezra Talbert's per 40 stats.
# Adding Jacob Talbert's per 40 stats.
# Adding Josiah Talbert's per 40 stats.
# Reggie Talbert's per 40 stats unavailable. Skipping player!
# Ricky Talbert's per 40 stats unavailable. Skipping player!
# _ Talbert's per 40 stats unavailable. Skipping player!
# Bill Talbot's per 40 stats unavailable. Skipping player!
# Adding Brandyn Talbot's per 40 stats.
# George Talbot's per 40 stats unavailable. Skipping player!
# Adding Gilbert Talbot's per 40 stats.
# John Talbot's per 40 stats unavailable. Skipping player!
# Lloyd Talbot's per 40 stats unavailable. Skipping player!
# Maurice Talbot's per 40 stats unavailable. Skipping player!
# Tyron Talbot's per 40 stats unavailable. Skipping player!
# Tyrone Talbot's per 40 stats unavailable. Skipping player!
# Bill Talbott's per 40 stats unavailable. Skipping player!
# Chuck Talbott's per 40 stats unavailable. Skipping player!
# Dartez Talbott's per 40 stats unavailable. Skipping player!
# Jim Talbott's per 40 stats unavailable. Skipping player!
# Jude Talbott's per 40 stats unavailable. Skipping player!
# Wayne Talbott's per 40 stats unavailable. Skipping player!
# Alan Talboy's per 40 stats unavailable. Skipping player!
# Adding Shauhin Talesh's per 40 stats.
# Calvin Talford's per 40 stats unavailable. Skipping player!
# Adding Kelton Talford's per 40 stats.
# Adding Landon Taliaferro's per 40 stats.
# Woody Taliaferro's per 40 stats unavailable. Skipping player!
# _ Taliaferro's per 40 stats unavailable. Skipping player!
# Adding Idris Talib's per 40 stats.
# Adding Chris Talkington's per 40 stats.
# John Talkington's per 40 stats unavailable. Skipping player!
# John Talkington's per 40 stats unavailable. Skipping player!
# Adding Ted Talkington's per 40 stats.
# Adding Racine Talla's per 40 stats.
# Adding James Tallarico's per 40 stats.
# Bob Tallent's per 40 stats unavailable. Skipping player!
# Mike Tallent's per 40 stats unavailable. Skipping player!
# Pat Tallent's per 40 stats unavailable. Skipping player!
# Adding Arthur Talley's per 40 stats.
# Adding Brian Talley's per 40 stats.
# Cliff Talley's per 40 stats unavailable. Skipping player!
# Craig Talley's per 40 stats unavailable. Skipping player!
# Adding Dylan Talley's per 40 stats.
# Eddie Talley's per 40 stats unavailable. Skipping player!
# Eddie Talley's per 40 stats unavailable. Skipping player!
# Adding Eric Talley's per 40 stats.
# Adding Gene Talley's per 40 stats.
# Jay Talley's per 40 stats unavailable. Skipping player!
# Adding Jordon Talley's per 40 stats.
# Ken Talley's per 40 stats unavailable. Skipping player!
# Adding Marlow Talley's per 40 stats.
# Adding Michael Talley's per 40 stats.
# Adding Mike Talley's per 40 stats.
# Reggie Talley's per 40 stats unavailable. Skipping player!
# Adding Shawn Talley's per 40 stats.
# Stan Talley's per 40 stats unavailable. Skipping player!
# Terrence Talley's per 40 stats unavailable. Skipping player!
# Terry Talley's per 40 stats unavailable. Skipping player!
# Wendell Talley's per 40 stats unavailable. Skipping player!
# Adding Zoran Talley's per 40 stats.
# Jeff Tallman's per 40 stats unavailable. Skipping player!
# Adding Nate Tallman's per 40 stats.
# Eric Talmadge's per 40 stats unavailable. Skipping player!
# Gary Talmadge's per 40 stats unavailable. Skipping player!
# Adding Erik Talton's per 40 stats.
# Adding Gary Talton's per 40 stats.
# Adding Tyree Talton's per 40 stats.
# Adding Xavier  Talton's per 40 stats.
# Adding Jashawn Talton-Thomas's per 40 stats.
# Crick Talus's per 40 stats unavailable. Skipping player!
# Phil Tama's per 40 stats unavailable. Skipping player!
# Adding Marcos Tamares's per 40 stats.
# Dick Tamberg's per 40 stats unavailable. Skipping player!
# Adding Amit Tamir's per 40 stats.
# Adding Quinn Tamm's per 40 stats.
# Wes Tamm's per 40 stats unavailable. Skipping player!
# Morris Tampa's per 40 stats unavailable. Skipping player!
# Adding Adam Tancredi's per 40 stats.
# Adding George Tandy's per 40 stats.
# George Tandy's per 40 stats unavailable. Skipping player!
# James Tandy's per 40 stats unavailable. Skipping player!
# Adding Kyky Tandy's per 40 stats.
# Abraham Tang's per 40 stats unavailable. Skipping player!
# Adding Chop Tang's per 40 stats.
# Adding Chris Tang's per 40 stats.
# Adding Louis Tang's per 40 stats.
# Adding Mohamed Tangara's per 40 stats.
# Jim Tangeman's per 40 stats unavailable. Skipping player!
# Thomas Tangeman's per 40 stats unavailable. Skipping player!
# Adding Leonard Tangishaka's per 40 stats.
# Dave Tanis's per 40 stats unavailable. Skipping player!
# Adding Ryan Tankelewicz's per 40 stats.
# Adding Tom Tankelewicz's per 40 stats.
# Adding Damon Tankersley's per 40 stats.
# Dwayne Tanks's per 40 stats unavailable. Skipping player!
# Adding Ameen Tanksley's per 40 stats.
# Joe Tanksley's per 40 stats unavailable. Skipping player!
# Adding Robert Tankson's per 40 stats.
# Adding Shawn Tann's per 40 stats.
# Ricky Tanneberger's per 40 stats unavailable. Skipping player!
# Adding Caleb Tannehill's per 40 stats.
# Marty Tannenbaum's per 40 stats unavailable. Skipping player!
# _ Tannenbaum's per 40 stats unavailable. Skipping player!
# Adding Adam Tanner's per 40 stats.
# Adding Alton Tanner's per 40 stats.
# Adding Andy Tanner's per 40 stats.
# Anthony Tanner's per 40 stats unavailable. Skipping player!
# Adding Caleb Tanner's per 40 stats.
# Clarence Tanner's per 40 stats unavailable. Skipping player!
# Darrell Tanner's per 40 stats unavailable. Skipping player!
# Adding David Tanner's per 40 stats.
# Adding Deaundra Tanner's per 40 stats.
# D\'Wayne Tanner's per 40 stats unavailable. Skipping player!
# Eddie Tanner's per 40 stats unavailable. Skipping player!
# Adding Frank Tanner's per 40 stats.
# Adding Herb Tanner's per 40 stats.
# Adding J.B. Tanner's per 40 stats.
# John Tanner's per 40 stats unavailable. Skipping player!
# Adding K.C. Tanner's per 40 stats.
# Mark Tanner's per 40 stats unavailable. Skipping player!
# Mark Tanner's per 40 stats unavailable. Skipping player!
# Sam Tanner's per 40 stats unavailable. Skipping player!
# Jim Tanney's per 40 stats unavailable. Skipping player!
# _ Tansey's per 40 stats unavailable. Skipping player!
# John Tansill's per 40 stats unavailable. Skipping player!
# Adding Justin Tanton's per 40 stats.
# Hans Tanzler's per 40 stats unavailable. Skipping player!
# Adding Ryan Tapak's per 40 stats.
# Adding Lohnnie Tape's per 40 stats.
# Adding Patrick Tape's per 40 stats.
# Lou Tapella's per 40 stats unavailable. Skipping player!
# Adding Justin Taphorn's per 40 stats.
# Matt Taphorn's per 40 stats unavailable. Skipping player!
# Adding Nathan Taphorn's per 40 stats.
# Pat Taphorn's per 40 stats unavailable. Skipping player!
# Adding Chase Tapley's per 40 stats.
# Tommy Tapley's per 40 stats unavailable. Skipping player!
# Adding Dominique Taplin's per 40 stats.
# Adding Sterling Taplin's per 40 stats.
# Billy Tapp's per 40 stats unavailable. Skipping player!
# Rodney Tapp's per 40 stats unavailable. Skipping player!
# Scott Tapp's per 40 stats unavailable. Skipping player!
# Adding Tanner Tapp's per 40 stats.
# Ted Tappe's per 40 stats unavailable. Skipping player!
# Adding Chehales Tapscott's per 40 stats.
# Adding Kader Tapsoba's per 40 stats.
# Adding Idris Taqqee's per 40 stats.
# Mike Tarabanovic's per 40 stats unavailable. Skipping player!
# Adding Nick Tarbat's per 40 stats.
# Kenneth Tarbell's per 40 stats unavailable. Skipping player!
# Adding Greg Tarca's per 40 stats.
# Adding Kevin Tarca's per 40 stats.
# Adding Kaleb Tarczewski's per 40 stats.
# Steve Tarczy's per 40 stats unavailable. Skipping player!
# Jerry Tardie's per 40 stats unavailable. Skipping player!
# Jim Tardivo's per 40 stats unavailable. Skipping player!
# Adding Michael Tardy's per 40 stats.
# Danny Tarkanian's per 40 stats unavailable. Skipping player!
# Adding Anthony Tarke's per 40 stats.
# Adding Nendah Tarke's per 40 stats.
# Adding Niksa Tarle's per 40 stats.
# Tommy Tarlton's per 40 stats unavailable. Skipping player!
# Ed Tarpey's per 40 stats unavailable. Skipping player!
# Adding Terry Tarpey's per 40 stats.
# _ Tarpey's per 40 stats unavailable. Skipping player!
# Roy Tarpley's per 40 stats unavailable. Skipping player!
# Adding Trevor Tarpley's per 40 stats.
# Dan Tarr's per 40 stats unavailable. Skipping player!
# David Tarr's per 40 stats unavailable. Skipping player!
# Donald Tarr's per 40 stats unavailable. Skipping player!
# Adding Jeff Tarr's per 40 stats.
# Rich Tarr's per 40 stats unavailable. Skipping player!
# Larry Tarrance's per 40 stats unavailable. Skipping player!
# Adding Marcus Tarrance's per 40 stats.
# Adding Brian Tarrant's per 40 stats.
# Adding Corey Tarrant's per 40 stats.
# Dave Tarrant's per 40 stats unavailable. Skipping player!
# Gordon Tarrant's per 40 stats unavailable. Skipping player!
# Rich Tarrant's per 40 stats unavailable. Skipping player!
# Adding Ricky Tarrant's per 40 stats.
# _ Tarrant's per 40 stats unavailable. Skipping player!
# _ Tarrant's per 40 stats unavailable. Skipping player!
# Lowell Tarrants's per 40 stats unavailable. Skipping player!
# Frank Tarrantts's per 40 stats unavailable. Skipping player!
# Randy Tarrier's per 40 stats unavailable. Skipping player!
# Fitzhugh Tarry's per 40 stats unavailable. Skipping player!
# Mike Tarry's per 40 stats unavailable. Skipping player!
# Levern Tart's per 40 stats unavailable. Skipping player!
# Pat Tart's per 40 stats unavailable. Skipping player!
# Adding Ra'Shawn Tart's per 40 stats.
# Frank Tartaron's per 40 stats unavailable. Skipping player!
# Adding Derrek Tartt's per 40 stats.
# Adding Andre Tarver's per 40 stats.
# Andre Tarver's per 40 stats unavailable. Skipping player!
# Adding Darren Tarver's per 40 stats.
# Adding Derrick Tarver's per 40 stats.
# Adding Josh Tarver's per 40 stats.
# Adding Mack Tarver's per 40 stats.
# Adding Miles Tarver's per 40 stats.
# Adding Seth Tarver's per 40 stats.
# Adding Shon Tarver's per 40 stats.
# Adding Theodis Tarver's per 40 stats.
# Tom Tarver's per 40 stats unavailable. Skipping player!
# Adding Victor Tarver's per 40 stats.
# Lorenza Tarvin's per 40 stats unavailable. Skipping player!
# Adding Dwight Tarwater's per 40 stats.
# Adding Danan Tasby's per 40 stats.
# Carl Taseff's per 40 stats unavailable. Skipping player!
# _ Taseff's per 40 stats unavailable. Skipping player!
# Adding Kris Tasker's per 40 stats.
# Adding Matthias Tass's per 40 stats.
# _ Tassi's per 40 stats unavailable. Skipping player!
# Jerry Tassielli's per 40 stats unavailable. Skipping player!
# Adding Solomon Tat's per 40 stats.
# Adding Nic Tata's per 40 stats.
# Adding Vytas Tatarunas's per 40 stats.
# Adding Aaron Tate's per 40 stats.
# Al Tate's per 40 stats unavailable. Skipping player!
# Adding Allen Tate's per 40 stats.
# Andre Tate's per 40 stats unavailable. Skipping player!
# Adding Andrew Tate's per 40 stats.
# Adding Anthony Tate's per 40 stats.
# Adding Antwon Tate's per 40 stats.
# Adding Arthur Tate's per 40 stats.
# Bob Tate's per 40 stats unavailable. Skipping player!
# Cal Tate's per 40 stats unavailable. Skipping player!
# Adding Clay Tate's per 40 stats.
# Adding Corey Tate's per 40 stats.
# Adding Cyrus Tate's per 40 stats.
# Adding Daman Tate's per 40 stats.
# Adding Dana Tate's per 40 stats.
# Adding Daniell Tate's per 40 stats.
# Adding De'Aires Tate's per 40 stats.
# Dick Tate's per 40 stats unavailable. Skipping player!
# Doug Tate's per 40 stats unavailable. Skipping player!
# Ed Tate's per 40 stats unavailable. Skipping player!
# Adding Isaiah Tate's per 40 stats.
# Adding Jae'Sean Tate's per 40 stats.
# Adding Jalen Tate's per 40 stats.
# Adding Jamaal Tate's per 40 stats.
# Adding Jaylon Tate's per 40 stats.
# Adding Jeremiah Tate's per 40 stats.
# Adding Jermaine Tate's per 40 stats.
# Jimmy Tate's per 40 stats unavailable. Skipping player!
# Adding Joey Tate's per 40 stats.
# John Tate's per 40 stats unavailable. Skipping player!
# John Tate's per 40 stats unavailable. Skipping player!
# Adding Julian Tate's per 40 stats.
# Adding Keith Tate's per 40 stats.
# Adding Keleaf Tate's per 40 stats.
# Kim Tate's per 40 stats unavailable. Skipping player!
# Adding LaTrell Tate's per 40 stats.
# Adding Michael Tate's per 40 stats.
# Michael Tate's per 40 stats unavailable. Skipping player!
# Adding Micheal Tate's per 40 stats.
# Mike Tate's per 40 stats unavailable. Skipping player!
# Mike Tate's per 40 stats unavailable. Skipping player!
# Adding Myles Tate's per 40 stats.
# Adding Myles Tate's per 40 stats.
# Adding Niles Tate's per 40 stats.
# Adding Reggie Tate's per 40 stats.
# Rich Tate's per 40 stats unavailable. Skipping player!
# Robert Tate's per 40 stats unavailable. Skipping player!
# Ron Tate's per 40 stats unavailable. Skipping player!
# Roosevelt Tate's per 40 stats unavailable. Skipping player!
# Steve Tate's per 40 stats unavailable. Skipping player!
# Adding Tahj Tate's per 40 stats.
# Terry Tate's per 40 stats unavailable. Skipping player!
# Tom Tate's per 40 stats unavailable. Skipping player!
# Adding Tony Tate's per 40 stats.
# Tony Tate's per 40 stats unavailable. Skipping player!
# Adding Trey Tate's per 40 stats.
# Tyrone Tate's per 40 stats unavailable. Skipping player!
# Wilbur Tate's per 40 stats unavailable. Skipping player!
# Wilbur Tate's per 40 stats unavailable. Skipping player!
# John Tates's per 40 stats unavailable. Skipping player!
# Kirk Tatge's per 40 stats unavailable. Skipping player!
# Ward Tatge's per 40 stats unavailable. Skipping player!
# Carl Tatham's per 40 stats unavailable. Skipping player!
# Adding Patrick Tatham's per 40 stats.
# Bill Tatlock's per 40 stats unavailable. Skipping player!
# Adding Wil Tattersall's per 40 stats.
# Brad Tatum's per 40 stats unavailable. Skipping player!
# Adding Bryson Tatum's per 40 stats.
# Adding Cameron Tatum's per 40 stats.
# Adding Charles Tatum's per 40 stats.
# Chris Tatum's per 40 stats unavailable. Skipping player!
# Adding Chron Tatum's per 40 stats.
# Adding Deonte Tatum's per 40 stats.
# Adding Donte Tatum's per 40 stats.
# Drew Tatum's per 40 stats unavailable. Skipping player!
# Earl Tatum's per 40 stats unavailable. Skipping player!
# Edd Tatum's per 40 stats unavailable. Skipping player!
# Adding Edwin Tatum's per 40 stats.
# Adding George Tatum's per 40 stats.
# Adding Hunter Tatum's per 40 stats.
# Adding Jamaal Tatum's per 40 stats.
# Adding Jayson Tatum's per 40 stats.
# Adding Jevon Tatum's per 40 stats.
# Adding John Tatum's per 40 stats.
# John Tatum's per 40 stats unavailable. Skipping player!
# Adding Justin Tatum's per 40 stats.
# Kevin Tatum's per 40 stats unavailable. Skipping player!
# Adding Landon Tatum's per 40 stats.
# Robert Tatum's per 40 stats unavailable. Skipping player!
# Ryle Tatum's per 40 stats unavailable. Skipping player!
# Willie Tatum's per 40 stats unavailable. Skipping player!
# Adding Bayonne Taty's per 40 stats.
# Adding J.J. Tauai's per 40 stats.
# Sam Taub's per 40 stats unavailable. Skipping player!
# _ Taub's per 40 stats unavailable. Skipping player!
# Adding John Taubeneck's per 40 stats.
# Reiny Tauck's per 40 stats unavailable. Skipping player!
# Adding Bryan Taueg's per 40 stats.
# Virgil Taueg's per 40 stats unavailable. Skipping player!
# Adding Sebastian Taulbee's per 40 stats.
# Adding Soo Soo Taulelei's per 40 stats.
# Bill Tauscher's per 40 stats unavailable. Skipping player!
# Adding Luke Tauscher's per 40 stats.
# Brad Tausheck's per 40 stats unavailable. Skipping player!
# Adding Connar Tava's per 40 stats.
# Adding Artem Tavakalyan's per 40 stats.
# Bob Tavanese's per 40 stats unavailable. Skipping player!
# Adding Will Tavares's per 40 stats.
# Jose Tavarez's per 40 stats unavailable. Skipping player!
# Jose Taverez's per 40 stats unavailable. Skipping player!
# Adding Jonathan Tavernari's per 40 stats.
# Adding Jace Tavita's per 40 stats.
# Adding Mario Taybron's per 40 stats.
# Adding A.J. Taylor's per 40 stats.
# Adding Aaron Taylor's per 40 stats.
# Adding Adrian Taylor's per 40 stats.
# Alan Taylor's per 40 stats unavailable. Skipping player!
# Adding Alex Taylor's per 40 stats.
# Adding Allen Taylor's per 40 stats.
# Adding Alray Taylor's per 40 stats.
# Adding Alvin Taylor's per 40 stats.
# Adding Andrew Taylor's per 40 stats.
# Adding Andrew Taylor's per 40 stats.
# Andy Taylor's per 40 stats unavailable. Skipping player!
# Adding Anis Taylor's per 40 stats.
# Anthony Taylor's per 40 stats unavailable. Skipping player!
# Adding Anthony Taylor's per 40 stats.
# Adding Anthony Taylor's per 40 stats.
# Adding Antony Taylor's per 40 stats.
# Adding Armani Taylor's per 40 stats.
# Art Taylor's per 40 stats unavailable. Skipping player!
# Adding Artie Taylor's per 40 stats.
# Adding Atiba Taylor's per 40 stats.
# Adding B.J. Taylor's per 40 stats.
# Babe Taylor's per 40 stats unavailable. Skipping player!
# Adding Bakari Taylor's per 40 stats.
# Barlow Taylor's per 40 stats unavailable. Skipping player!
# Barry Taylor's per 40 stats unavailable. Skipping player!
# Adding Barry Taylor's per 40 stats.
# Barry Taylor's per 40 stats unavailable. Skipping player!
# Benjy Taylor's per 40 stats unavailable. Skipping player!
# Bill Taylor's per 40 stats unavailable. Skipping player!
# Bill Taylor's per 40 stats unavailable. Skipping player!
# Bill Taylor's per 40 stats unavailable. Skipping player!
# Bill Taylor's per 40 stats unavailable. Skipping player!
# Bill Taylor's per 40 stats unavailable. Skipping player!
# Bill Taylor's per 40 stats unavailable. Skipping player!
# Bill Taylor's per 40 stats unavailable. Skipping player!
# Bill Taylor's per 40 stats unavailable. Skipping player!
# Adding Billy Taylor's per 40 stats.
# Adding Billy Taylor's per 40 stats.
# Billy Taylor's per 40 stats unavailable. Skipping player!
# Billy Taylor's per 40 stats unavailable. Skipping player!
# Blaine Taylor's per 40 stats unavailable. Skipping player!
# Blake Taylor's per 40 stats unavailable. Skipping player!
# Adding Bo Taylor's per 40 stats.
# Bob Taylor's per 40 stats unavailable. Skipping player!
# Bob Taylor's per 40 stats unavailable. Skipping player!
# Bob Taylor's per 40 stats unavailable. Skipping player!
# Bobby Taylor's per 40 stats unavailable. Skipping player!
# Bobby Taylor's per 40 stats unavailable. Skipping player!
# Adding Brandon Taylor's per 40 stats.
# Adding Brandon Taylor's per 40 stats.
# Brandon Taylor's per 40 stats unavailable. Skipping player!
# Adding Brendyn Taylor's per 40 stats.
# Brian Taylor's per 40 stats unavailable. Skipping player!
# Adding Brian Taylor's per 40 stats.
# Adding Brian Taylor's per 40 stats.
# Brian Taylor's per 40 stats unavailable. Skipping player!
# Adding Brian Taylor's per 40 stats.
# Adding Brooks Taylor's per 40 stats.
# Adding Brooks Taylor's per 40 stats.
# Bruce Taylor's per 40 stats unavailable. Skipping player!
# Adding Bryan Taylor's per 40 stats.
# Adding Bryan Taylor's per 40 stats.
# Adding Bryan Taylor's per 40 stats.
# Bryan Taylor's per 40 stats unavailable. Skipping player!
# Adding Bryce Taylor's per 40 stats.
# Butch Taylor's per 40 stats unavailable. Skipping player!
# Adding Byron Taylor's per 40 stats.
# Byron Taylor's per 40 stats unavailable. Skipping player!
# Cal Taylor's per 40 stats unavailable. Skipping player!
# Adding Camerron Taylor's per 40 stats.
# Cardell Taylor's per 40 stats unavailable. Skipping player!
# Adding Carlos Taylor's per 40 stats.
# Adding Carlos Taylor's per 40 stats.
# Carlos Taylor's per 40 stats unavailable. Skipping player!
# Adding Cataurius Taylor's per 40 stats.
# Adding Charles Taylor's per 40 stats.
# Adding Charlie Taylor's per 40 stats.
# Adding Cheo Taylor's per 40 stats.
# Adding Chris Taylor's per 40 stats.
# Adding Christopher Taylor's per 40 stats.
# Chuck Taylor's per 40 stats unavailable. Skipping player!
# Chuck Taylor's per 40 stats unavailable. Skipping player!
# Clarence Taylor's per 40 stats unavailable. Skipping player!
# Adding Clarence Taylor's per 40 stats.
# Adding Clarence Taylor's per 40 stats.
# Claude Sleepy Taylor's per 40 stats unavailable. Skipping player!
# Cooper Taylor's per 40 stats unavailable. Skipping player!
# Adding Corey Taylor's per 40 stats.
# Corey Taylor's per 40 stats unavailable. Skipping player!
# Corky Taylor's per 40 stats unavailable. Skipping player!
# Adding Cornelius Taylor's per 40 stats.
# Adding Coupe Taylor's per 40 stats.
# Adding Craig Taylor's per 40 stats.
# Craig Taylor's per 40 stats unavailable. Skipping player!
# Craig Taylor's per 40 stats unavailable. Skipping player!
# Craig Taylor's per 40 stats unavailable. Skipping player!
# Curtis Taylor's per 40 stats unavailable. Skipping player!
# Adding D'Shon Taylor's per 40 stats.
# Adding Dacari Taylor's per 40 stats.
# Adding Dairein Taylor's per 40 stats.
# Adding Dale Taylor's per 40 stats.
# Adding Damontae Taylor's per 40 stats.
# Adding Dante Taylor's per 40 stats.
# Adding Darius Taylor's per 40 stats.
# Adding Darnell Taylor's per 40 stats.
# Adding David Taylor's per 40 stats.
# Adding David Taylor's per 40 stats.
# David Taylor's per 40 stats unavailable. Skipping player!
# David Taylor's per 40 stats unavailable. Skipping player!
# David Taylor's per 40 stats unavailable. Skipping player!
# David Taylor's per 40 stats unavailable. Skipping player!
# David Taylor's per 40 stats unavailable. Skipping player!
# David Taylor's per 40 stats unavailable. Skipping player!
# Adding Dedric Taylor's per 40 stats.
# Adding Deion Taylor's per 40 stats.
# Adding Delonte Taylor's per 40 stats.
# Delonte Taylor's per 40 stats unavailable. Skipping player!
# Dennis Taylor's per 40 stats unavailable. Skipping player!
# Adding Denzell Taylor's per 40 stats.
# Derek Taylor's per 40 stats unavailable. Skipping player!
# Adding Derrell Taylor's per 40 stats.
# Adding Derrick Taylor's per 40 stats.
# Derrick Taylor's per 40 stats unavailable. Skipping player!
# Adding Deshon Taylor's per 40 stats.
# Adding Deveric Taylor's per 40 stats.
# Adding Diamond Taylor's per 40 stats.
# Dick Taylor's per 40 stats unavailable. Skipping player!
# Dick Taylor's per 40 stats unavailable. Skipping player!
# Dick Taylor's per 40 stats unavailable. Skipping player!
# Adding Doc Taylor's per 40 stats.
# Adding Doc Taylor's per 40 stats.
# Dominic Taylor's per 40 stats unavailable. Skipping player!
# Adding Dominique Taylor's per 40 stats.
# Don Taylor's per 40 stats unavailable. Skipping player!
# Don Taylor's per 40 stats unavailable. Skipping player!
# Don Taylor's per 40 stats unavailable. Skipping player!
# Adding Donald Taylor's per 40 stats.
# Adding Donell Taylor's per 40 stats.
# Adding Donnie Taylor's per 40 stats.
# Adding Dontrell Taylor's per 40 stats.
# Adding Doug Taylor's per 40 stats.
# Adding Duane Taylor's per 40 stats.
# Adding DuJuan Taylor's per 40 stats.
# Dwayne Taylor's per 40 stats unavailable. Skipping player!
# Dwight Taylor's per 40 stats unavailable. Skipping player!
# Ed Taylor's per 40 stats unavailable. Skipping player!
# Eddie Taylor's per 40 stats unavailable. Skipping player!
# Adding Emmitt Taylor's per 40 stats.
# Adding Eric Taylor's per 40 stats.
# Adding Eric Taylor's per 40 stats.
# Eric Taylor's per 40 stats unavailable. Skipping player!
# Adding Evan Taylor's per 40 stats.
# Adding Evan Taylor's per 40 stats.
# Everett Taylor's per 40 stats unavailable. Skipping player!
# Fred Taylor's per 40 stats unavailable. Skipping player!
# Fred Taylor's per 40 stats unavailable. Skipping player!
# Adding Gabe Taylor's per 40 stats.
# Garry Taylor's per 40 stats unavailable. Skipping player!
# Geary Taylor's per 40 stats unavailable. Skipping player!
# George Taylor's per 40 stats unavailable. Skipping player!
# George Taylor's per 40 stats unavailable. Skipping player!
# Adding Gordon Taylor's per 40 stats.
# Gordon Taylor's per 40 stats unavailable. Skipping player!
# Graham Taylor's per 40 stats unavailable. Skipping player!
# Grant Taylor's per 40 stats unavailable. Skipping player!
# Adding Greg Taylor's per 40 stats.
# Adding Greg Taylor's per 40 stats.
# Greg Taylor's per 40 stats unavailable. Skipping player!
# Greg Taylor's per 40 stats unavailable. Skipping player!
# Greg Taylor's per 40 stats unavailable. Skipping player!
# Harvey Taylor's per 40 stats unavailable. Skipping player!
# Henry Taylor's per 40 stats unavailable. Skipping player!
# Adding Henry Taylor's per 40 stats.
# Herb Taylor's per 40 stats unavailable. Skipping player!
# Homer Taylor's per 40 stats unavailable. Skipping player!
# Horace Taylor's per 40 stats unavailable. Skipping player!
# Howard Taylor's per 40 stats unavailable. Skipping player!
# Adding Hyman Taylor's per 40 stats.
# Adding Isaac Taylor's per 40 stats.
# Adding Isaiah Taylor's per 40 stats.
# Adding Isaiah Taylor's per 40 stats.
# J.D. Taylor's per 40 stats unavailable. Skipping player!
# Adding Jachai Taylor's per 40 stats.
# Adding Jacquil Taylor's per 40 stats.
# Adding Jahmel Taylor's per 40 stats.
# Adding Jamar Taylor's per 40 stats.
# Adding Jamar Taylor's per 40 stats.
# James Taylor's per 40 stats unavailable. Skipping player!
# Adding Jaron Taylor's per 40 stats.
# Adding Jason Taylor's per 40 stats.
# Adding Jason Taylor's per 40 stats.
# Jay Taylor's per 40 stats unavailable. Skipping player!
# Jeff Taylor's per 40 stats unavailable. Skipping player!
# Adding Jeff Taylor's per 40 stats.
# Adding Jeff Taylor's per 40 stats.
# Jeff Taylor's per 40 stats unavailable. Skipping player!
# Adding Jeffery Taylor's per 40 stats.
# Jeffery Taylor's per 40 stats unavailable. Skipping player!
# Adding Jeremiah Taylor's per 40 stats.
# Adding Jermaine Taylor's per 40 stats.
# Jerry Taylor's per 40 stats unavailable. Skipping player!
# Jerry Taylor's per 40 stats unavailable. Skipping player!
# Jerry Taylor's per 40 stats unavailable. Skipping player!
# Adding Jessie Taylor's per 40 stats.
# Jim Taylor's per 40 stats unavailable. Skipping player!
# Jim Taylor's per 40 stats unavailable. Skipping player!
# Adding Jimmie Taylor's per 40 stats.
# Adding Jimmie Taylor's per 40 stats.
# Jimmy Taylor's per 40 stats unavailable. Skipping player!
# Adding Joe Taylor's per 40 stats.
# Adding Joe Taylor's per 40 stats.
# Joe Taylor's per 40 stats unavailable. Skipping player!
# Adding Joey Taylor's per 40 stats.
# Adding John Taylor's per 40 stats.
# Adding John Taylor's per 40 stats.
# Adding John Taylor's per 40 stats.
# John Taylor's per 40 stats unavailable. Skipping player!
# John Taylor's per 40 stats unavailable. Skipping player!
# John Taylor's per 40 stats unavailable. Skipping player!
# Adding Johnny Taylor's per 40 stats.
# Johnny Taylor's per 40 stats unavailable. Skipping player!
# Johnny Taylor's per 40 stats unavailable. Skipping player!
# Johnny Taylor's per 40 stats unavailable. Skipping player!
# Johnny Taylor's per 40 stats unavailable. Skipping player!
# Adding Jon Taylor's per 40 stats.
# Jon Taylor's per 40 stats unavailable. Skipping player!
# Adding Jonathan Taylor's per 40 stats.
# Adding Jordan Taylor's per 40 stats.
# Adding Joseph Taylor's per 40 stats.
# Adding Josh Taylor's per 40 stats.
# Adding Josh Taylor's per 40 stats.
# Adding Justin Taylor's per 40 stats.
# Adding Justin Taylor's per 40 stats.
# Adding Kaleim Taylor's per 40 stats.
# Adding Kammron Taylor's per 40 stats.
# Keith Taylor's per 40 stats unavailable. Skipping player!
# Adding Kellii Taylor's per 40 stats.
# Adding Kellon Taylor's per 40 stats.
# Ken Taylor's per 40 stats unavailable. Skipping player!
# Adding Kenneth Taylor's per 40 stats.
# Adding Kenneth Taylor's per 40 stats.
# Adding Kenny Taylor's per 40 stats.
# Kent Taylor's per 40 stats unavailable. Skipping player!
# Kent Taylor's per 40 stats unavailable. Skipping player!
# Adding Kevin Taylor's per 40 stats.
# Adding Kevin Taylor's per 40 stats.
# Adding Khristian Taylor's per 40 stats.
# Kirk Taylor's per 40 stats unavailable. Skipping player!
# Kitrick Taylor's per 40 stats unavailable. Skipping player!
# Adding Kurt Taylor's per 40 stats.
# Adding Kwane Taylor's per 40 stats.
# Adding Kyle Taylor's per 40 stats.
# Kyle Taylor's per 40 stats unavailable. Skipping player!
# Adding Lamar Taylor's per 40 stats.
# Lance Taylor's per 40 stats unavailable. Skipping player!
# Lango Taylor's per 40 stats unavailable. Skipping player!
# Lanny Taylor's per 40 stats unavailable. Skipping player!
# Adding Larry Taylor's per 40 stats.
# Larry Taylor's per 40 stats unavailable. Skipping player!
# Adding LeKeith Taylor's per 40 stats.
# Leonard Taylor's per 40 stats unavailable. Skipping player!
# Adding Leonard Taylor's per 40 stats.
# Leory Taylor's per 40 stats unavailable. Skipping player!
# Les Taylor's per 40 stats unavailable. Skipping player!
# Adding Lorenzo Taylor's per 40 stats.
# Lou Taylor's per 40 stats unavailable. Skipping player!
# Lucky Taylor's per 40 stats unavailable. Skipping player!
# Adding Lunden Taylor's per 40 stats.
# Mack Taylor's per 40 stats unavailable. Skipping player!
# Malcolm Taylor's per 40 stats unavailable. Skipping player!
# Adding Marcus Taylor's per 40 stats.
# Mark Taylor's per 40 stats unavailable. Skipping player!
# Adding Marlon Taylor's per 40 stats.
# Adding Marlon Taylor's per 40 stats.
# Adding Marshall Taylor's per 40 stats.
# Marshall Taylor's per 40 stats unavailable. Skipping player!
# Marvin Taylor's per 40 stats unavailable. Skipping player!
# Adding Mason Taylor's per 40 stats.
# Adding Matt Taylor's per 40 stats.
# Adding Matt Taylor's per 40 stats.
# Matt Taylor's per 40 stats unavailable. Skipping player!
# Adding Maurice Taylor's per 40 stats.
# Adding Maurice Taylor's per 40 stats.
# Adding Maurice Taylor's per 40 stats.
# Melvin Taylor's per 40 stats unavailable. Skipping player!
# Adding Mensah Taylor's per 40 stats.
# Adding Michael Taylor's per 40 stats.
# Adding Michael Taylor's per 40 stats.
# Michael Taylor's per 40 stats unavailable. Skipping player!
# Michael Taylor's per 40 stats unavailable. Skipping player!
# Adding Michael Taylor's per 40 stats.
# Mike Taylor's per 40 stats unavailable. Skipping player!
# Mike Taylor's per 40 stats unavailable. Skipping player!
# Mike Taylor's per 40 stats unavailable. Skipping player!
# Mike Taylor's per 40 stats unavailable. Skipping player!
# Adding Mike Taylor's per 40 stats.
# Adding Mike Taylor's per 40 stats.
# Mike Taylor's per 40 stats unavailable. Skipping player!
# Mike Taylor's per 40 stats unavailable. Skipping player!
# Adding Miles Taylor's per 40 stats.
# Adding Mitch Taylor's per 40 stats.
# Mitch Taylor's per 40 stats unavailable. Skipping player!
# Morgan Taylor's per 40 stats unavailable. Skipping player!
# Adding Morgan Taylor's per 40 stats.
# Moses Taylor's per 40 stats unavailable. Skipping player!
# Adding Myles Taylor's per 40 stats.
# Adding Najia Taylor's per 40 stats.
# Adding Nate Taylor's per 40 stats.
# Adding Nick Taylor's per 40 stats.
# Nick Taylor's per 40 stats unavailable. Skipping player!
# Adding Nils Taylor's per 40 stats.
# Noel Taylor's per 40 stats unavailable. Skipping player!
# Noel Taylor's per 40 stats unavailable. Skipping player!
# Adding Nolan Taylor's per 40 stats.
# Adding O'Barcus Taylor's per 40 stats.
# Oliver Taylor's per 40 stats unavailable. Skipping player!
# Ollie Taylor's per 40 stats unavailable. Skipping player!
# Oscar Taylor's per 40 stats unavailable. Skipping player!
# Oscar Taylor's per 40 stats unavailable. Skipping player!
# Adding Otto Taylor's per 40 stats.
# Adding P.J. Taylor's per 40 stats.
# Adding Paris Taylor's per 40 stats.
# Parke Taylor's per 40 stats unavailable. Skipping player!
# Adding Paul Taylor's per 40 stats.
# Adding Peyton Taylor's per 40 stats.
# Adding Phil Taylor 's per 40 stats.
# Phil Taylor's per 40 stats unavailable. Skipping player!
# Phil Taylor's per 40 stats unavailable. Skipping player!
# Phil Taylor's per 40 stats unavailable. Skipping player!
# Adding Phillip Taylor's per 40 stats.
# Adding Phyllip Taylor's per 40 stats.
# Q.C. Taylor's per 40 stats unavailable. Skipping player!
# Adding Quentin Taylor's per 40 stats.
# Adding Quincy Taylor's per 40 stats.
# Adding Quinn Taylor's per 40 stats.
# Adding Quinn Taylor's per 40 stats.
# Ralph Taylor's per 40 stats unavailable. Skipping player!
# Adding Ramell Taylor's per 40 stats.
# Adding Ramone Taylor's per 40 stats.
# Randolph Taylor's per 40 stats unavailable. Skipping player!
# Adding Rashad Taylor's per 40 stats.
# Adding Raymond Taylor's per 40 stats.
# Adding Reggie Taylor's per 40 stats.
# Rhea Taylor's per 40 stats unavailable. Skipping player!
# Rhea Taylor's per 40 stats unavailable. Skipping player!
# Adding Rich Taylor's per 40 stats.
# Rich Taylor's per 40 stats unavailable. Skipping player!
# Adding Richard Taylor's per 40 stats.
# Richard Taylor's per 40 stats unavailable. Skipping player!
# Richie Taylor's per 40 stats unavailable. Skipping player!
# Rick Taylor's per 40 stats unavailable. Skipping player!
# Rick Taylor's per 40 stats unavailable. Skipping player!
# Adding Ricky Taylor's per 40 stats.
# Adding Robert Taylor's per 40 stats.
# Robert Taylor's per 40 stats unavailable. Skipping player!
# Adding Robert Taylor's per 40 stats.
# Adding Robert Taylor's per 40 stats.
# Adding Rod Taylor's per 40 stats.
# Adding Roderick Taylor's per 40 stats.
# Adding Roderick Taylor's per 40 stats.
# Rodney Taylor's per 40 stats unavailable. Skipping player!
# Rodnie Taylor's per 40 stats unavailable. Skipping player!
# Roger Taylor's per 40 stats unavailable. Skipping player!
# Roger Taylor's per 40 stats unavailable. Skipping player!
# Rogers Taylor's per 40 stats unavailable. Skipping player!
# Rollie Fatty Taylor's per 40 stats unavailable. Skipping player!
# Ron Taylor's per 40 stats unavailable. Skipping player!
# Ron Taylor's per 40 stats unavailable. Skipping player!
# Ron Taylor's per 40 stats unavailable. Skipping player!
# Ron Taylor's per 40 stats unavailable. Skipping player!
# Ron Taylor's per 40 stats unavailable. Skipping player!
# Ron Taylor's per 40 stats unavailable. Skipping player!
# Adding Ronell Taylor's per 40 stats.
# Adding Ronnie Taylor's per 40 stats.
# Roy Taylor's per 40 stats unavailable. Skipping player!
# Roy Taylor's per 40 stats unavailable. Skipping player!
# Russell Taylor's per 40 stats unavailable. Skipping player!
# Adding Ryan Taylor's per 40 stats.
# Adding Ryan Taylor's per 40 stats.
# Sammy Taylor's per 40 stats unavailable. Skipping player!
# Sandy Taylor's per 40 stats unavailable. Skipping player!
# Adding Scooter Taylor's per 40 stats.
# Adding Scott Taylor's per 40 stats.
# Adding Scott Taylor's per 40 stats.
# Adding Scott Taylor's per 40 stats.
# Scott Taylor's per 40 stats unavailable. Skipping player!
# Adding Seth Taylor's per 40 stats.
# Adding Shannon Taylor's per 40 stats.
# Adding Shawn Taylor's per 40 stats.
# Skip Taylor's per 40 stats unavailable. Skipping player!
# Adding Steve Taylor's per 40 stats.
# Adding Steve Taylor's per 40 stats.
# Steve Taylor's per 40 stats unavailable. Skipping player!
# Steve Taylor's per 40 stats unavailable. Skipping player!
# Adding Stevie Taylor's per 40 stats.
# Adding Syniker Taylor's per 40 stats.
# Adding T.J. Taylor's per 40 stats.
# Adding T.J. Taylor's per 40 stats.
# Adding Tanner Taylor's per 40 stats.
# Adding Tayloe Taylor's per 40 stats.
# Ted Taylor's per 40 stats unavailable. Skipping player!
# Adding Terrell Taylor's per 40 stats.
# Adding Terry Taylor's per 40 stats.
# Adding Terry Taylor's per 40 stats.
# Terry Taylor's per 40 stats unavailable. Skipping player!
# Terry Taylor's per 40 stats unavailable. Skipping player!
# Adding Terry Taylor's per 40 stats.
# Tex Taylor's per 40 stats unavailable. Skipping player!
# Adding Therin Taylor's per 40 stats.
# Adding TJ Taylor's per 40 stats.
# Todd Taylor's per 40 stats unavailable. Skipping player!
# Adding Tom Taylor's per 40 stats.
# Tom Taylor's per 40 stats unavailable. Skipping player!
# Tommy Taylor's per 40 stats unavailable. Skipping player!
# Tommy Taylor's per 40 stats unavailable. Skipping player!
# Adding Tony Taylor's per 40 stats.
# Tony Taylor's per 40 stats unavailable. Skipping player!
# Tracy Taylor's per 40 stats unavailable. Skipping player!
# Adding Travis Taylor's per 40 stats.
# Adding Trevon Taylor's per 40 stats.
# Adding Troy Taylor's per 40 stats.
# Adding Troy Taylor's per 40 stats.
# Troy Taylor's per 40 stats unavailable. Skipping player!
# Troy Taylor's per 40 stats unavailable. Skipping player!
# Troy Taylor's per 40 stats unavailable. Skipping player!
# Adding Tuqwan Taylor's per 40 stats.
# Adding Ty Taylor's per 40 stats.
# Adding Tyler Taylor's per 40 stats.
# Adding Tyrell Taylor's per 40 stats.
# Adding Tyshawn Taylor's per 40 stats.
# Vaughn Taylor's per 40 stats unavailable. Skipping player!
# Adding Vernon Taylor's per 40 stats.
# Vince Taylor's per 40 stats unavailable. Skipping player!
# Adding Vince Taylor's per 40 stats.
# Vince Taylor's per 40 stats unavailable. Skipping player!
# Walter Pete Taylor's per 40 stats unavailable. Skipping player!
# Wayne Taylor's per 40 stats unavailable. Skipping player!
# Wendell Taylor's per 40 stats unavailable. Skipping player!
# Adding Wesley Taylor's per 40 stats.
# Adding Will Taylor's per 40 stats.
# Adding Willie Taylor's per 40 stats.
# Willie Taylor's per 40 stats unavailable. Skipping player!
# Willie Taylor's per 40 stats unavailable. Skipping player!
# Willie Taylor's per 40 stats unavailable. Skipping player!
# Wilson Taylor's per 40 stats unavailable. Skipping player!
# Adding Xzavier Taylor's per 40 stats.
# Adding Zac Taylor's per 40 stats.
# Adding Zaire Taylor's per 40 stats.
# _ Taylor's per 40 stats unavailable. Skipping player!
# _ Taylor's per 40 stats unavailable. Skipping player!
# _ Taylor's per 40 stats unavailable. Skipping player!
# _ Taylor's per 40 stats unavailable. Skipping player!
# Dave Taynor's per 40 stats unavailable. Skipping player!
# Adding Jonathan Tchamwa Tchatchoua's per 40 stats.
# Adding James Tchana's per 40 stats.
# Adding Rony Tchatchoua's per 40 stats.
# Adding Philippe Tchekane Bofia's per 40 stats.
# Adding Russel Tchewa's per 40 stats.
# Adding Steve Tchiengang's per 40 stats.
# Adding William Tchiengang's per 40 stats.
# Adding Matt Tchir's per 40 stats.
# Adding Denzel Tchougang's per 40 stats.
# Adding Blondeau Tchoukuiengo's per 40 stats.
# Adding Frank Tchuisi's per 40 stats.
# _ Teach's per 40 stats unavailable. Skipping player!
# Anthony Teachey's per 40 stats unavailable. Skipping player!
# Terry Teachout's per 40 stats unavailable. Skipping player!
# Adding Shane Teagarden's per 40 stats.
# Terry Teagle's per 40 stats unavailable. Skipping player!
# Adding Adam Teague's per 40 stats.
# Adding Anthony Teague's per 40 stats.
# Adding Antoine Teague's per 40 stats.
# Barry Teague's per 40 stats unavailable. Skipping player!
# Adding Cameron Teague's per 40 stats.
# Dan Teague's per 40 stats unavailable. Skipping player!
# Adding David Teague's per 40 stats.
# David Teague's per 40 stats unavailable. Skipping player!
# Don Teague's per 40 stats unavailable. Skipping player!
# Adding Gene Teague's per 40 stats.
# James Teague's per 40 stats unavailable. Skipping player!
# Adding Jeff Teague's per 40 stats.
# John Teague's per 40 stats unavailable. Skipping player!
# Adding MaCio Teague's per 40 stats.
# Adding Marquis Teague's per 40 stats.
# Maurice Teague's per 40 stats unavailable. Skipping player!
# Rod Teague's per 40 stats unavailable. Skipping player!
# Shawn Teague's per 40 stats unavailable. Skipping player!
# Adding Tahjai Teague's per 40 stats.
# Terry Teague's per 40 stats unavailable. Skipping player!
# Adding Patrick Teagues's per 40 stats.
# Adding Chris Teahan's per 40 stats.
# Adding Conner Teahan's per 40 stats.
# Matt Teahan's per 40 stats unavailable. Skipping player!
# Adding Markee Teal's per 40 stats.
# Martin Teal's per 40 stats unavailable. Skipping player!
# Dennis Tealer's per 40 stats unavailable. Skipping player!
# Adding Radford Team's per 40 stats.
# Ron Teamer's per 40 stats unavailable. Skipping player!
# Russ Tearney's per 40 stats unavailable. Skipping player!
# Adding Kai Tease's per 40 stats.
# Adding Carvell Teasett's per 40 stats.
# Tim Teasley's per 40 stats unavailable. Skipping player!
# _ Teasley's per 40 stats unavailable. Skipping player!
# Adding Darrell Teat's per 40 stats.
# Bryan Teater's per 40 stats unavailable. Skipping player!
# _ Tebbe's per 40 stats unavailable. Skipping player!
# Neil Tebbenkamp's per 40 stats unavailable. Skipping player!
# Jack Tebbs's per 40 stats unavailable. Skipping player!
# Jeff Tebbs's per 40 stats unavailable. Skipping player!
# Adding Justyn Tebbs's per 40 stats.
# Adding Quynn Tebbs's per 40 stats.
# Terry Tebbs's per 40 stats unavailable. Skipping player!
# Terry Tebbs's per 40 stats unavailable. Skipping player!
# Tom Tebbs's per 40 stats unavailable. Skipping player!
# Joe Tebo's per 40 stats unavailable. Skipping player!
# Bob TeCarr's per 40 stats unavailable. Skipping player!
# Adding Mike Technow's per 40 stats.
# Adding Steve Tecker's per 40 stats.
# Adding Joseph Tecklenburg's per 40 stats.
# Paul Tedder's per 40 stats unavailable. Skipping player!
# Adding Mike Tedesco's per 40 stats.
# Ralph Tedesco's per 40 stats unavailable. Skipping player!
# Bob Tedesky's per 40 stats unavailable. Skipping player!
# _ Tedesky's per 40 stats unavailable. Skipping player!
# Mike Tee's per 40 stats unavailable. Skipping player!
# Ron Tee's per 40 stats unavailable. Skipping player!
# Adding Ayan Teel's per 40 stats.
# John Teel's per 40 stats unavailable. Skipping player!
# Adding Vernon Teel's per 40 stats.
# Bob Teeler's per 40 stats unavailable. Skipping player!
# Tim Teer's per 40 stats unavailable. Skipping player!
# Adding Blaine Teeter's per 40 stats.
# Adding Brett Teeter's per 40 stats.
# Curtis Teeter's per 40 stats unavailable. Skipping player!
# Dale Teeter's per 40 stats unavailable. Skipping player!
# Adding Jason Teeter's per 40 stats.
# Marc Teets's per 40 stats unavailable. Skipping player!
# Adding Ryan Teets's per 40 stats.
# Kenne Teffeteller's per 40 stats unavailable. Skipping player!
# Thad Tegtmeyer's per 40 stats unavailable. Skipping player!
# Alvaro Teheran's per 40 stats unavailable. Skipping player!
# Herb Teicher's per 40 stats unavailable. Skipping player!
# Adding Guilherme Teichmann's per 40 stats.
# Adding Tanel Tein's per 40 stats.
# Mark Teismann's per 40 stats unavailable. Skipping player!
# Ron Teixeira's per 40 stats unavailable. Skipping player!
# Adding Lance Tejada's per 40 stats.
# Adding Dave Telander's per 40 stats.
# Bill Telasky's per 40 stats unavailable. Skipping player!
# _ Telasky's per 40 stats unavailable. Skipping player!
# Adding Brad Teleccia's per 40 stats.
# John Telepo's per 40 stats unavailable. Skipping player!
# Richard Teleski's per 40 stats unavailable. Skipping player!
# Adding Albert Telfair's per 40 stats.
# Adding Ethan Telfair's per 40 stats.
# Adding Mario Telfair's per 40 stats.
# Adding Westley Telfare's per 40 stats.
# Dave Telfer's per 40 stats unavailable. Skipping player!
# Adding Jason Telford's per 40 stats.
# Joe Telford's per 40 stats unavailable. Skipping player!
# Adding Jahmyl Telfort's per 40 stats.
# Arch Telis's per 40 stats unavailable. Skipping player!
# Mark Tellechea's per 40 stats unavailable. Skipping player!
# Gerry Tellefsen's per 40 stats unavailable. Skipping player!
# Adding Michael Teller's per 40 stats.
# Adding Blas Telleria's per 40 stats.
# Robert Telles's per 40 stats unavailable. Skipping player!
# Robert Telles's per 40 stats unavailable. Skipping player!
# Terry Telligman's per 40 stats unavailable. Skipping player!
# Adding Reed Tellinghuisen's per 40 stats.
# Adding Cory Tellis's per 40 stats.
# Adding Saliou-Binet Telly's per 40 stats.
# Sylvester Temaat's per 40 stats unavailable. Skipping player!
# Tom Temaat's per 40 stats unavailable. Skipping player!
# Adding Shane Temara's per 40 stats.
# Adding Troy Temara's per 40 stats.
# Adding Nick Temen's per 40 stats.
# Adding Rory Temkin's per 40 stats.
# Adding Chris Temming's per 40 stats.
# Adding Jack Tempchin's per 40 stats.
# Adding Kevin Tempest's per 40 stats.
# Adding Brandon Temple's per 40 stats.
# Adding Calvin Temple's per 40 stats.
# Adding Collis Temple's per 40 stats.
# Collis Temple's per 40 stats unavailable. Skipping player!
# Adding Garrett Temple's per 40 stats.
# Gerald Temple's per 40 stats unavailable. Skipping player!
# Adding Joe Temple's per 40 stats.
# Adding John Temple's per 40 stats.
# Mark Temple's per 40 stats unavailable. Skipping player!
# Adding Matthew Temple's per 40 stats.
# Vernon Temple's per 40 stats unavailable. Skipping player!
# Adding Joel Templeman's per 40 stats.
# Adding Adam Templeton's per 40 stats.
# Peden Templeton's per 40 stats unavailable. Skipping player!
# Tom Ten Broeck's per 40 stats unavailable. Skipping player!
# Adding J.P. Tenata's per 40 stats.
# Adding Marcel Tenberge's per 40 stats.
# Greg Tencza's per 40 stats unavailable. Skipping player!
# Adding Matt Tendam's per 40 stats.
# Marty Tendler's per 40 stats unavailable. Skipping player!
# Adding John Tenerowicz's per 40 stats.
# Mark Tenhoeve's per 40 stats unavailable. Skipping player!
# Greg Tennant's per 40 stats unavailable. Skipping player!
# Adding Dexter Tennell's per 40 stats.
# Adding Sam Tennessee's per 40 stats.
# Adding Iiro Tenngren's per 40 stats.
# Adding Drew Tennial's per 40 stats.
# Eric Tennille's per 40 stats unavailable. Skipping player!
# Mike Tennison's per 40 stats unavailable. Skipping player!
# Adding Trey Tennyson's per 40 stats.
# James Tention's per 40 stats unavailable. Skipping player!
# Rodney Tention's per 40 stats unavailable. Skipping player!
# Dave Tenwick's per 40 stats unavailable. Skipping player!
# Tom Tenwick's per 40 stats unavailable. Skipping player!
# Adding Alvydas Tenys's per 40 stats.
# Ron Tenzyk's per 40 stats unavailable. Skipping player!
# Terry Teobbs's per 40 stats unavailable. Skipping player!
# Dale Tepas's per 40 stats unavailable. Skipping player!
# Dennis Tepe's per 40 stats unavailable. Skipping player!
# Ed Tepe's per 40 stats unavailable. Skipping player!
# _ Teravainen's per 40 stats unavailable. Skipping player!
# Adding Gerrit Terdenge's per 40 stats.
# Dave Terek's per 40 stats unavailable. Skipping player!
# Dave Terek's per 40 stats unavailable. Skipping player!
# Dick Terlingen's per 40 stats unavailable. Skipping player!
# Adding Matt Terpening's per 40 stats.
# Adding Daniel Terpin's per 40 stats.
# ...
# Gene Zane's per 40 stats unavailable. Skipping player!
# Stewart Zane's per 40 stats unavailable. Skipping player!
# Stewart Zane's per 40 stats unavailable. Skipping player!
# Adding Matt Zaney's per 40 stats.
# Eugene Zang's per 40 stats unavailable. Skipping player!
# Adding Michael Zangari's per 40 stats.
# Adding George Zaninovich's per 40 stats.
# George Zaninovich's per 40 stats unavailable. Skipping player!
# Adding Nura Zanna's per 40 stats.
# Adding Talib Zanna's per 40 stats.
# Rudy Zannini's per 40 stats unavailable. Skipping player!
# Craig Zanon's per 40 stats unavailable. Skipping player!
# Rick Zanon's per 40 stats unavailable. Skipping player!
# Scott Zanon's per 40 stats unavailable. Skipping player!
# Pete van Zant's per 40 stats unavailable. Skipping player!
# John Zanzalari's per 40 stats unavailable. Skipping player!
# Tony Zanze's per 40 stats unavailable. Skipping player!
# Adding Szymon Zapala's per 40 stats.
# Adding Tommy Zapata's per 40 stats.
# Bill Zapp's per 40 stats unavailable. Skipping player!
# Ermine Zappa's per 40 stats unavailable. Skipping player!
# Ron Zappia's per 40 stats unavailable. Skipping player!
# _ Zaptor's per 40 stats unavailable. Skipping player!
# Gil Zaragoza's per 40 stats unavailable. Skipping player!
# Adding Zack Zaragoza's per 40 stats.
# Joe Zaranka's per 40 stats unavailable. Skipping player!
# John Zaraoza's per 40 stats unavailable. Skipping player!
# Morris Zarchen's per 40 stats unavailable. Skipping player!
# Stan Zardozny's per 40 stats unavailable. Skipping player!
# Adding Andrew Zarechnak's per 40 stats.
# Adding Nemanja Zarkovic's per 40 stats.
# Bob Zarr's per 40 stats unavailable. Skipping player!
# Max Zaslofsky's per 40 stats unavailable. Skipping player!
# Adding Eric Zastoupil's per 40 stats.
# Ed Zastrow's per 40 stats unavailable. Skipping player!
# Adding Nate Zastrow's per 40 stats.
# Butch Zatezalo's per 40 stats unavailable. Skipping player!
# Rudy Zatezalo's per 40 stats unavailable. Skipping player!
# Jeff Zatkoff's per 40 stats unavailable. Skipping player!
# Johnny Zatopek's per 40 stats unavailable. Skipping player!
# John Zatorski's per 40 stats unavailable. Skipping player!
# Ed Zausch's per 40 stats unavailable. Skipping player!
# Ed Zausch's per 40 stats unavailable. Skipping player!
# Adding Donatas Zavackas's per 40 stats.
# Jeff Zavada's per 40 stats unavailable. Skipping player!
# Adding Jeff Zavada's per 40 stats.
# Adding Javier Zavala's per 40 stats.
# Bob Zavorskas's per 40 stats unavailable. Skipping player!
# Tom Zavorskas's per 40 stats unavailable. Skipping player!
# Ron Zawacki's per 40 stats unavailable. Skipping player!
# Ted Zawacki's per 40 stats unavailable. Skipping player!
# Ray Zawadzki's per 40 stats unavailable. Skipping player!
# Joe Zawawacki's per 40 stats unavailable. Skipping player!
# Bob Zawoluk's per 40 stats unavailable. Skipping player!
# Adding Steve Zazuri's per 40 stats.
# Frank Zazzaro's per 40 stats unavailable. Skipping player!
# John Zazzaro's per 40 stats unavailable. Skipping player!
# Bill Zban's per 40 stats unavailable. Skipping player!
# Adding Dima Zdor's per 40 stats.
# Larry Zebrack's per 40 stats unavailable. Skipping player!
# Adding Aleksandar Zecevic's per 40 stats.
# Adding Stefan Zecevic's per 40 stats.
# Gene Zech's per 40 stats unavailable. Skipping player!
# Adding Patrick Zeck's per 40 stats.
# Adding Marcus Zegarowski's per 40 stats.
# Adding Tyler Zegarzewski's per 40 stats.
# Adding Joe Zeglinski's per 40 stats.
# Adding Sammy Zeglinski's per 40 stats.
# Adding Zack Zeglinski's per 40 stats.
# Adding Andrew Zehnder's per 40 stats.
# Todd Zehner's per 40 stats unavailable. Skipping player!
# John Zeides's per 40 stats unavailable. Skipping player!
# _ Zeiff's per 40 stats unavailable. Skipping player!
# Dick Zeiger's per 40 stats unavailable. Skipping player!
# Adding Bo Zeigler's per 40 stats.
# Dave Zeigler's per 40 stats unavailable. Skipping player!
# Adding Davin Zeigler's per 40 stats.
# Adding Demitrius Zeigler's per 40 stats.
# Adding Derrick Zeigler's per 40 stats.
# Ernie Zeigler's per 40 stats unavailable. Skipping player!
# Gordon Zeigler's per 40 stats unavailable. Skipping player!
# Adding Kenny Zeigler's per 40 stats.
# Adding Levelle Zeigler's per 40 stats.
# Marcus Zeigler's per 40 stats unavailable. Skipping player!
# Mitchell Zeigler's per 40 stats unavailable. Skipping player!
# Adding Omar Zeigler's per 40 stats.
# Adding Trey Zeigler's per 40 stats.
# Adding Nic Zeil's per 40 stats.
# Don Zeiler's per 40 stats unavailable. Skipping player!
# Adding Nick Zeisloft's per 40 stats.
# Dick Zeitler's per 40 stats unavailable. Skipping player!
# Bill Zeits's per 40 stats unavailable. Skipping player!
# Adding Branimir Zeko's per 40 stats.
# Ray Zelek's per 40 stats unavailable. Skipping player!
# Ted Zelek's per 40 stats unavailable. Skipping player!
# Adding Andrej Zelenbaba's per 40 stats.
# Adding Jovan Zelenbaba's per 40 stats.
# Norm Zelenko's per 40 stats unavailable. Skipping player!
# Frank Zelesnik's per 40 stats unavailable. Skipping player!
# Dick Zelickson's per 40 stats unavailable. Skipping player!
# Jack Zelinger's per 40 stats unavailable. Skipping player!
# _ Zelinski's per 40 stats unavailable. Skipping player!
# Adding Andrew Zelis's per 40 stats.
# Adding Maros Zeliznak's per 40 stats.
# Adding Cody Zeller's per 40 stats.
# Dave Zeller's per 40 stats unavailable. Skipping player!
# Gary Zeller's per 40 stats unavailable. Skipping player!
# Adding Luke Zeller's per 40 stats.
# Marty Zeller's per 40 stats unavailable. Skipping player!
# Adding Tyler Zeller's per 40 stats.
# Ed Zello's per 40 stats unavailable. Skipping player!
# Adding Damian Zellous's per 40 stats.
# Joseph Zemba's per 40 stats unavailable. Skipping player!
# Steve Zemba's per 40 stats unavailable. Skipping player!
# Dick Zembal's per 40 stats unavailable. Skipping player!
# John Zembron's per 40 stats unavailable. Skipping player!
# Adding Deividas Zemgulis's per 40 stats.
# Adding Deivis Zemgulis's per 40 stats.
# Bob Zender's per 40 stats unavailable. Skipping player!
# Ben Zenevich's per 40 stats unavailable. Skipping player!
# Adding Martin Zeno's per 40 stats.
# Adding Michael Zeno's per 40 stats.
# Michael Zeno's per 40 stats unavailable. Skipping player!
# Tony Zeno's per 40 stats unavailable. Skipping player!
# Adding Guy Zenou's per 40 stats.
# Adding Mike Zepeda's per 40 stats.
# Adding Keil Zepernick's per 40 stats.
# Adding Timothy Zephyr's per 40 stats.
# Bill Zepplin's per 40 stats unavailable. Skipping player!
# Adding Neven Zeravica's per 40 stats.
# Adding Chris Zerbe's per 40 stats.
# Paul Zeringue's per 40 stats unavailable. Skipping player!
# Jeff Zern's per 40 stats unavailable. Skipping player!
# Michael Zernich's per 40 stats unavailable. Skipping player!
# Bill Zersen's per 40 stats unavailable. Skipping player!
# _ Zerwas's per 40 stats unavailable. Skipping player!
# Adding Peter Zestermann's per 40 stats.
# _ Zetz's per 40 stats unavailable. Skipping player!
# Al Zetzsche's per 40 stats unavailable. Skipping player!
# Phil Zevenbergen's per 40 stats unavailable. Skipping player!
# Adding Thomas Zevgaras's per 40 stats.
# Adding Kevin Zhang's per 40 stats.
# Adding Max Zhang's per 40 stats.
# Adding Alex Zhao's per 40 stats.
# Adding Andrew Zidar's per 40 stats.
# Adding George Zidek's per 40 stats.
# Adding Jan Zidek's per 40 stats.
# Adding Malte Ziegenhagen's per 40 stats.
# Jerry Ziegenhorn's per 40 stats unavailable. Skipping player!
# Bob Ziegler's per 40 stats unavailable. Skipping player!
# Don Ziegler's per 40 stats unavailable. Skipping player!
# Don Ziegler's per 40 stats unavailable. Skipping player!
# Fritz Ziegler's per 40 stats unavailable. Skipping player!
# Adding Karl Ziegler's per 40 stats.
# Lonnie Ziegler's per 40 stats unavailable. Skipping player!
# M Ziegler's per 40 stats unavailable. Skipping player!
# Rick Ziegler's per 40 stats unavailable. Skipping player!
# Ron Ziegler's per 40 stats unavailable. Skipping player!
# Todd Ziegler's per 40 stats unavailable. Skipping player!
# Adding Travis Ziegler's per 40 stats.
# Adding Matt Zielenbach's per 40 stats.
# Frank Zielinski's per 40 stats unavailable. Skipping player!
# Jerry Zielinski's per 40 stats unavailable. Skipping player!
# Adding Maciej Zielinski's per 40 stats.
# Russ Ziemba's per 40 stats unavailable. Skipping player!
# Adding Steve Ziemian's per 40 stats.
# Chris Zier's per 40 stats unavailable. Skipping player!
# Adding Isaiah Zierden's per 40 stats.
# Larry Zigerelli's per 40 stats unavailable. Skipping player!
# Adding Matt Zignorski's per 40 stats.
# Tim Ziko's per 40 stats unavailable. Skipping player!
# Chris Zikos's per 40 stats unavailable. Skipping player!
# Adding Giacomo Zilli's per 40 stats.
# Jim Zilli's per 40 stats unavailable. Skipping player!
# Greg Zilverberg's per 40 stats unavailable. Skipping player!
# Stanley Zima's per 40 stats unavailable. Skipping player!
# Adding Andrew Zimbro's per 40 stats.
# Ken Zimko's per 40 stats unavailable. Skipping player!
# Bill Zimmer's per 40 stats unavailable. Skipping player!
# Adding Jason Zimmer's per 40 stats.
# Adding Adam Zimmerman's per 40 stats.
# Arnie Zimmerman's per 40 stats unavailable. Skipping player!
# Ben Zimmerman's per 40 stats unavailable. Skipping player!
# Adding Chris Zimmerman's per 40 stats.
# Dave Zimmerman's per 40 stats unavailable. Skipping player!
# Adding Derrick Zimmerman's per 40 stats.
# Dick Zimmerman's per 40 stats unavailable. Skipping player!
# Don Zimmerman's per 40 stats unavailable. Skipping player!
# Fred Zimmerman's per 40 stats unavailable. Skipping player!
# Adding Gerald Zimmerman's per 40 stats.
# Jack Zimmerman's per 40 stats unavailable. Skipping player!
# Jack Zimmerman's per 40 stats unavailable. Skipping player!
# Adding James Zimmerman's per 40 stats.
# Adding Jason Zimmerman's per 40 stats.
# Jim Zimmerman's per 40 stats unavailable. Skipping player!
# Joe Zimmerman's per 40 stats unavailable. Skipping player!
# Pete Zimmerman's per 40 stats unavailable. Skipping player!
# Adding Rodney Zimmerman's per 40 stats.
# Adding Scott Zimmerman's per 40 stats.
# Adding Stephen Zimmerman's per 40 stats.
# Adding Thurman Zimmerman's per 40 stats.
# Todd Zimmerman's per 40 stats unavailable. Skipping player!
# Todd Zimmerman's per 40 stats unavailable. Skipping player!
# Adding Andrew Zimmermann's per 40 stats.
# Frank Zimmovan's per 40 stats unavailable. Skipping player!
# Adding Alex Zimnickas's per 40 stats.
# Adding Greg Zimny's per 40 stats.
# Scott Zimos's per 40 stats unavailable. Skipping player!
# Ted Zimowicz's per 40 stats unavailable. Skipping player!
# David Zingg's per 40 stats unavailable. Skipping player!
# John Zinirich's per 40 stats unavailable. Skipping player!
# Dave Zink's per 40 stats unavailable. Skipping player!
# Adding Nevin Zink's per 40 stats.
# Gary Zinkgraf's per 40 stats unavailable. Skipping player!
# Chuck Zinky's per 40 stats unavailable. Skipping player!
# Jim Zinn's per 40 stats unavailable. Skipping player!
# Rob Zinn's per 40 stats unavailable. Skipping player!
# Adding Terry Zinn's per 40 stats.
# Walt Zinn's per 40 stats unavailable. Skipping player!
# Paul Zinser's per 40 stats unavailable. Skipping player!
# Bill Zinsky's per 40 stats unavailable. Skipping player!
# Jim Zinsky's per 40 stats unavailable. Skipping player!
# Mark Ziolko's per 40 stats unavailable. Skipping player!
# John Zipp's per 40 stats unavailable. Skipping player!
# Marty Zippel's per 40 stats unavailable. Skipping player!
# _ Zippel's per 40 stats unavailable. Skipping player!
# Adding Jon Ziri's per 40 stats.
# Morton Zisk's per 40 stats unavailable. Skipping player!
# Adding Alexander Ziskunov's per 40 stats.
# Adding Matt Zitani's per 40 stats.
# Fred Zitar's per 40 stats unavailable. Skipping player!
# Lou Ziter's per 40 stats unavailable. Skipping player!
# Bill Zito's per 40 stats unavailable. Skipping player!
# Adding John Zito's per 40 stats.
# Adding Ales Zivanovic's per 40 stats.
# Adding Lazar Zivanovic's per 40 stats.
# Adding Milos Zivanovic's per 40 stats.
# Adding Mitar Zivanovic's per 40 stats.
# Adding Luka Zivkovic's per 40 stats.
# Chris Zivney's per 40 stats unavailable. Skipping player!
# Adding Tyler Zivney's per 40 stats.
# Lubo Zizakovic's per 40 stats unavailable. Skipping player!
# Adding Nikola Zizic's per 40 stats.
# Jay Ziznewski's per 40 stats unavailable. Skipping player!
# Steve Zlko's per 40 stats unavailable. Skipping player!
# Adding Drazen Zlovaric's per 40 stats.
# Adding Aaron Zobrist's per 40 stats.
# John Zoccali's per 40 stats unavailable. Skipping player!
# Adding Alex Zock's per 40 stats.
# Roger Zoeller's per 40 stats unavailable. Skipping player!
# Adding Kirsten Zoellner's per 40 stats.
# Jim Zoet's per 40 stats unavailable. Skipping player!
# Adding Mark Zoller's per 40 stats.
# Adding Klaas Zollner's per 40 stats.
# Adding Vinny Zollo's per 40 stats.
# Charles Zolot's per 40 stats unavailable. Skipping player!
# Chick Zomlefer's per 40 stats unavailable. Skipping player!
# Adding Matt Zona's per 40 stats.
# Mike Zona's per 40 stats unavailable. Skipping player!
# Adding Kenrick Zondervan's per 40 stats.
# Adding Sean Zone's per 40 stats.
# Bill Zopf's per 40 stats unavailable. Skipping player!
# Adding Noah Zoppi's per 40 stats.
# Adding Paul Zorad's per 40 stats.
# Bob Zoretich's per 40 stats unavailable. Skipping player!
# Adding Danijel Zoric's per 40 stats.
# Adding Kristers Zoriks's per 40 stats.
# Bill Zorn's per 40 stats unavailable. Skipping player!
# Adding Tyler Zornes's per 40 stats.
# Dave Zornow's per 40 stats unavailable. Skipping player!
# Paul Zorsky's per 40 stats unavailable. Skipping player!
# Adding Ezra Zoschke's per 40 stats.
# Adding Brian Zoubek's per 40 stats.
# Adding Nisre Zouzoua's per 40 stats.
# Adrian Zuber's per 40 stats unavailable. Skipping player!
# Dallas Zuber's per 40 stats unavailable. Skipping player!
# _ Zuber's per 40 stats unavailable. Skipping player!
# Adding Aitor Zubizarreta's per 40 stats.
# Mark Zubor's per 40 stats unavailable. Skipping player!
# _ Zucco's per 40 stats unavailable. Skipping player!
# Henry Zuchowski's per 40 stats unavailable. Skipping player!
# Ed Zucker's per 40 stats unavailable. Skipping player!
# Herbert Zuckerman's per 40 stats unavailable. Skipping player!
# Adding Maros Zuffa's per 40 stats.
# Adding Cale Zuiker's per 40 stats.
# Adding Jake Zuilhof's per 40 stats.
# Adding Vladimir Zujovic's per 40 stats.
# Adding Jay Zulauf's per 40 stats.
# Adding Jon Zulauf's per 40 stats.
# Dick Zulch's per 40 stats unavailable. Skipping player!
# Gordie Zullges's per 40 stats unavailable. Skipping player!
# Jimmy Zullo's per 40 stats unavailable. Skipping player!
# Adding Arthur Zulu's per 40 stats.
# Don Zumbro's per 40 stats unavailable. Skipping player!
# George Zumbro's per 40 stats unavailable. Skipping player!
# Chip Zumer's per 40 stats unavailable. Skipping player!
# Adding Neal Zumwalt's per 40 stats.
# Adding Kyle Zunic's per 40 stats.
# Carlos Zuniga's per 40 stats unavailable. Skipping player!
# Dave Zupan's per 40 stats unavailable. Skipping player!
# Adding Zeljko Zupic's per 40 stats.
# Adding Johnny Zuppardo's per 40 stats.
# Joe Zuravleff's per 40 stats unavailable. Skipping player!
# Phil Zuravleff's per 40 stats unavailable. Skipping player!
# Philip Zuravleff's per 40 stats unavailable. Skipping player!
# Adding Chris Zurcher's per 40 stats.
# Kim Zurcher's per 40 stats unavailable. Skipping player!
# Adding Drew Zurek's per 40 stats.
# George Zurenda's per 40 stats unavailable. Skipping player!
# Adding Stephen Zurich's per 40 stats.
# Adding Darren Zusack's per 40 stats.
# Adding Xabi Zusperreguy's per 40 stats.
# Adding Stanislav Zuzak's per 40 stats.
# Al Zvinakis's per 40 stats unavailable. Skipping player!
# Al Zvoda's per 40 stats unavailable. Skipping player!
# Adding Brian Zvonecek's per 40 stats.
# John Zwakman's per 40 stats unavailable. Skipping player!
# Mark Zwart's per 40 stats unavailable. Skipping player!
# Adding Clint Zwayer's per 40 stats.
# Adding Eric Zwayer's per 40 stats.
# Walter Zwick's per 40 stats unavailable. Skipping player!
# Adding Serge Zwikker's per 40 stats.
# Joe Zych's per 40 stats unavailable. Skipping player!
# Lou Zykiewicz's per 40 stats unavailable. Skipping player!
# Jack Zyla's per 40 stats unavailable. Skipping player!
# Adding Michal Zylinski's per 40 stats.
# Adding Brock Zylstra's per 40 stats.
# Gene Zyzda's per 40 stats unavailable. Skipping player!

# %%
table.to_csv('TtoZ.csv',index=False)
