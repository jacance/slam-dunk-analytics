# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize
import string
import html5lib

# %%
lottery_range = list(np.arange(1990,2021))

# %%
year = []
team_abb = []
player = []
college = []

for i in lottery_range:
    url = f"https://www.basketball-reference.com/draft/NBA_{i}.html"
    response = requests.get(url)
    soup = bs(response.text, 'html.parser')
    left = soup.find_all('td', class_='left')
    for j in range(0, len(left), 3):
        team_abb.append(left[j].text)
        player.append(left[j+1].text)
        college.append(left[j+2].text)
        year.append(i)

# %%
draft_df = pd.DataFrame({'year':year,'team_abb':team_abb,'player':player,'college':college})
draft_df
# Out:
#       year team_abb              player                college
# 0     1990      NJN     Derrick Coleman               Syracuse
# 1     1990      SEA         Gary Payton           Oregon State
# 2     1990      DEN  Mahmoud Abdul-Rauf                    LSU
# 3     1990      ORL        Dennis Scott           Georgia Tech
# 4     1990      CHH        Kendall Gill               Illinois
# ...    ...      ...                 ...                    ...
# 1803  2020      CHO        Grant Riller  College of Charleston
# 1804  2020      LAC        Reggie Perry      Mississippi State
# 1805  2020      PHI           Paul Reed                 DePaul
# 1806  2020      TOR        Jalen Harris                 Nevada
# 1807  2020      NOP         Sam Merrill  Utah State University
#
# [1808 rows x 4 columns]

# %%
draft_df.to_csv('1990_2020drafts.csv',index=False)
