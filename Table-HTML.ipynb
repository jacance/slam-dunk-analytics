# %%
import pandas as pd

# %%
draft2017 = 'csv/draft_predactual2017.csv'
draft2018 = 'csv/draft_predactual2018.csv'
draft2019 = 'csv/draft_predactual2019.csv'
career = 'csv/career.csv'

# %%
df2017 = pd.read_csv(draft2017)
df2018 = pd.read_csv(draft2018)
df2019 = pd.read_csv(draft2019)
career_df = pd.read_csv(career)

# %%
df2017 = df2017.rename(columns = {"round": "Round" ,"pick": "Pick" ,"predicted_player": "Predicted Player", "actual_player": "Actual Player", "residual": "Delta"})
df2017_cleaned = df2017.set_index("Round")

# %%
df2018 = df2018.rename(columns = {"round": "Round" ,"pick": "Pick" ,"predicted_player": "Predicted Player", "actual_player": "Actual Player", "residual": "Delta"})
df2018_cleaned = df2018.set_index("Round")
df2018_cleaned
# Out:
#        Pick         Predicted Player            Actual Player  Delta
# Round
# 1         1  Shai Gilgeous-Alexander            Deandre Ayton   10.0
# 1         2               Kevin Knox        Marvin Bagley III    7.0
# 1         3            Jaren Jackson              Luka Dončić    NaN
# 1         4            Davion Turner        Jaren Jackson Jr.    NaN
# 1         5            Mohamed Bamba               Trae Young    NaN
# 1         6           Justin Tillman                 Mo Bamba    NaN
# 1         7              Ben Lammers       Wendell Carter Jr.    NaN
# 1         8            Deandre Ayton            Collin Sexton   -7.0
# 1         9               Trae Young               Kevin Knox   -4.0
# 1        10               Gary Trent            Mikal Bridges    NaN
# 1        11            Collin Sexton  Shai Gilgeous-Alexander   -3.0
# 1        12               Jalin Hart            Miles Bridges    NaN
# ...

# %%
df2019 = df2019.rename(columns = {"round": "Round" ,"pick": "Pick" ,"predicted_player": "Predicted Player", "actual_player": "Actual Player", "residual": "Delta"})
df2019_cleaned = df2019.set_index("Round")
df2019_cleaned
# Out:
#        Pick          Predicted Player             Actual Player  Delta
# Round
# 1         1           Zion Williamson           Zion Williamson    0.0
# 1         2          Ignas Brazdeikis                 Ja Morant   45.0
# 1         3           De'Andre Hunter                RJ Barrett    1.0
# 1         4            Darius Garland           De'Andre Hunter    1.0
# 1         5                Coby White            Darius Garland    2.0
# 1         6                 Nick Ward            Jarrett Culver    NaN
# 1         7               Cam Reddish                Coby White    3.0
# 1         8             Jaquan Dotson              Jaxson Hayes    NaN
# 1         9            Lew Stallworth             Rui Hachimura    NaN
# 1        10              Jaxson Hayes               Cam Reddish   -2.0
# 1        11                 Mike Daum           Cameron Johnson    NaN
# 1        12                Nick Emery           P.J. Washington    NaN
# ...

# %%
# non_us_players = []


# for x in range(len(df2017_cleaned)):
#     if df2017_cleaned['Predicted Player'][x] not in list(career_df['player']):
#         name = df2017_cleaned['Predicted Player'][x]
#         non_us_players.append(name)
#         print(name)
#     else:
#         pass

# %%
draft = pd.read_csv("csv/draft.csv")

# %%
df2017_cleaned.reset_index(inplace=True)
df2018_cleaned.reset_index(inplace=True)
df2019_cleaned.reset_index(inplace=True)

# %%
nonus2017 = list(draft['player'].loc[(draft['year'] == 2017) & (draft['college'] == 'No US College')])
nonus2018 = list(draft['player'].loc[(draft['year'] == 2018) & (draft['college'] == 'No US College')])
nonus2019 = list(draft['player'].loc[(draft['year'] == 2019) & (draft['college'] == 'No US College')])

# %%
nonus2018
# Out:
# ['Luka Dončić',
#  'Anfernee Simons',
#  'Džanan Musa',
#  'Elie Okobo',
#  'Mitchell Robinson',
#  'Isaac Bonga',
#  'Rodions Kurucs',
#  'Issuf Sanon',
#  'Arnoldas Kulboka']

# %%
df2017_cleaned = df2017_cleaned.fillna("N/A")
df2018_cleaned = df2018_cleaned.fillna("N/A")
df2019_cleaned = df2019_cleaned.fillna("N/A")

# %%
for x in range(len(df2017_cleaned)):
    if df2017_cleaned['Delta'][x] == "N/A":
        if df2017_cleaned['Actual Player'][x] in nonus2017:
            df2017_cleaned['Delta'][x] = df2017_cleaned['Delta'][x].replace("N/A", "Intl")
        else:
            pass
# Out:
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for x in range(len(df2018_cleaned)):
    if df2018_cleaned['Delta'][x] == "N/A":
        if df2018_cleaned['Actual Player'][x] in nonus2018:
            df2018_cleaned['Delta'][x] = df2018_cleaned['Delta'][x].replace("N/A", "Intl")
        else:
            pass
# Out:
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
for x in range(len(df2017_cleaned)):
    if df2019_cleaned['Delta'][x] == "N/A":
        if df2019_cleaned['Actual Player'][x] in nonus2019:
            df2019_cleaned['Delta'][x] = df2017_cleaned['Delta'][x].replace("N/A", "Intl")
        else:
            pass
# Out:
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
df2017_cleaned = df2017_cleaned.set_index("Round")
df2018_cleaned = df2018_cleaned.set_index("Round")
df2019_cleaned = df2019_cleaned.set_index("Round")

# %%
df2017_cleaned
# Out:
#        Pick        Predicted Player        Actual Player Delta
# Round
# 1         1          Markelle Fultz       Markelle Fultz     0
# 1         2              Malik Monk           Lonzo Ball     9
# 1         3       Jordan Washington         Jayson Tatum   N/A
# 1         4               Eric Mika         Josh Jackson   N/A
# 1         5              Lonzo Ball         De'Aaron Fox    -3
# 1         6            Jayson Tatum       Jonathan Isaac    -3
# 1         7    Demetrius McReynolds      Lauri Markkanen   N/A
# 1         8            De'Aaron Fox      Frank Ntilikina    -3
# 1         9          Jonathan Isaac     Dennis Smith Jr.    -3
# 1        10         Lauri Markkanen         Zach Collins    -3
# 1        11            Josh Jackson           Malik Monk    -7
# 1        12            Zach Collins         Luke Kennard    -2
# 1        13            Luke Kennard     Donovan Mitchell    -1
# 1        14        Donovan Mitchell          Bam Adebayo    -1
# ...

# %%
df2017_cleaned.to_html('2017picks.html')
df2018_cleaned.to_html('2018picks.html')
df2019_cleaned.to_html('2019picks.html')
