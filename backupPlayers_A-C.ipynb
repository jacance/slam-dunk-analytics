# %%
#Imports
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
from unicodedata import normalize
import string
import html5lib

# %%
# #Maybe necessary installation
# pip install html5lib

# %%
#Obtain all player names/links
#Set letter list/empty lists
letters = ['a','b','c','d','e','f']
player_links3 = []
final_players3 = []
final_player_links = []
official_players = []
for i in letters:
    #Setup preliminary lists for specific letter
    all_players = []
    player_links = []
    final_players = []
    #Soup setup for specific letter
    url = f'https://www.sports-reference.com/cbb/players/{i}-index.html'
    response = requests.get(url)
    soup = bs(response.text, 'html.parser')
    href = soup.find_all('a')
    #Get links
    all_links = [x['href'] for x in href]
    #Get players
    for i in href:
        try:
            all_players.append(i.text)
        except:
            all_players.append(i)
    #Filter for just /cbb/players in URL
    for i in range(len(all_links)):
        try:
            if '/cbb/players' in all_links[i]:
                player_links.append(all_links[i])
                final_players.append(all_players[i])
        except:
            pass
    #Get rid of Danny Vranes, Marvin Barnes, Bobby Hurley, James Worthy, Tayshaun Prince duplicates
    player_links3.append(player_links[:len(player_links)-5])
    final_players3.append(final_players[:len(player_links)-5])
#Unlisting
player_links2 = []
final_players2 = []
for x in player_links3:
    for y in x:
        player_links2.append(y)
for x in final_players3:
    for y in x:
        final_players2.append(y)
#Replace /cbb/players, filter for player names/links only
individual_player_links = [x.replace('/cbb/players','') for x in player_links2 if '/cbb/players' in x]
final_player_links = []
official_players = []
for i in range(len(individual_player_links)):
    if ((individual_player_links[i] != '/') & (individual_player_links[i] != '')): 
        final_player_links.append(individual_player_links[i])
        official_players.append(final_players2[i])

# %%
import bs4
#Get columns
#Soup setup w/comments
url2 = f'https://www.sports-reference.com/cbb/players{final_player_links[0]}'
response2 = requests.get(url2)
soup2 = bs(response2.text)
comments = soup2.find_all(text=lambda text:isinstance(text, bs4.Comment))
#Get commented out HTML
per_40_html = []
for i in range(len(comments)):
    if '<table class="row_summable sortable stats_table" id="players_per_min" data-cols-to-freeze=",1">' in str(comments[i]):
        per_40_html.append(comments[i])
    else:
        pass
#Get column names + create empty table
table1 = pd.read_html(per_40_html[0])
table = pd.DataFrame(columns=table1[0].columns)

# %%
player_table_names = []
for i in range(len(final_player_links)):
    #Soup setup w/comments
    per_40_html = []
    url2 = f'https://www.sports-reference.com/cbb/players{final_player_links[i]}'
    response2 = requests.get(url2)
    soup2 = bs(response2.text)
    comments = soup2.find_all(text=lambda text:isinstance(text, bs4.Comment))
    #Get commented out HTML
    for j in comments:
        if '<table class="row_summable sortable stats_table" id="players_per_min" data-cols-to-freeze=",1">' in str(j):
            per_40_html.append(j)
        else:
            pass
    #Filter for the per 40 to even exist
    if len(per_40_html) != 0:
        #Get base table/append if exists
        table0 = pd.read_html(per_40_html[0])
        table00 = table0[0]
        table00['player'] = official_players[i]
        table = table.append(table00)
        #Add player name to list
        player_table_names.append(official_players[i])
        print(f"Adding {official_players[i]}'s per 40 stats.")
    else:
        print(f"{official_players[i]}'s per 40 stats unavailable. Skipping player!")
# Out:
# Adding Menghe a'Nyam's per 40 stats.
# Adding Jordan Aaberg's per 40 stats.
# Adding Karl Aaker's per 40 stats.
# Steve Aaker's per 40 stats unavailable. Skipping player!
# Waine Aalto's per 40 stats unavailable. Skipping player!
# Adding Mike Aaman's per 40 stats.
# Adding Craig Aamot's per 40 stats.
# Art Aaron's per 40 stats unavailable. Skipping player!
# Adding Carlton Aaron's per 40 stats.
# David Aaron's per 40 stats unavailable. Skipping player!
# Adding Jordan Aaron's per 40 stats.
# Adding Kris Aaron's per 40 stats.
# Leslie Aaron's per 40 stats unavailable. Skipping player!
# Michael Aaron's per 40 stats unavailable. Skipping player!
# Adding Nate Aaron's per 40 stats.
# Patrick Aaron's per 40 stats unavailable. Skipping player!
# Adding Shaddean Aaron's per 40 stats.
# Adding Shaqquan Aaron's per 40 stats.
# Adding Troy Aaron's per 40 stats.
# Adding Joe Aase's per 40 stats.
# Pardie Abadee's per 40 stats unavailable. Skipping player!
# Adding Brian Abadie's per 40 stats.
# Adding Ronell Abaekobe's per 40 stats.
# Adding Eli Abaev's per 40 stats.
# Adding Kwesi Abakah's per 40 stats.
# Adding Kevin Abanobi's per 40 stats.
# Adding Jerome Abbage's per 40 stats.
# Ed Abbey's per 40 stats unavailable. Skipping player!
# Jerry Abbey's per 40 stats unavailable. Skipping player!
# Bill Abbott's per 40 stats unavailable. Skipping player!
# Don Abbott's per 40 stats unavailable. Skipping player!
# George Abbott's per 40 stats unavailable. Skipping player!
# Adding Gus Abbott's per 40 stats.
# Hayden Abbott's per 40 stats unavailable. Skipping player!
# Larry Abbott's per 40 stats unavailable. Skipping player!
# Adding Malik Abbott's per 40 stats.
# Adding Matthew Abbott's per 40 stats.
# Adding Ryan Abbott's per 40 stats.
# Tony Abbott's per 40 stats unavailable. Skipping player!
# Adding Ty Abbott's per 40 stats.
# Chris Abboushi's per 40 stats unavailable. Skipping player!
# Adding Huthifah Abdel Jawad's per 40 stats.
# Adding Mostafa Abdel Latif's per 40 stats.
# Adding Ha-Keem Abdel-Khaliq's per 40 stats.
# Alaa Abdelnaby's per 40 stats unavailable. Skipping player!
# Jabbar Abdi's per 40 stats unavailable. Skipping player!
# Adding Salah Abdo's per 40 stats.
# Mohammed Abdrabboh's per 40 stats unavailable. Skipping player!
# Adding Akbar Abdul-Ahad's per 40 stats.
# Adding Muhammad Abdul-Aleem's per 40 stats.
# Adding Musa Abdul-Aleem's per 40 stats.
# Adding Jalil Abdul-Bassit's per 40 stats.
# Adding Mustafa Abdul-Hamid's per 40 stats.
# Kareem Abdul-Jabbar's per 40 stats unavailable. Skipping player!
# Adding Kareem Abdul-Jabbar's per 40 stats.
# Adding Khaleel Abdul-Malik's per 40 stats.
# Adding Khaalis Abdul-Raqeeb's per 40 stats.
# Mahmoud Abdul-Rauf's per 40 stats unavailable. Skipping player!
# Adding Tariq Abdul-Wahad's per 40 stats.
# Adding Kahhar Abdul-Wali's per 40 stats.
# Adding Abdul Abdullah's per 40 stats.
# Adding Ahmad Abdullah's per 40 stats.
# Adding Ali Abdullah's per 40 stats.
# Adding Bilal Abdullah's per 40 stats.
# Adding Halim Abdullah's per 40 stats.
# Adding Hasan Abdullah's per 40 stats.
# Adding Hassan Abdullah's per 40 stats.
# Adding Sulaiman Abdullah's per 40 stats.
# Adding Umar Abdullah's per 40 stats.
# Adding Mohammed Abdulsalam's per 40 stats.
# Adding Jordan Abdur-Ra'oof's per 40 stats.
# Adding Amir Abdur-Rahim's per 40 stats.
# Adding Bilal Abdur-Rahim's per 40 stats.
# Adding Jabri Abdur-Rahim's per 40 stats.
# Adding Muhammad Abdur-Rahim's per 40 stats.
# Adding Shareef Abdur-Rahim's per 40 stats.
# Adding Muhammad-Ali Abdur-Rahkman's per 40 stats.
# Adding Saif Abdur-rahman's per 40 stats.
# Adding Anwar Abdus-Salaam's per 40 stats.
# Adding Toso Abedamowo's per 40 stats.
# Chuck Abedie's per 40 stats unavailable. Skipping player!
# Adding Fletcher Abee's per 40 stats.
# Ron Abegglen's per 40 stats unavailable. Skipping player!
# Dave Abel's per 40 stats unavailable. Skipping player!
# Adding Griffin Abel's per 40 stats.
# Adding Solomon Abel's per 40 stats.
# Dick Abele's per 40 stats unavailable. Skipping player!
# Adding Martins Abele's per 40 stats.
# _ Abele's per 40 stats unavailable. Skipping player!
# Bubba Abell's per 40 stats unavailable. Skipping player!
# Adding Remy Abell's per 40 stats.
# Adding Ray Abellard's per 40 stats.
# Alan Abelman's per 40 stats unavailable. Skipping player!
# Adding Brent Abendroth's per 40 stats.
# Paul Abendroth's per 40 stats unavailable. Skipping player!
# Jason Aber's per 40 stats unavailable. Skipping player!
# Barry Abercrombie's per 40 stats unavailable. Skipping player!
# Ernest Abercrombie's per 40 stats unavailable. Skipping player!
# Adding Ernie Abercrombie's per 40 stats.
# Adding Riley Abercrombie's per 40 stats.
# Adding Shawn Abercrombie's per 40 stats.
# Adding Thomas Abercrombie's per 40 stats.
# Rick Aberegg's per 40 stats unavailable. Skipping player!
# Donald Aberg's per 40 stats unavailable. Skipping player!
# Hank Aberman's per 40 stats unavailable. Skipping player!
# Hugh Aberman's per 40 stats unavailable. Skipping player!
# Adding Anthony Abernathy's per 40 stats.
# Bill Abernathy's per 40 stats unavailable. Skipping player!
# Dugan Abernathy's per 40 stats unavailable. Skipping player!
# Jim Abernathy's per 40 stats unavailable. Skipping player!
# Ron Abernathy's per 40 stats unavailable. Skipping player!
# Adding A Abernethy's per 40 stats.
# Bill Abernethy's per 40 stats unavailable. Skipping player!
# Adding Todd Abernethy's per 40 stats.
# Tom Abernethy's per 40 stats unavailable. Skipping player!
# Keith Abeyta's per 40 stats unavailable. Skipping player!
# Adding Onyekawtuke Abiakam's per 40 stats.
# Adding Kazembe Abif's per 40 stats.
# Adding Micaiah Abii's per 40 stats.
# Adding Otoja Abit's per 40 stats.
# Doug Able's per 40 stats unavailable. Skipping player!
# Forest Able's per 40 stats unavailable. Skipping player!
# Kent Able's per 40 stats unavailable. Skipping player!
# _ Able's per 40 stats unavailable. Skipping player!
# Richard Ableman's per 40 stats unavailable. Skipping player!
# Reuben Ables's per 40 stats unavailable. Skipping player!
# Adding Frank Ableson's per 40 stats.
# Adding Nash Ablo's per 40 stats.
# Italo Ablondi's per 40 stats unavailable. Skipping player!
# Adding Max Abmas's per 40 stats.
# Mike Abner's per 40 stats unavailable. Skipping player!
# Adding Clyde Abney's per 40 stats.
# Adding L.B. Abney's per 40 stats.
# Adding Larry Abney's per 40 stats.
# Adding Lebastian Abney's per 40 stats.
# Phil Abney's per 40 stats unavailable. Skipping player!
# Adding Efe Abogidi's per 40 stats.
# Adding Wandji Aboubakar's per 40 stats.
# Mike Aboud's per 40 stats unavailable. Skipping player!
# Adding Ahmed Aboul-Foutouh's per 40 stats.
# Adding Charles Abouo's per 40 stats.
# Adding Alfred Aboya's per 40 stats.
# Ansley Abraham's per 40 stats unavailable. Skipping player!
# Colon Abraham's per 40 stats unavailable. Skipping player!
# Adding Dennard Abraham's per 40 stats.
# Adding Faisal Abraham's per 40 stats.
# Adding Fred Abraham's per 40 stats.
# Adding Henry Abraham's per 40 stats.
# Adding Karon Abraham's per 40 stats.
# Larry Abraham's per 40 stats unavailable. Skipping player!
# Adding Moses Abraham's per 40 stats.
# Adding Nsilo Abraham's per 40 stats.
# Adding Peter Abraham's per 40 stats.
# Ralph Abraham's per 40 stats unavailable. Skipping player!
# Adding Ryann Abraham's per 40 stats.
# Adding Trevan Abraham's per 40 stats.
# Adding Albert Abrahams's per 40 stats.
# Adding Joe Abrahams's per 40 stats.
# Jerry Abrahamson's per 40 stats unavailable. Skipping player!
# Jim Abrahamson's per 40 stats unavailable. Skipping player!
# Adding Kale Abrahamson's per 40 stats.
# Kent Abrahamson's per 40 stats unavailable. Skipping player!
# Rick Abrahamson's per 40 stats unavailable. Skipping player!
# Tom Abrahamson's per 40 stats unavailable. Skipping player!
# Tom Abrahamson's per 40 stats unavailable. Skipping player!
# Adding Junior Abrahao's per 40 stats.
# Al Abram's per 40 stats unavailable. Skipping player!
# Adding DeAndre Abram's per 40 stats.
# Demetrius Abram's per 40 stats unavailable. Skipping player!
# Adding Gerrod Abram's per 40 stats.
# Adding Jimmy Abram's per 40 stats.
# Adding Lester Abram's per 40 stats.
# Lonnie Abram's per 40 stats unavailable. Skipping player!
# Mike Abram's per 40 stats unavailable. Skipping player!
# Vito Abramavicius's per 40 stats unavailable. Skipping player!
# Merle Abrames's per 40 stats unavailable. Skipping player!
# Jay Abramowitch's per 40 stats unavailable. Skipping player!
# Dave Abramowitz's per 40 stats unavailable. Skipping player!
# Adding David Abramowitz's per 40 stats.
# Adding A.J. Abrams's per 40 stats.
# Adding Aaron Abrams's per 40 stats.
# Adding Aleks Abrams's per 40 stats.
# Adding Byron Abrams's per 40 stats.
# Corky Abrams's per 40 stats unavailable. Skipping player!
# Adding Danya Abrams's per 40 stats.
# Adding Dexter Abrams's per 40 stats.
# Erv Abrams's per 40 stats unavailable. Skipping player!
# Henri Abrams's per 40 stats unavailable. Skipping player!
# Adding Jamar Abrams's per 40 stats.
# Adding James Abrams's per 40 stats.
# Jim Abrams's per 40 stats unavailable. Skipping player!
# Adding Lincoln Abrams's per 40 stats.
# Marvin Abrams's per 40 stats unavailable. Skipping player!
# Marvin Abrams's per 40 stats unavailable. Skipping player!
# Rodney Abrams's per 40 stats unavailable. Skipping player!
# Ronny Abrams's per 40 stats unavailable. Skipping player!
# Tim Abrams's per 40 stats unavailable. Skipping player!
# Adding Tracy Abrams's per 40 stats.
# Wayne Abrams's per 40 stats unavailable. Skipping player!
# _ Abrams's per 40 stats unavailable. Skipping player!
# Derric Abrecht's per 40 stats unavailable. Skipping player!
# Adding Alex Abreu's per 40 stats.
# Adding Alvin Abreu's per 40 stats.
# James Abromaitis's per 40 stats unavailable. Skipping player!
# Adding Jason Abromaitis's per 40 stats.
# Adding Tim Abromaitis's per 40 stats.
# Adding Devonta Abron's per 40 stats.
# Adding Tim Abruzzo's per 40 stats.
# Adding Drew Absher's per 40 stats.
# Dale Abshire's per 40 stats unavailable. Skipping player!
# Dale Abshire's per 40 stats unavailable. Skipping player!
# James Abston's per 40 stats unavailable. Skipping player!
# Adding Taylor Abt's per 40 stats.
# Adding Abdul-Malik Abu's per 40 stats.
# Adding Jamal Abu-Shamala's per 40 stats.
# Adding Mohamed Abuarisha's per 40 stats.
# Adding Abood Abuissa's per 40 stats.
# Adding Mohamed Abukar's per 40 stats.
# Pete Abuls's per 40 stats unavailable. Skipping player!
# Adding Joey Accaoui's per 40 stats.
# Pete Accetta's per 40 stats unavailable. Skipping player!
# Adding Jared Accettura's per 40 stats.
# Gene Acciari's per 40 stats unavailable. Skipping player!
# Ted Aceto's per 40 stats unavailable. Skipping player!
# Adding Kristopher Acevedo's per 40 stats.
# Lupe Acevedo's per 40 stats unavailable. Skipping player!
# _ Acevedo's per 40 stats unavailable. Skipping player!
# Adding Mohammed Acha's per 40 stats.
# Adding Kieron Achara's per 40 stats.
# Rick Achberger's per 40 stats unavailable. Skipping player!
# _ Achenbach's per 40 stats unavailable. Skipping player!
# Adding Haris Achilleos's per 40 stats.
# Adding God'sgift Achiuwa's per 40 stats.
# Adding Precious Achiuwa's per 40 stats.
# Adding Toma Acholonu's per 40 stats.
# Dana Achtzehn's per 40 stats unavailable. Skipping player!
# Adding Alex Acker's per 40 stats.
# Adding Jarvis Acker's per 40 stats.
# Jon Acker's per 40 stats unavailable. Skipping player!
# Adding Justin Acker's per 40 stats.
# Adding Matt Acker's per 40 stats.
# Adding Maurice Acker's per 40 stats.
# Adding Sean Acker's per 40 stats.
# Don Ackerman's per 40 stats unavailable. Skipping player!
# Gary Ackerman's per 40 stats unavailable. Skipping player!
# Ken Ackerman's per 40 stats unavailable. Skipping player!
# Adding Patrick Ackerman's per 40 stats.
# Adding Tad Ackerman's per 40 stats.
# Adding Tony Ackerman's per 40 stats.
# Carl Ackermann's per 40 stats unavailable. Skipping player!
# George Ackles's per 40 stats unavailable. Skipping player!
# Dan Ackley's per 40 stats unavailable. Skipping player!
# Earl Ackley's per 40 stats unavailable. Skipping player!
# _ Ackley's per 40 stats unavailable. Skipping player!
# Harold Acoff's per 40 stats unavailable. Skipping player!
# Rick Acord's per 40 stats unavailable. Skipping player!
# Adding Nikko Acosta's per 40 stats.
# Adding Shane Acoveno's per 40 stats.
# Adding Kris Acox's per 40 stats.
# Adding Milan Acquaah's per 40 stats.
# Adding Kobby Acquah's per 40 stats.
# Adding Alessandro Acquaviva's per 40 stats.
# Mark Acre's per 40 stats unavailable. Skipping player!
# Adding Kani Acree's per 40 stats.
# Jeff Acres's per 40 stats unavailable. Skipping player!
# Mark Acres's per 40 stats unavailable. Skipping player!
# Adding Matt Acres's per 40 stats.
# Mike Acres's per 40 stats unavailable. Skipping player!
# Walt Actwood's per 40 stats unavailable. Skipping player!
# Adding Darius Acuff's per 40 stats.
# Mike Acuff's per 40 stats unavailable. Skipping player!
# Adding Tyson Acuff's per 40 stats.
# Adding Jo Acuil's per 40 stats.
# Adding Mattia Acunzo's per 40 stats.
# Adding Quincy Acy's per 40 stats.
# Andrew Adair's per 40 stats unavailable. Skipping player!
# Bobby Adair's per 40 stats unavailable. Skipping player!
# Charles Adair's per 40 stats unavailable. Skipping player!
# Dick Adair's per 40 stats unavailable. Skipping player!
# Jerry Adair's per 40 stats unavailable. Skipping player!
# Adding Manny Adako's per 40 stats.
# Adding Arnaud William Adala Moto's per 40 stats.
# Edmund Adamczyk's per 40 stats unavailable. Skipping player!
# Chuck Adamek's per 40 stats unavailable. Skipping player!
# Mitch Adamek's per 40 stats unavailable. Skipping player!
# Joe Adamitis's per 40 stats unavailable. Skipping player!
# Adding Sam Adamo's per 40 stats.
# Adding Adama Adams's per 40 stats.
# Adding AJ Adams's per 40 stats.
# Adding Ako Adams's per 40 stats.
# Al Adams's per 40 stats unavailable. Skipping player!
# Adding Allen Adams's per 40 stats.
# Alton Adams's per 40 stats unavailable. Skipping player!
# Alvan Adams's per 40 stats unavailable. Skipping player!
# Adding Andre Adams's per 40 stats.
# Andre Adams's per 40 stats unavailable. Skipping player!
# Andre Adams's per 40 stats unavailable. Skipping player!
# Adding Andre Adams's per 40 stats.
# Adding Anthony Adams's per 40 stats.
# Adding Antonio Adams's per 40 stats.
# Adding Austin Adams's per 40 stats.
# Adding Bakari Adams's per 40 stats.
# Barry Adams's per 40 stats unavailable. Skipping player!
# Adding Ben Adams's per 40 stats.
# Adding Billy Adams's per 40 stats.
# Adding Blake Adams's per 40 stats.
# Bob Adams's per 40 stats unavailable. Skipping player!
# Bob Adams's per 40 stats unavailable. Skipping player!
# Bob Adams's per 40 stats unavailable. Skipping player!
# Bob Adams's per 40 stats unavailable. Skipping player!
# Bob Adams's per 40 stats unavailable. Skipping player!
# Adding Brandon Adams's per 40 stats.
# Adding Brandon Adams's per 40 stats.
# Brandon Adams's per 40 stats unavailable. Skipping player!
# Brandon Adams's per 40 stats unavailable. Skipping player!
# Adding Brendan Adams's per 40 stats.
# Adding Brian Adams's per 40 stats.
# Bud Adams's per 40 stats unavailable. Skipping player!
# Bunk Adams's per 40 stats unavailable. Skipping player!
# Burnett Adams's per 40 stats unavailable. Skipping player!
# Carl Adams's per 40 stats unavailable. Skipping player!
# Carroll Adams's per 40 stats unavailable. Skipping player!
# Adding Chad Adams's per 40 stats.
# Adding Changa Adams's per 40 stats.
# Charles Adams's per 40 stats unavailable. Skipping player!
# Charles Adams's per 40 stats unavailable. Skipping player!
# Charles Adams's per 40 stats unavailable. Skipping player!
# Adding Chase Adams's per 40 stats.
# Adding Chase Adams's per 40 stats.
# Adding Chase Adams's per 40 stats.
# Chip Adams's per 40 stats unavailable. Skipping player!
# Adding Chris Adams's per 40 stats.
# Adding Chris Adams's per 40 stats.
# Adding Chris Adams's per 40 stats.
# Adding Chris Adams's per 40 stats.
# Adding Christian Adams's per 40 stats.
# Clarence Adams's per 40 stats unavailable. Skipping player!
# Clayton Adams's per 40 stats unavailable. Skipping player!
# Dana Adams's per 40 stats unavailable. Skipping player!
# Adding Danny Adams's per 40 stats.
# Adding Darian Adams's per 40 stats.
# Darryl Adams's per 40 stats unavailable. Skipping player!
# Adding David Adams's per 40 stats.
# Adding DeAndre Adams's per 40 stats.
# Adding Demek Adams's per 40 stats.
# Adding Derek Adams's per 40 stats.
# Dick Adams's per 40 stats unavailable. Skipping player!
# Dick Adams's per 40 stats unavailable. Skipping player!
# Dick Adams's per 40 stats unavailable. Skipping player!
# Adding Dionte Adams's per 40 stats.
# Don Adams's per 40 stats unavailable. Skipping player!
# Adding Drew Adams's per 40 stats.
# Adding Dustin Adams's per 40 stats.
# Dwight Adams's per 40 stats unavailable. Skipping player!
# Eddie Adams's per 40 stats unavailable. Skipping player!
# Eddie Adams's per 40 stats unavailable. Skipping player!
# Eddie Adams's per 40 stats unavailable. Skipping player!
# Elmo Adams's per 40 stats unavailable. Skipping player!
# Adding Eric Adams's per 40 stats.
# Adding Eric Adams's per 40 stats.
# Eric Adams's per 40 stats unavailable. Skipping player!
# Adding Erik Adams's per 40 stats.
# Fred Adams's per 40 stats unavailable. Skipping player!
# Adding Garrius Adams's per 40 stats.
# Gary Adams's per 40 stats unavailable. Skipping player!
# Gary Adams's per 40 stats unavailable. Skipping player!
# George Adams's per 40 stats unavailable. Skipping player!
# Adding Girod Adams's per 40 stats.
# Adding Greg Adams's per 40 stats.
# Adding Hassan Adams's per 40 stats.
# Haywood Adams's per 40 stats unavailable. Skipping player!
# Adding Ian Adams's per 40 stats.
# Adding Isaiah Adams's per 40 stats.
# Jack Adams's per 40 stats unavailable. Skipping player!
# Jack Adams's per 40 stats unavailable. Skipping player!
# Jack Adams's per 40 stats unavailable. Skipping player!
# Jake Adams's per 40 stats unavailable. Skipping player!
# Adding Jalen Adams's per 40 stats.
# Adding Jalen Adams's per 40 stats.
# Adding Jamal Adams's per 40 stats.
# Adding Jamie Adams's per 40 stats.
# Jamil Adams's per 40 stats unavailable. Skipping player!
# Adding Jaylen Adams's per 40 stats.
# Jeff Adams's per 40 stats unavailable. Skipping player!
# Adding Jeremy Adams's per 40 stats.
# Adding Jerome Adams's per 40 stats.
# Jerry Adams's per 40 stats unavailable. Skipping player!
# Jim Adams's per 40 stats unavailable. Skipping player!
# Jim Adams's per 40 stats unavailable. Skipping player!
# Adding John Adams's per 40 stats.
# John Adams's per 40 stats unavailable. Skipping player!
# John Adams's per 40 stats unavailable. Skipping player!
# John Adams's per 40 stats unavailable. Skipping player!
# Adding Jonathan Adams's per 40 stats.
# Adding Jonathan Adams's per 40 stats.
# Adding Jordan Adams's per 40 stats.
# Adding Jordyn Adams's per 40 stats.
# Adding Josh Adams's per 40 stats.
# Adding Julian Adams's per 40 stats.
# Adding Kevin Adams's per 40 stats.
# Adding Kevin Adams's per 40 stats.
# Adding Kim Adams's per 40 stats.
# Lafayette Adams's per 40 stats unavailable. Skipping player!
# Adding Lamond Adams's per 40 stats.
# Larry Adams's per 40 stats unavailable. Skipping player!
# Len Adams's per 40 stats unavailable. Skipping player!
# Adding Levi Adams's per 40 stats.
# Adding Lindsey Adams's per 40 stats.
# Lloyd Adams's per 40 stats unavailable. Skipping player!
# Adding Louis Adams's per 40 stats.
# Adding Luke Adams's per 40 stats.
# Luke Adams's per 40 stats unavailable. Skipping player!
# Marcus Adams's per 40 stats unavailable. Skipping player!
# Adding Mark Adams's per 40 stats.
# Adding Mark Adams's per 40 stats.
# Mark Adams's per 40 stats unavailable. Skipping player!
# Adding Marlon Adams's per 40 stats.
# Adding Martavius Adams's per 40 stats.
# Marvin Adams's per 40 stats unavailable. Skipping player!
# Maurice Adams's per 40 stats unavailable. Skipping player!
# Maurice Adams's per 40 stats unavailable. Skipping player!
# Adding Melvin Adams's per 40 stats.
# Michael Adams's per 40 stats unavailable. Skipping player!
# Adding Michael Adams's per 40 stats.
# Mike Adams's per 40 stats unavailable. Skipping player!
# Adding Mike Adams's per 40 stats.
# Milton Adams's per 40 stats unavailable. Skipping player!
# Neil Adams's per 40 stats unavailable. Skipping player!
# Nugent Adams's per 40 stats unavailable. Skipping player!
# Adding Pete Adams's per 40 stats.
# Adding Phillip Adams's per 40 stats.
# Adding Quadry Adams's per 40 stats.
# Adding Randy Adams's per 40 stats.
# Ray Adams's per 40 stats unavailable. Skipping player!
# Ray Adams's per 40 stats unavailable. Skipping player!
# Raylon Adams's per 40 stats unavailable. Skipping player!
# Reggie Adams's per 40 stats unavailable. Skipping player!
# Rich Adams's per 40 stats unavailable. Skipping player!
# Richie Adams's per 40 stats unavailable. Skipping player!
# Ricky Adams's per 40 stats unavailable. Skipping player!
# Adding Rio Adams's per 40 stats.
# Adding Roderick Adams's per 40 stats.
# Rodney Adams's per 40 stats unavailable. Skipping player!
# Ron Adams's per 40 stats unavailable. Skipping player!
# Scott Adams's per 40 stats unavailable. Skipping player!
# Adding Shaun Adams's per 40 stats.
# Adding Shelby Adams's per 40 stats.
# Stan Adams's per 40 stats unavailable. Skipping player!
# Adding Stephaun Adams's per 40 stats.
# Steve Adams's per 40 stats unavailable. Skipping player!
# Steve Adams's per 40 stats unavailable. Skipping player!
# Adding Steven Adams's per 40 stats.
# Adding Taj Adams's per 40 stats.
# Ted Adams's per 40 stats unavailable. Skipping player!
# Thomas Adams's per 40 stats unavailable. Skipping player!
# Thomas Adams's per 40 stats unavailable. Skipping player!
# Thomas Adams's per 40 stats unavailable. Skipping player!
# Todd Adams's per 40 stats unavailable. Skipping player!
# Tom Adams's per 40 stats unavailable. Skipping player!
# Tom Adams's per 40 stats unavailable. Skipping player!
# Tom Adams's per 40 stats unavailable. Skipping player!
# Tom Adams's per 40 stats unavailable. Skipping player!
# Adding Tommy Adams's per 40 stats.
# Tony Adams's per 40 stats unavailable. Skipping player!
# Adding Tremell Adams's per 40 stats.
# Adding Tyler Adams's per 40 stats.
# Adding Tyrel Adams's per 40 stats.
# Tyrone Adams's per 40 stats unavailable. Skipping player!
# Adding Vic Adams's per 40 stats.
# Adding Will Adams's per 40 stats.
# Adding Will Adams's per 40 stats.
# Adding William Adams's per 40 stats.
# Adding Wink Adams's per 40 stats.
# Adding Xavier Adams's per 40 stats.
# Zachary Adams's per 40 stats unavailable. Skipping player!
# _ Adams's per 40 stats unavailable. Skipping player!
# _ Adams's per 40 stats unavailable. Skipping player!
# _ Adams's per 40 stats unavailable. Skipping player!
# _ Adams's per 40 stats unavailable. Skipping player!
# _ Adams's per 40 stats unavailable. Skipping player!
# Adding Mika Adams-Woods's per 40 stats.
# Chuck Adamson's per 40 stats unavailable. Skipping player!
# Dale Adamson's per 40 stats unavailable. Skipping player!
# Jan Adamson's per 40 stats unavailable. Skipping player!
# Jim Adamson's per 40 stats unavailable. Skipping player!
# John Adamson's per 40 stats unavailable. Skipping player!
# Adding Mark Adamson's per 40 stats.
# Adding Matt Adamson's per 40 stats.
# Adding Amin Adamu's per 40 stats.
# Adding Shareif Adamu's per 40 stats.
# Walt Adamushko's per 40 stats unavailable. Skipping player!
# Adding Jo Adande's per 40 stats.
# Alex Adas's per 40 stats unavailable. Skipping player!
# Adding Koki Adasi's per 40 stats.
# Adding Jalen Adaway's per 40 stats.
# Billy Joe Adcock's per 40 stats unavailable. Skipping player!
# John Adcock's per 40 stats unavailable. Skipping player!
# _ Adcock's per 40 stats unavailable. Skipping player!
# Adding Dylan Addae-Wusu's per 40 stats.
# Adding Jeffrey Addai's per 40 stats.
# Adding Dave Addelsberg's per 40 stats.
# Adding Blair Adderley's per 40 stats.
# Paul Adderley's per 40 stats unavailable. Skipping player!
# Manny Adderly's per 40 stats unavailable. Skipping player!
# Richie Adderly's per 40 stats unavailable. Skipping player!
# Adding Eric Addie's per 40 stats.
# Phil Addington's per 40 stats unavailable. Skipping player!
# Adding Brian Addison's per 40 stats.
# Carlos Addison's per 40 stats unavailable. Skipping player!
# CPT James Addison's per 40 stats unavailable. Skipping player!
# Curtis Addison's per 40 stats unavailable. Skipping player!
# John Addison's per 40 stats unavailable. Skipping player!
# John Addison's per 40 stats unavailable. Skipping player!
# Rafael Addison's per 40 stats unavailable. Skipping player!
# Raymond Addison's per 40 stats unavailable. Skipping player!
# Reed Addison's per 40 stats unavailable. Skipping player!
# Adding Tito Addison's per 40 stats.
# Jim Addleman's per 40 stats unavailable. Skipping player!
# Adding Emmanuel Addo's per 40 stats.
# Adding Isaiah Addo-Ankrah's per 40 stats.
# Adding David Adebanjo's per 40 stats.
# Adding Ade Adebayo's per 40 stats.
# Adding Bam Adebayo's per 40 stats.
# Adding Sunday Adebayo's per 40 stats.
# Adding Temi Adebayo's per 40 stats.
# Adding Rotolu Adebiyi's per 40 stats.
# Adding Ayo Adedeji's per 40 stats.
# Adding Desmond Adedeji's per 40 stats.
# Adding Adetunji Adedipe's per 40 stats.
# Adding Alex Adediran's per 40 stats.
# Adding Emmanuel Adedoyin's per 40 stats.
# Adding Ogo Adegboye's per 40 stats.
# Adding Emmanuel Adeife's per 40 stats.
# Adding Jawad Adekoya's per 40 stats.
# Adding Jubril Adekoya's per 40 stats.
# Adding Deji Adekunle's per 40 stats.
# Adding Emmanuel Adekunle's per 40 stats.
# Adding Deng Adel's per 40 stats.
# Adding Kenny Adeleke's per 40 stats.
# Adding Demilade Adelekun's per 40 stats.
# John Adelhardt's per 40 stats unavailable. Skipping player!
# Ron Adelhardt's per 40 stats unavailable. Skipping player!
# Darnell Adell's per 40 stats unavailable. Skipping player!
# Adding Sanjay Adell's per 40 stats.
# Clete Adelman's per 40 stats unavailable. Skipping player!
# Adding Max Adelman's per 40 stats.
# Rick Adelman's per 40 stats unavailable. Skipping player!
# Steve Adelman's per 40 stats unavailable. Skipping player!
# Glenn Adelsberger's per 40 stats unavailable. Skipping player!
# Howie Adelson's per 40 stats unavailable. Skipping player!
# _ Adelson's per 40 stats unavailable. Skipping player!
# Adding Seth Adelsperger's per 40 stats.
# Adding Armend Ademi's per 40 stats.
# Adding Anthony Ademiluyi's per 40 stats.
# Adding Quincy Ademokoya's per 40 stats.
# Adding Faisal Aden's per 40 stats.
# Len Aden's per 40 stats unavailable. Skipping player!
# Adding Shore Adenekan's per 40 stats.
# Adding J.T. Adenrele's per 40 stats.
# Adding Aaron Adeoye's per 40 stats.
# Adding Nurudeen Adepoju's per 40 stats.
# Dick Ader's per 40 stats unavailable. Skipping player!
# Adding Adefolalrin Adetogun's per 40 stats.
# Adding Mike Adewunmi's per 40 stats.
# Don Adey's per 40 stats unavailable. Skipping player!
# Adding Josh Adeyeye's per 40 stats.
# Adding Pernell Adgei's per 40 stats.
# Adding Anthony Adger's per 40 stats.
# Nate Adger's per 40 stats unavailable. Skipping player!
# Adding Silas Adheke's per 40 stats.
# Adding Deng Adiang's per 40 stats.
# Dick Adiar's per 40 stats unavailable. Skipping player!
# Adding Emmanuel Adigun's per 40 stats.
# Adding Yomi Adigun's per 40 stats.
# Adding Lazare Adingono's per 40 stats.
# Adding Niwayo Adjei's per 40 stats.
# Adding Frederic Adjiwanou's per 40 stats.
# Brooks Adkins's per 40 stats unavailable. Skipping player!
# Adding Chad Adkins's per 40 stats.
# Curtis Adkins's per 40 stats unavailable. Skipping player!
# David Adkins's per 40 stats unavailable. Skipping player!
# David Adkins's per 40 stats unavailable. Skipping player!
# David Adkins's per 40 stats unavailable. Skipping player!
# Doug Adkins's per 40 stats unavailable. Skipping player!
# Earl Adkins's per 40 stats unavailable. Skipping player!
# Jeff Adkins's per 40 stats unavailable. Skipping player!
# Jim Adkins's per 40 stats unavailable. Skipping player!
# Adding Joe Adkins's per 40 stats.
# Adding Keith Adkins's per 40 stats.
# Adding Lamar Adkins's per 40 stats.
# Paul Adkins's per 40 stats unavailable. Skipping player!
# Paul Adkins's per 40 stats unavailable. Skipping player!
# Rocky Adkins's per 40 stats unavailable. Skipping player!
# Adding Rodney Adkins's per 40 stats.
# Sidney Adkins's per 40 stats unavailable. Skipping player!
# _ Adkins's per 40 stats unavailable. Skipping player!
# David Adkisson's per 40 stats unavailable. Skipping player!
# Randy Adleman's per 40 stats unavailable. Skipping player!
# Allen Adler's per 40 stats unavailable. Skipping player!
# Adding Dan Adler's per 40 stats.
# Adding David Adler's per 40 stats.
# Gary Adler's per 40 stats unavailable. Skipping player!
# H.P. Adler's per 40 stats unavailable. Skipping player!
# Adding Jerod Adler's per 40 stats.
# Adding Landon Adler's per 40 stats.
# Adding Matt Adler's per 40 stats.
# Ray Adler's per 40 stats unavailable. Skipping player!
# Adding Scott Adler's per 40 stats.
# _ Adler's per 40 stats unavailable. Skipping player!
# Adding Quinton Adlesh's per 40 stats.
# Pat Adley's per 40 stats unavailable. Skipping player!
# Al Adney's per 40 stats unavailable. Skipping player!
# Adding Abdul Ado's per 40 stats.
# Adding Josh Adoh's per 40 stats.
# Adding Songo Adoki's per 40 stats.
# Terry Adolfson's per 40 stats unavailable. Skipping player!
# Mose Adolph's per 40 stats unavailable. Skipping player!
# Terry Adolph's per 40 stats unavailable. Skipping player!
# Adding Aurimas Adomaitis's per 40 stats.
# Joe Adomanis's per 40 stats unavailable. Skipping player!
# _ Adomitis's per 40 stats unavailable. Skipping player!
# Bryan Adrian's per 40 stats unavailable. Skipping player!
# Adding Nathan Adrian's per 40 stats.
# Rocky Adrianson's per 40 stats unavailable. Skipping player!
# Adding Jeff Adrien's per 40 stats.
# Charlie Adrion's per 40 stats unavailable. Skipping player!
# Adding Marvin Adu's per 40 stats.
# Adding Anthony Aduba's per 40 stats.
# Adding Rivest Aduku's per 40 stats.
# Adding Taylor Adway's per 40 stats.
# Adding Jason Aerts's per 40 stats.
# Adding Robert Aery's per 40 stats.
# Paul Afeaki's per 40 stats unavailable. Skipping player!
# Adding Serge Afeli's per 40 stats.
# Jim Affeldt's per 40 stats unavailable. Skipping player!
# Adding Arron Afflalo's per 40 stats.
# Ed Affolter's per 40 stats unavailable. Skipping player!
# Adding Jean-Paul Afif's per 40 stats.
# Adding Ernest Aflakpui's per 40 stats.
# Adding Wesley Afolayan's per 40 stats.
# Adding Isaac Aftalion's per 40 stats.
# Eddie Agard's per 40 stats unavailable. Skipping player!
# Adding Latiq Agard's per 40 stats.
# Eric Agardy's per 40 stats unavailable. Skipping player!
# Tom Agardy's per 40 stats unavailable. Skipping player!
# Tom Agardy's per 40 stats unavailable. Skipping player!
# Mark Agather's per 40 stats unavailable. Skipping player!
# Max Agather's per 40 stats unavailable. Skipping player!
# Adding Aguir Agau's per 40 stats.
# Adding Akoy Agau's per 40 stats.
# Adding Peter Agba's per 40 stats.
# Adding Uka Agbai's per 40 stats.
# Adding Ochai Agbaji's per 40 stats.
# Olofu Agbaji's per 40 stats unavailable. Skipping player!
# Largest Agbejemisin's per 40 stats unavailable. Skipping player!
# Adding Reggie Agbeko's per 40 stats.
# Adding Danny Agbelese's per 40 stats.
# Adding Chibuzo Agbo's per 40 stats.
# Adding Christopher Agbo's per 40 stats.
# Ayo Agbonkpolo's per 40 stats unavailable. Skipping player!
# Adding Max Agbonkpolo's per 40 stats.
# Adding Tunde Agboola's per 40 stats.
# Adding Arthur Agee's per 40 stats.
# Joe Agee's per 40 stats unavailable. Skipping player!
# Leonard Agee's per 40 stats unavailable. Skipping player!
# Leonard Agee's per 40 stats unavailable. Skipping player!
# Mike Agee's per 40 stats unavailable. Skipping player!
# Adding Ralph Agee's per 40 stats.
# Adding Rashaun Agee's per 40 stats.
# Robert Agee's per 40 stats unavailable. Skipping player!
# Adding Rod Agee's per 40 stats.
# Adding Sam Agee's per 40 stats.
# Adding Tajuan Agee's per 40 stats.
# Adding Jon Ager's per 40 stats.
# Adding Maurice Ager's per 40 stats.
# Adding Obij Aget's per 40 stats.
# Adding Sotiris Aggelou's per 40 stats.
# Adding Noruwa Agho's per 40 stats.
# Adding Patrick Agho's per 40 stats.
# David Agin's per 40 stats unavailable. Skipping player!
# Troy Agler's per 40 stats unavailable. Skipping player!
# Adding Aaron Agnew's per 40 stats.
# Adding Christian Agnew's per 40 stats.
# Adding Darrious Agnew's per 40 stats.
# Adding Leon Agnew's per 40 stats.
# Pat Agnew's per 40 stats unavailable. Skipping player!
# Richard Agnew's per 40 stats unavailable. Skipping player!
# Charlie Agnor's per 40 stats unavailable. Skipping player!
# _ Agoglia's per 40 stats unavailable. Skipping player!
# Chris Agorastos's per 40 stats unavailable. Skipping player!
# Adding Gabe Agorioge's per 40 stats.
# Adding Pietro Agostini's per 40 stats.
# Adding Jashaun Agosto's per 40 stats.
# Adding Denis Agre's per 40 stats.
# Adding Sydney Agudah's per 40 stats.
# Alex Agudio's per 40 stats unavailable. Skipping player!
# Adding Antoine Agudio's per 40 stats.
# Adding Ajang Aguek's per 40 stats.
# Adding Cassian Aguet's per 40 stats.
# Adding Diego Aguiar's per 40 stats.
# Adding Isaac Aguiar's per 40 stats.
# George Aguilar's per 40 stats unavailable. Skipping player!
# Adding Japeth Aguilar's per 40 stats.
# Pete Aguilar's per 40 stats unavailable. Skipping player!
# Adding Ron Aguilar's per 40 stats.
# Adding Ronnie Aguilar's per 40 stats.
# Adding Gabriel Aguirre's per 40 stats.
# Mark Aguirre's per 40 stats unavailable. Skipping player!
# Adding Nico Aguirre's per 40 stats.
# Adding Ray Aguirre's per 40 stats.
# Adding Moses Aguko's per 40 stats.
# Adding Franklin Agunanne's per 40 stats.
# Adding Devon Agusi's per 40 stats.
# Adding Chris Agwumaro's per 40 stats.
# Adding Jefkins Agyeman-Budu's per 40 stats.
# Adding Jamie Ahale's per 40 stats.
# Magdi Ahamed's per 40 stats unavailable. Skipping player!
# Adding Maverick Ahanmisi's per 40 stats.
# Adding Oren Aharoni's per 40 stats.
# Jerry Ahart's per 40 stats unavailable. Skipping player!
# Tom Ahaus's per 40 stats unavailable. Skipping player!
# Adding Blake Ahearn's per 40 stats.
# Adding Bobby Ahearn's per 40 stats.
# Ed Ahearn's per 40 stats unavailable. Skipping player!
# Ed Ahearn's per 40 stats unavailable. Skipping player!
# Jim Ahearn's per 40 stats unavailable. Skipping player!
# Adding Kwadzo Ahelegbe's per 40 stats.
# Adding Akrum Ahemed's per 40 stats.
# Adding David Ahern's per 40 stats.
# David Ahern's per 40 stats unavailable. Skipping player!
# Dennis Ahern's per 40 stats unavailable. Skipping player!
# Adding Derek Ahern's per 40 stats.
# Ed Ahern's per 40 stats unavailable. Skipping player!
# James Ahern's per 40 stats unavailable. Skipping player!
# Adding James Ahern's per 40 stats.
# William Ahern's per 40 stats unavailable. Skipping player!
# _ Aherns's per 40 stats unavailable. Skipping player!
# Andy Ahijevych's per 40 stats unavailable. Skipping player!
# _ Ahl's per 40 stats unavailable. Skipping player!
# Adding Jarkko Ahlbom's per 40 stats.
# Lloyd Ahlbrand's per 40 stats unavailable. Skipping player!
# Mike Ahlers's per 40 stats unavailable. Skipping player!
# Adding Adam Ahlfeld's per 40 stats.
# Steve Ahlfeld's per 40 stats unavailable. Skipping player!
# Adding Hampus Ahlin's per 40 stats.
# Walt Ahlstedt's per 40 stats unavailable. Skipping player!
# Adding Esa Ahmad's per 40 stats.
# Adding Khalil Ahmad's per 40 stats.
# Adding Mike Ahmad's per 40 stats.
# Adding Abdul Ahmed's per 40 stats.
# Adding Alat-Eldin Ahmed's per 40 stats.
# Adding Aly Ahmed's per 40 stats.
# Adding Bashir Ahmed's per 40 stats.
# Magdi Ahmed's per 40 stats unavailable. Skipping player!
# Adding Mo Ahmed's per 40 stats.
# Adding Muhammed Ahmed's per 40 stats.
# Adding Emir Ahmedic's per 40 stats.
# Paul Aho's per 40 stats unavailable. Skipping player!
# Adding Herve Aholode's per 40 stats.
# Adding Seth Ahrendt's per 40 stats.
# Adding Justin Ahrens's per 40 stats.
# Adding Kyle Ahrens's per 40 stats.
# Roger Ahrens's per 40 stats unavailable. Skipping player!
# Kevin Ahsmuhs's per 40 stats unavailable. Skipping player!
# Adding Olli Ahvenniemi's per 40 stats.
# Adding Giedrius Aidietis's per 40 stats.
# Adding Fiifi Aidoo's per 40 stats.
# Paul Aiello's per 40 stats unavailable. Skipping player!
# Paul Aiello's per 40 stats unavailable. Skipping player!
# Peter Aiello's per 40 stats unavailable. Skipping player!
# Adding Francis Aihe's per 40 stats.
# Al Aiken's per 40 stats unavailable. Skipping player!
# Adding Bryce Aiken's per 40 stats.
# Adding C.J. Aiken's per 40 stats.
# Curtis Aiken's per 40 stats unavailable. Skipping player!
# Darrell Aiken's per 40 stats unavailable. Skipping player!
# Adding Kim Aiken's per 40 stats.
# Miles Aiken's per 40 stats unavailable. Skipping player!
# Ron Aiken's per 40 stats unavailable. Skipping player!
# Adding Curtis Aiken Jr's per 40 stats.
# Abe Aikens's per 40 stats unavailable. Skipping player!
# Adding Travis Aikens's per 40 stats.
# Adding Walt Aikens's per 40 stats.
# Jon Aikten's per 40 stats unavailable. Skipping player!
# Duncan Ailing's per 40 stats unavailable. Skipping player!
# Adding Tyler Ailshie's per 40 stats.
# Adding Fardaws Aimaq's per 40 stats.
# Adding Babajidne Aina's per 40 stats.
# Adding Austin Ainge's per 40 stats.
# Adding Cooper Ainge's per 40 stats.
# Adding Crew Ainge's per 40 stats.
# Danny Ainge's per 40 stats unavailable. Skipping player!
# Doug Ainge's per 40 stats unavailable. Skipping player!
# Adding Richard Ainooson's per 40 stats.
# Sterling Ainsworth's per 40 stats unavailable. Skipping player!
# Adding Stelu Aioanei's per 40 stats.
# Jack Air's per 40 stats unavailable. Skipping player!
# Adding Scott Airato's per 40 stats.
# Adding Ben Aird's per 40 stats.
# Adding Tom Airey's per 40 stats.
# Frank Airington's per 40 stats unavailable. Skipping player!
# Jackie Airington's per 40 stats unavailable. Skipping player!
# Adding Jaylin Airington's per 40 stats.
# Stanley Airington's per 40 stats unavailable. Skipping player!
# Marty Aisdrade's per 40 stats unavailable. Skipping player!
# Matthew Aitch's per 40 stats unavailable. Skipping player!
# Adding Bobby Aitkenhead's per 40 stats.
# Adding Aloy Aiyar's per 40 stats.
# Adding Omotayo Aiyegbusi's per 40 stats.
# Adding Temi Aiyegbusi's per 40 stats.
# Adding Kanu Aja's per 40 stats.
# Adding John Bol Ajak's per 40 stats.
# Adding Jerard Ajami's per 40 stats.
# Adding Olushula Ajanaku's per 40 stats.
# Adding Bul Ajang's per 40 stats.
# Adding Abayomi Ajasin's per 40 stats.
# Adding Josh Ajayi's per 40 stats.
# Adding Junior Ajayi's per 40 stats.
# Adding Mobolaji Ajayi's per 40 stats.
# Adding Olalekan Ajayi's per 40 stats.
# Steve Ajello's per 40 stats unavailable. Skipping player!
# Adding Nigel Ajere's per 40 stats.
# Adding Joe Ajike's per 40 stats.
# Adding Chier Ajou's per 40 stats.
# Adding Chidi Ajufo's per 40 stats.
# Adding Austin Ajukwa's per 40 stats.
# Jack Ajzner's per 40 stats unavailable. Skipping player!
# Adding Jude Akabueze's per 40 stats.
# Adding Fayssal Akacem's per 40 stats.
# Adding O'Karo Akamune's per 40 stats.
# Adding Jarinn Akana's per 40 stats.
# Adding Kevin Akana's per 40 stats.
# Adding Jermaul Akanbi's per 40 stats.
# Adding Dimitry Akanda-Coronel's per 40 stats.
# Adding Dexter Akanno's per 40 stats.
# Greg Akars's per 40 stats unavailable. Skipping player!
# Adding Ameka Akaya's per 40 stats.
# Adding Gary Akbar's per 40 stats.
# Muhamad Akbar's per 40 stats unavailable. Skipping player!
# Adding Madut Akec's per 40 stats.
# Adding Nicola Akele's per 40 stats.
# Adding Nana Akenten's per 40 stats.
# Mike Aker's per 40 stats unavailable. Skipping player!
# Scott Aker's per 40 stats unavailable. Skipping player!
# Adding Glenn Akerland's per 40 stats.
# Adding Austin Akers's per 40 stats.
# Greg Akers's per 40 stats unavailable. Skipping player!
# Jim Akers's per 40 stats unavailable. Skipping player!
# Lane Akers's per 40 stats unavailable. Skipping player!
# Mike Akers's per 40 stats unavailable. Skipping player!
# Adding Rob Akers's per 40 stats.
# Adding Tyler Akers's per 40 stats.
# Willie Akers's per 40 stats unavailable. Skipping player!
# _ Akers's per 40 stats unavailable. Skipping player!
# Don Akerson's per 40 stats unavailable. Skipping player!
# Adding Bradley Akhile's per 40 stats.
# Adding Osekalome Akhile's per 40 stats.
# Adding Samson Akilo's per 40 stats.
# Adding Daniel Akin's per 40 stats.
# Henry Akin's per 40 stats unavailable. Skipping player!
# John Akin's per 40 stats unavailable. Skipping player!
# Lewis Akin's per 40 stats unavailable. Skipping player!
# Adding Nathan Akin's per 40 stats.
# Akin Akin-Otiko's per 40 stats unavailable. Skipping player!
# Adding Kawika Akina's per 40 stats.
# Adding Wale Akinbobola's per 40 stats.
# Adding Jeleel Akindele's per 40 stats.
# Adding Dokun Akingbade's per 40 stats.
# Adding Akin Akingbala's per 40 stats.
# Adding Babatunde Akingbola's per 40 stats.
# Adding Akini Akini's per 40 stats.
# Adding James Akinjo's per 40 stats.
# Adding Bryan Akinkugbe's per 40 stats.
# Adding Adebayo Akinkunle's per 40 stats.
# Adding Femi Akinnagbe's per 40 stats.
# Olufemi Akinola's per 40 stats unavailable. Skipping player!
# Adding Matt Akinosho's per 40 stats.
# Adding Femi Akinpetide's per 40 stats.
# Bill Akins's per 40 stats unavailable. Skipping player!
# Dan Akins's per 40 stats unavailable. Skipping player!
# Don Akins's per 40 stats unavailable. Skipping player!
# Adding Eric Akins's per 40 stats.
# Jerome Akins's per 40 stats unavailable. Skipping player!
# Ron Akins's per 40 stats unavailable. Skipping player!
# Adding Terrance Akins's per 40 stats.
# Terry Akins's per 40 stats unavailable. Skipping player!
# Adding Tony Akins's per 40 stats.
# Ulysses Akins's per 40 stats unavailable. Skipping player!
# Adding Tayo Akinsete's per 40 stats.
# Adding Doyin Akintobi-Adeyeye's per 40 stats.
# Adding Abiola Akintola's per 40 stats.
# Adding Ayo Akinwole's per 40 stats.
# Adding Victor Akinyanju's per 40 stats.
# Adding Kaodirichi Akobundu-Ehiog's per 40 stats.
# Adding Josh Akognon's per 40 stats.
# Adding Jamar Akoh's per 40 stats.
# Adding Akok Akok's per 40 stats.
# Adding Teeng Akol's per 40 stats.
# Adding Tola Akomolafe's per 40 stats.
# Adding DeVaughn Akoon-Purcell's per 40 stats.
# Adding Bol Akot's per 40 stats.
# Adding Emmanuel Akot's per 40 stats.
# Adding Ike Akotaobi's per 40 stats.
# Adding Benson Akpan's per 40 stats.
# Adding Nkeruwem Akpan's per 40 stats.
# Adding Uko Akpan's per 40 stats.
# Adding Raphael Akpejiori's per 40 stats.
# Adding George Akpele's per 40 stats.
# Adding Omar Akram's per 40 stats.
# Bill Akridge's per 40 stats unavailable. Skipping player!
# Dean Akridge's per 40 stats unavailable. Skipping player!
# Adding Matt Akridge's per 40 stats.
# Bernie Akromis's per 40 stats unavailable. Skipping player!
# T Akstens's per 40 stats unavailable. Skipping player!
# Adding Jonathan Aku's per 40 stats.
# Adding Michael Akuchie's per 40 stats.
# Adding Eso Akunne's per 40 stats.
# Adding Ogheneyole Akuwovo's per 40 stats.
# Adding Jordan Akwenuke's per 40 stats.
# Adding Josh Akwenuke's per 40 stats.
# Adding Theo Akwuba's per 40 stats.
# Adding Thomas Akyazili's per 40 stats.
# Abdur Rahim Al Mattin's per 40 stats unavailable. Skipping player!
# Adding Rashid Al-Kaleem's per 40 stats.
# Adding Mustafa Al-Sayyad's per 40 stats.
# Adding Sam Alabakis's per 40 stats.
# Adding Solomon Alabi's per 40 stats.
# John Alach's per 40 stats unavailable. Skipping player!
# Adding Ross Alacqua's per 40 stats.
# Adding Bola Alade's per 40 stats.
# Adding Edward Alade's per 40 stats.
# Adding Thomas Aladi's per 40 stats.
# Frank Alagia's per 40 stats unavailable. Skipping player!
# Frank Alagia's per 40 stats unavailable. Skipping player!
# Gerry Alaimo's per 40 stats unavailable. Skipping player!
# Rotimi Alakija's per 40 stats unavailable. Skipping player!
# Adding Ikaika Alama-Francis's per 40 stats.
# Adding Angel Alamo's per 40 stats.
# Adding Jakob Alamudun's per 40 stats.
# Rick Alander's per 40 stats unavailable. Skipping player!
# Adding Sean Alarcon's per 40 stats.
# Mark Alarie's per 40 stats unavailable. Skipping player!
# Tom Alas's per 40 stats unavailable. Skipping player!
# Adding Warith Alatishe's per 40 stats.
# Adding Jameel Alausa's per 40 stats.
# Adding P.J. Alawoya's per 40 stats.
# Ray Alba's per 40 stats unavailable. Skipping player!
# Vin Albanese's per 40 stats unavailable. Skipping player!
# _ Albanese's per 40 stats unavailable. Skipping player!
# Adding Corey Albano's per 40 stats.
# Glenn Albano's per 40 stats unavailable. Skipping player!
# James Albano's per 40 stats unavailable. Skipping player!
# Adding Steve Albany's per 40 stats.
# Stan Albeck's per 40 stats unavailable. Skipping player!
# Bud Albee's per 40 stats unavailable. Skipping player!
# Ray Albee's per 40 stats unavailable. Skipping player!
# Don Alberico's per 40 stats unavailable. Skipping player!
# Ron Albers's per 40 stats unavailable. Skipping player!
# Adding Tanner Albers's per 40 stats.
# Adding Travis Albers's per 40 stats.
# Bob Alberston's per 40 stats unavailable. Skipping player!
# Adding Braelee Albert's per 40 stats.
# Glenn Albert's per 40 stats unavailable. Skipping player!
# Adding Malik Albert's per 40 stats.
# Mike Albert's per 40 stats unavailable. Skipping player!
# Pete Albert's per 40 stats unavailable. Skipping player!
# Stan Albert's per 40 stats unavailable. Skipping player!
# John Albertell's per 40 stats unavailable. Skipping player!
# Charlie Alberti's per 40 stats unavailable. Skipping player!
# Adding Bryan Alberts's per 40 stats.
# Jerry Alberts's per 40 stats unavailable. Skipping player!
# Adding Mark Alberts's per 40 stats.
# Mike Alberts's per 40 stats unavailable. Skipping player!
# Bob Albertson's per 40 stats unavailable. Skipping player!
# Bob Albertson's per 40 stats unavailable. Skipping player!
# Mike Albertson's per 40 stats unavailable. Skipping player!
# Rick Albertson's per 40 stats unavailable. Skipping player!
# Dennis Albight's per 40 stats unavailable. Skipping player!
# Bob Albo's per 40 stats unavailable. Skipping player!
# Italo Albondi's per 40 stats unavailable. Skipping player!
# Bob Albrecht's per 40 stats unavailable. Skipping player!
# Fred Albrecht's per 40 stats unavailable. Skipping player!
# Jeff Albrecht's per 40 stats unavailable. Skipping player!
# Adding Justin Albrecht's per 40 stats.
# Randy Albrecht's per 40 stats unavailable. Skipping player!
# Adding Spike Albrecht's per 40 stats.
# Adding Stephen Albrecht's per 40 stats.
# Adding Beau Albrechtson's per 40 stats.
# Randy Albrecth's per 40 stats unavailable. Skipping player!
# Bob Albright's per 40 stats unavailable. Skipping player!
# Adding Chris Albright's per 40 stats.
# Adding Christian Albright's per 40 stats.
# Dana Albright's per 40 stats unavailable. Skipping player!
# Doug Albright's per 40 stats unavailable. Skipping player!
# Adding James Albright's per 40 stats.
# Jon Albright's per 40 stats unavailable. Skipping player!
# Thomas Albright's per 40 stats unavailable. Skipping player!
# Adding Tyrone Albright's per 40 stats.
# John Albrinck's per 40 stats unavailable. Skipping player!
# Adding Braxton Albritton's per 40 stats.
# Adding Chris Albritton's per 40 stats.
# Adding Dorian Albritton's per 40 stats.
# Adding Scotty Albritton's per 40 stats.
# Adding Eddie Alcantara's per 40 stats.
# Adding Wesley Alcegaire's per 40 stats.
# Adding Bradley Alcime's per 40 stats.
# Adding Marlon Alcindor's per 40 stats.
# Adding Shakeem Alcindor's per 40 stats.
# Adding McIntoche Alcius's per 40 stats.
# Adding Will Alcock's per 40 stats.
# Adding Dan Alcorn's per 40 stats.
# Gary Alcorn's per 40 stats unavailable. Skipping player!
# Harold Alcorn's per 40 stats unavailable. Skipping player!
# Mark Alcorn's per 40 stats unavailable. Skipping player!
# Adding Mike Alcorn's per 40 stats.
# Adding Santi Aldama's per 40 stats.
# Ron Alde's per 40 stats unavailable. Skipping player!
# Bob Alden's per 40 stats unavailable. Skipping player!
# Adding Drew Alder's per 40 stats.
# Adding Tyler Alderman's per 40 stats.
# Corky Alderson's per 40 stats unavailable. Skipping player!
# Adding Dylan Alderson's per 40 stats.
# Jack Alderson's per 40 stats unavailable. Skipping player!
# Adding Rico Alderson's per 40 stats.
# Adding Vincent Aldevinge's per 40 stats.
# Adding Jeff Aldinger's per 40 stats.
# Adding Brandon Aldrich's per 40 stats.
# Adding Cole Aldrich's per 40 stats.
# David Aldrich's per 40 stats unavailable. Skipping player!
# Adding Evan Aldrich's per 40 stats.
# Adding Josh Aldrich's per 40 stats.
# Ken Aldrich's per 40 stats unavailable. Skipping player!
# Thomas Aldrich's per 40 stats unavailable. Skipping player!
# Tim Aldrich's per 40 stats unavailable. Skipping player!
# Archie Aldridge's per 40 stats unavailable. Skipping player!
# Bill Aldridge's per 40 stats unavailable. Skipping player!
# Adding Colin Aldridge's per 40 stats.
# Harold Aldridge's per 40 stats unavailable. Skipping player!
# Adding Jackson Aldridge's per 40 stats.
# Adding LaMarcus Aldridge's per 40 stats.
# Lee Aldridge's per 40 stats unavailable. Skipping player!
# Mike Aldridge's per 40 stats unavailable. Skipping player!
# Adding Nick Aldridge's per 40 stats.
# Adding Peyton Aldridge's per 40 stats.
# Rod Aldridge's per 40 stats unavailable. Skipping player!
# Warren Aldridge's per 40 stats unavailable. Skipping player!
# Ronnie Aldy's per 40 stats unavailable. Skipping player!
# ...
# Jim Farley's per 40 stats unavailable. Skipping player!
# John Farley's per 40 stats unavailable. Skipping player!
# Adding Justin Farley's per 40 stats.
# Adding Kevin Farley's per 40 stats.
# Lance Farley's per 40 stats unavailable. Skipping player!
# Michael Farley's per 40 stats unavailable. Skipping player!
# Mike Farley's per 40 stats unavailable. Skipping player!
# Adding Rafael Farley's per 40 stats.
# Adding Reed Farley's per 40 stats.
# Adding Scott Farley's per 40 stats.
# Adding Terrance Farley's per 40 stats.
# Adding Timon Farley's per 40 stats.
# Tommy Farley's per 40 stats unavailable. Skipping player!
# William Farley's per 40 stats unavailable. Skipping player!
# Adding Willie Farley's per 40 stats.
# _ Farma's per 40 stats unavailable. Skipping player!
# Don Farmar's per 40 stats unavailable. Skipping player!
# Adding Jordan Farmar's per 40 stats.
# Adding Anthony Farmer's per 40 stats.
# Adding Ashton Farmer's per 40 stats.
# Adding Ben Farmer's per 40 stats.
# Bobby Farmer's per 40 stats unavailable. Skipping player!
# Adding Christian Farmer's per 40 stats.
# Adding Cory Farmer's per 40 stats.
# Adding Craig Farmer's per 40 stats.
# Darryl Farmer's per 40 stats unavailable. Skipping player!
# Adding Desmon Farmer's per 40 stats.
# Ed Farmer's per 40 stats unavailable. Skipping player!
# Adding Fletcher Farmer's per 40 stats.
# George Farmer's per 40 stats unavailable. Skipping player!
# Adding Jeff Farmer's per 40 stats.
# Adding Jemal Farmer's per 40 stats.
# Jim Farmer's per 40 stats unavailable. Skipping player!
# Jim Farmer's per 40 stats unavailable. Skipping player!
# John Farmer's per 40 stats unavailable. Skipping player!
# John Farmer's per 40 stats unavailable. Skipping player!
# Johnny Farmer's per 40 stats unavailable. Skipping player!
# Larry Farmer's per 40 stats unavailable. Skipping player!
# Mark Farmer's per 40 stats unavailable. Skipping player!
# Mike Farmer's per 40 stats unavailable. Skipping player!
# Adding Monte' Farmer's per 40 stats.
# Richie Farmer's per 40 stats unavailable. Skipping player!
# Robert Farmer's per 40 stats unavailable. Skipping player!
# Adding Steve Farmer's per 40 stats.
# Tony Farmer's per 40 stats unavailable. Skipping player!
# Keith Farnam's per 40 stats unavailable. Skipping player!
# George Farnbach's per 40 stats unavailable. Skipping player!
# Marc Farnell's per 40 stats unavailable. Skipping player!
# Brad Farnham's per 40 stats unavailable. Skipping player!
# Adding Sean Farnham's per 40 stats.
# Dave Farnsworth's per 40 stats unavailable. Skipping player!
# Frank Farnsworth's per 40 stats unavailable. Skipping player!
# _ Farnsworth's per 40 stats unavailable. Skipping player!
# Adding Ali Farokhmanesh's per 40 stats.
# Adding Hayden Farquhar's per 40 stats.
# Adding Junior Farquhar's per 40 stats.
# Steve Farquhar's per 40 stats unavailable. Skipping player!
# Adding Zach Farquhar's per 40 stats.
# Adding Puncho Farquharson's per 40 stats.
# Adding Dilon Farr's per 40 stats.
# J.B. Farr's per 40 stats unavailable. Skipping player!
# Adding James Farr's per 40 stats.
# James Farr's per 40 stats unavailable. Skipping player!
# Jim Farr's per 40 stats unavailable. Skipping player!
# Adding Lamarr Farr's per 40 stats.
# Morris Farr's per 40 stats unavailable. Skipping player!
# Stan Farr's per 40 stats unavailable. Skipping player!
# Terry Farr's per 40 stats unavailable. Skipping player!
# Adding Eli Farrakhan's per 40 stats.
# Adding Mustapha Farrakhan's per 40 stats.
# Adding Noah Farrakhan's per 40 stats.
# Adding AJ Farrar's per 40 stats.
# Joe Farrar's per 40 stats unavailable. Skipping player!
# Adding Nick Farrar's per 40 stats.
# Ralph Farrar's per 40 stats unavailable. Skipping player!
# Rex Farrar's per 40 stats unavailable. Skipping player!
# Larry Farrare's per 40 stats unavailable. Skipping player!
# Adding Brad Farrell's per 40 stats.
# Charlie 2 Farrell's per 40 stats unavailable. Skipping player!
# Adding Chris Farrell's per 40 stats.
# Adding Danny Farrell's per 40 stats.
# Donnie Farrell's per 40 stats unavailable. Skipping player!
# Doug Farrell's per 40 stats unavailable. Skipping player!
# Eddie Farrell's per 40 stats unavailable. Skipping player!
# Fred Farrell's per 40 stats unavailable. Skipping player!
# James Farrell's per 40 stats unavailable. Skipping player!
# James Farrell's per 40 stats unavailable. Skipping player!
# Adding Javorn Farrell's per 40 stats.
# John Farrell's per 40 stats unavailable. Skipping player!
# Josh Farrell's per 40 stats unavailable. Skipping player!
# Adding Kelvin Farrell's per 40 stats.
# Marty Farrell's per 40 stats unavailable. Skipping player!
# Adding Matt Farrell's per 40 stats.
# Adding Mike Farrell's per 40 stats.
# Mike Farrell's per 40 stats unavailable. Skipping player!
# Adding Mitch Farrell's per 40 stats.
# Pat Farrell's per 40 stats unavailable. Skipping player!
# Adding Patrick Farrell's per 40 stats.
# Richard Farrell's per 40 stats unavailable. Skipping player!
# Adding Sean Farrell's per 40 stats.
# Terry Farrell's per 40 stats unavailable. Skipping player!
# Tom Farrell's per 40 stats unavailable. Skipping player!
# Tom Farrell's per 40 stats unavailable. Skipping player!
# Tom Farrell's per 40 stats unavailable. Skipping player!
# Adding Zedrek Farrell's per 40 stats.
# _ Farrell's per 40 stats unavailable. Skipping player!
# Adding Mike Farrelly's per 40 stats.
# Derek Farren's per 40 stats unavailable. Skipping player!
# Jim Farren's per 40 stats unavailable. Skipping player!
# Adding Alex Farrer's per 40 stats.
# Bob Farrer's per 40 stats unavailable. Skipping player!
# Adding Trey Farrer's per 40 stats.
# James Farrington's per 40 stats unavailable. Skipping player!
# Adding Malcolm Farrington's per 40 stats.
# Adding Rodger Farrington's per 40 stats.
# Adding Scottie Farrington's per 40 stats.
# Tom Farrington's per 40 stats unavailable. Skipping player!
# Adding Torrey Farrington's per 40 stats.
# Adding Brent Farris's per 40 stats.
# David Farris's per 40 stats unavailable. Skipping player!
# Adding Duwe Farris's per 40 stats.
# Adding E.J. Farris's per 40 stats.
# Ivan Farris's per 40 stats unavailable. Skipping player!
# J.J. Farris's per 40 stats unavailable. Skipping player!
# Adding Kam Farris's per 40 stats.
# Lovell Farris's per 40 stats unavailable. Skipping player!
# Adding Mark Farris's per 40 stats.
# Adding Ravon Farris's per 40 stats.
# Adding Solomon Farris's per 40 stats.
# Adding Traylin Farris's per 40 stats.
# Ward Farris's per 40 stats unavailable. Skipping player!
# Adding Boo Farrow's per 40 stats.
# Adding Wendale Farrow's per 40 stats.
# Adding Max Farthing's per 40 stats.
# Adding Ali Faruq-Bey's per 40 stats.
# Ed Farver's per 40 stats unavailable. Skipping player!
# Dick Farwell's per 40 stats unavailable. Skipping player!
# John Farwell's per 40 stats unavailable. Skipping player!
# Bill Farwyke's per 40 stats unavailable. Skipping player!
# Adding Emmanuel Fasaye's per 40 stats.
# Bill Fash's per 40 stats unavailable. Skipping player!
# Adding Tedaryl Fason's per 40 stats.
# Panagiotis Fasoulas's per 40 stats unavailable. Skipping player!
# Roy Fasparski's per 40 stats unavailable. Skipping player!
# Quincy Fassette's per 40 stats unavailable. Skipping player!
# Al Fassnacht's per 40 stats unavailable. Skipping player!
# Charles Fast's per 40 stats unavailable. Skipping player!
# Adding Nathan Fast's per 40 stats.
# Roger Fasting's per 40 stats unavailable. Skipping player!
# Chuck Fath's per 40 stats unavailable. Skipping player!
# Reuben Fatheree's per 40 stats unavailable. Skipping player!
# Joey Fatta's per 40 stats unavailable. Skipping player!
# Chuck Faubion's per 40 stats unavailable. Skipping player!
# Jim Faucette's per 40 stats unavailable. Skipping player!
# Adding Brian Faulcon's per 40 stats.
# Adding Tim Faulconer's per 40 stats.
# Doug Faulds's per 40 stats unavailable. Skipping player!
# Adding Jaron Faulds's per 40 stats.
# Bill Faulhaber's per 40 stats unavailable. Skipping player!
# Adding Kenny Faulk's per 40 stats.
# Adding Oren Faulk's per 40 stats.
# Roger Faulk's per 40 stats unavailable. Skipping player!
# Adding Sam Faulk's per 40 stats.
# Adding Aaron Faulkner's per 40 stats.
# Bob Faulkner's per 40 stats unavailable. Skipping player!
# Adding Brian Faulkner's per 40 stats.
# Charles Faulkner's per 40 stats unavailable. Skipping player!
# Darrell Faulkner's per 40 stats unavailable. Skipping player!
# Adding Darryl Faulkner's per 40 stats.
# Doug Faulkner's per 40 stats unavailable. Skipping player!
# Adding Ethan Faulkner's per 40 stats.
# Adding Evan Faulkner's per 40 stats.
# Isaiah Faulkner's per 40 stats unavailable. Skipping player!
# Adding Jamal Faulkner's per 40 stats.
# James Faulkner's per 40 stats unavailable. Skipping player!
# Jeff Faulkner's per 40 stats unavailable. Skipping player!
# Adding Jeremy Faulkner's per 40 stats.
# Adding Jibreel Faulkner's per 40 stats.
# Adding Jim Faulkner's per 40 stats.
# Joe Faulkner's per 40 stats unavailable. Skipping player!
# Larry Faulkner's per 40 stats unavailable. Skipping player!
# Adding Mason Faulkner's per 40 stats.
# Mike Faulkner's per 40 stats unavailable. Skipping player!
# Mike Faulkner's per 40 stats unavailable. Skipping player!
# Adding Omari Faulkner's per 40 stats.
# Adding Robert Faulkner's per 40 stats.
# Adding Sean Faulkner's per 40 stats.
# Tim Faulkner's per 40 stats unavailable. Skipping player!
# Adding Trevon Faulkner's per 40 stats.
# Adding Jason Faulknor's per 40 stats.
# Allen Faulks's per 40 stats unavailable. Skipping player!
# Adding Thaddeus Fauntleroy's per 40 stats.
# Joe Faupl's per 40 stats unavailable. Skipping player!
# Adding Salim Fauras's per 40 stats.
# Adding Alonso Faure's per 40 stats.
# Buddy Faurole's per 40 stats unavailable. Skipping player!
# Adding Maizen Fausett's per 40 stats.
# _ Fausett's per 40 stats unavailable. Skipping player!
# Don Fausset's per 40 stats unavailable. Skipping player!
# Curtis Faust's per 40 stats unavailable. Skipping player!
# Duane Faust's per 40 stats unavailable. Skipping player!
# Eartha Faust's per 40 stats unavailable. Skipping player!
# Adding Erik Faust's per 40 stats.
# Adding Nick Faust's per 40 stats.
# Adding Al Faux's per 40 stats.
# Adding Don Faux's per 40 stats.
# Adding Andrew Fava's per 40 stats.
# Adding Matt Favaro's per 40 stats.
# Adding David Favorite's per 40 stats.
# Paul Favorite's per 40 stats unavailable. Skipping player!
# Adding Derrick Favors's per 40 stats.
# Adding Herman Favors's per 40 stats.
# Marx Favors's per 40 stats unavailable. Skipping player!
# Adding Watende Favors's per 40 stats.
# Adding Brendan Favre's per 40 stats.
# Marty Favret's per 40 stats unavailable. Skipping player!
# Adding Matt Faw's per 40 stats.
# Dave Fawcett's per 40 stats unavailable. Skipping player!
# Mike Fawcett's per 40 stats unavailable. Skipping player!
# Adding Saeed Fawehinmi's per 40 stats.
# Alan Fay's per 40 stats unavailable. Skipping player!
# Adding Carlton Fay's per 40 stats.
# Adding Jake Fay's per 40 stats.
# Adding Jared Fay's per 40 stats.
# Adding Lance Fay's per 40 stats.
# Adding Assane Faye's per 40 stats.
# Adding Cheikh Faye's per 40 stats.
# Adding Mouhammad Faye's per 40 stats.
# Adding Pierre Faye's per 40 stats.
# Adding Mike Fayed's per 40 stats.
# Johnny Fayne's per 40 stats unavailable. Skipping player!
# Adding Phil Fayne's per 40 stats.
# Adding Phillip Fayne's per 40 stats.
# Adding Tim Fayson's per 40 stats.
# Adding C.J. Fayton's per 40 stats.
# Adding Jay Fazande's per 40 stats.
# Joe Fazekas's per 40 stats unavailable. Skipping player!
# Adding Nick Fazekas's per 40 stats.
# Paul Fazekas's per 40 stats unavailable. Skipping player!
# Adding Ryan Fazekas's per 40 stats.
# Bob Fazio's per 40 stats unavailable. Skipping player!
# Bill Feagans's per 40 stats unavailable. Skipping player!
# Mike Feagans's per 40 stats unavailable. Skipping player!
# Adding Charles Feagin's per 40 stats.
# Adding KJ Feagin's per 40 stats.
# Adding Richard Feagin's per 40 stats.
# Jim Feamster's per 40 stats unavailable. Skipping player!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-6d35fb877e5f> in <module>
#      16     if len(per_40_html) != 0:
#      17         #Get base table/append if exists
# ---> 18         table0 = pd.read_html(per_40_html[0])
#      19         table00 = table0[0]
#      20         table00['player'] = official_players[i]
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1098         na_values=na_values,
#    1099         keep_default_na=keep_default_na,
# -> 1100         displayed_only=displayed_only,
#    1101     )
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     918     for table in tables:
#     919         try:
# --> 920             ret.append(_data_to_frame(data=table, **kwargs))
#     921         except EmptyDataError:  # empty table
#     922             continue
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/io/html.py in _data_to_frame(**kwargs)
#     797     _expand_elements(body)
#     798     tp = TextParser(body, header=header, **kwargs)
# --> 799     df = tp.read()
#     800     return df
#     801
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1146             new_rows = len(index)
#    1147
# -> 1148         df = DataFrame(col_dict, columns=columns, index=index)
#    1149
#    1150         self._currow += new_rows
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      72     axes = [ensure_index(columns), index]
#      73
# ---> 74     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      75
#      76
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/core/internals/managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1668
#    1669     try:
# -> 1670         blocks = form_blocks(arrays, names, axes)
#    1671         mgr = BlockManager(blocks, axes)
#    1672         mgr._consolidate_inplace()
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/core/internals/managers.py in form_blocks(arrays, names, axes)
#    1719         v = arrays[name_idx]
#    1720
# -> 1721         block_type = get_block_type(v)
#    1722         items_dict[block_type.__name__].append((i, k, v))
#    1723
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    3011     elif is_datetime64tz_dtype(values):
#    3012         cls = DatetimeTZBlock
# -> 3013     elif is_interval_dtype(dtype) or is_period_dtype(dtype):
#    3014         cls = ObjectValuesExtensionBlock
#    3015     elif is_extension_array_dtype(values):
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/core/dtypes/common.py in is_interval_dtype(arr_or_dtype)
#     537     if arr_or_dtype is None:
#     538         return False
# --> 539     return IntervalDtype.is_dtype(arr_or_dtype)
#     540
#     541
#
# /opt/anaconda3/envs/pythondata/lib/python3.6/site-packages/pandas/core/dtypes/dtypes.py in is_dtype(cls, dtype)
#    1122         self._subtype = state["subtype"]
#    1123
# -> 1124     @classmethod
#    1125     def is_dtype(cls, dtype) -> bool:
#    1126         """
#
# KeyboardInterrupt:

# %%
table.to_csv("Players_A-RichardFeagin.csv")

# %%
table
# Out:
#      Season              School    Conf   G  GS    MP   FG   FGA    FG%   2P  \
# 0   2006-07            Canisius    MAAC  28  13   383  2.6   6.2  0.424  2.6
# 1   2007-08            Canisius    MAAC  13   6   163  2.7   6.9  0.393  2.7
# 2    Career            Canisius     NaN  41  19   546  2.6   6.4  0.414  2.6
# 0   2009-10  North Dakota State  Summit  29  16   397  4.6   7.5  0.622  4.6
# 1   2011-12  North Dakota State  Summit  31   0   367  5.0   7.4  0.676  5.0
# ..      ...                 ...     ...  ..  ..   ...  ...   ...    ...  ...
# 6       NaN         Santa Clara     NaN  83  81  2757  6.3  14.1  0.443  4.0
# 7       NaN     San Diego State     NaN  32  32   971  4.2  10.8  0.384  1.8
# 0   2017-18      Morehead State     OVC  19   0   133  2.7   6.9  0.391  1.5
# 1   2018-19      Morehead State     OVC  10   0    58  4.1  11.0  0.375  2.8
# 2    Career      Morehead State     NaN  29   0   191  3.1   8.2  0.385  1.9
#
#     2PA    2P%   3P  3PA    3P%   FT  FTA    FT%   TRB  AST  STL  BLK  TOV  \
# 0   5.8  0.446  0.0  0.3  0.000  1.6  3.4  0.455   8.1  0.2  1.3  1.1  2.5
# 1   6.9  0.393  0.0  0.0    NaN  2.9  4.4  0.667  11.5  0.2  1.5  0.2  3.9
# 2   6.2  0.429  0.0  0.2  0.000  2.0  3.7  0.529   9.2  0.2  1.3  0.9  2.9
# 0   7.5  0.622  0.0  0.0    NaN  1.5  2.3  0.652   8.4  0.4  0.9  3.4  2.5
# 1   7.4  0.676  0.0  0.0    NaN  3.1  3.3  0.933   8.8  0.4  1.1  2.6  2.1
# ..  ...    ...  ...  ...    ...  ...  ...    ...   ...  ...  ...  ...  ...
# 6   8.6  0.472  2.2  5.5  0.398  2.4  2.9  0.840   3.2  4.8  1.0  0.1  2.8
# 7   4.6  0.384  2.4  6.2  0.384  1.2  1.5  0.833   4.3  3.9  0.8  0.4  2.2
# 0   4.2  0.357  1.2  2.7  0.444  0.0  0.0    NaN   6.6  3.6  0.9  0.0  3.3
# 1   5.5  0.500  1.4  5.5  0.250  2.8  3.4  0.800   6.2  4.8  0.0  0.0  2.1
# 2   4.6  0.409  1.3  3.6  0.353  0.8  1.0  0.800   6.5  4.0  0.6  0.0  2.9
#
#      PF   PTS          player
# 0   6.6   6.8   Menghe a'Nyam
# 1   6.9   8.3   Menghe a'Nyam
# 2   6.7   7.3   Menghe a'Nyam
# 0   6.0  10.8   Jordan Aaberg
# 1   6.1  13.1   Jordan Aaberg
# ..  ...   ...             ...
# 6   2.6  17.1       KJ Feagin
# 7   2.3  11.9       KJ Feagin
# 0   2.4   6.6  Richard Feagin
# 1   1.4  12.4  Richard Feagin
# 2   2.1   8.4  Richard Feagin
#
# [54899 rows x 26 columns]
